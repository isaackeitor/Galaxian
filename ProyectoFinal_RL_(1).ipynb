# %%
# !pip install gymnasium[atari] ale-py autorom imageio imageio-ffmpeg torch torchvision
# !AutoROM --accept-license
# Out:
# Requirement already satisfied: ale-py in /usr/local/lib/python3.12/dist-packages (0.11.2)
# Collecting autorom
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (2.37.2)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.12/dist-packages (0.6.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from autorom) (8.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from autorom) (2.32.4)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->autorom) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->autorom) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->autorom) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->autorom) (2025.10.5)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Installing collected packages: autorom
# Successfully installed autorom-0.6.1
# AutoROM will download the Atari 2600 ROMs.
# They will be installed to:
# 	/usr/local/lib/python3.12/dist-packages/AutoROM/roms
#
# Existing ROMs will be overwritten.
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/adventure.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/air_raid.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/alien.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/amidar.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/assault.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/asterix.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/asteroids.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/atlantis.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/atlantis2.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/backgammon.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/bank_heist.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/basic_math.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/battle_zone.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/beam_rider.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/berzerk.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/blackjack.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/bowling.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/boxing.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/breakout.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/carnival.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/casino.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/centipede.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/chopper_command.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/combat.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/crazy_climber.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/crossbow.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/darkchambers.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/defender.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/demon_attack.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/donkey_kong.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/double_dunk.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/earthworld.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/elevator_action.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/enduro.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/entombed.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/et.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/fishing_derby.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/flag_capture.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/freeway.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/frogger.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/frostbite.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/galaxian.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/gopher.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/gravitar.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/hangman.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/haunted_house.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/hero.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/human_cannonball.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/ice_hockey.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/jamesbond.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/journey_escape.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/joust.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/kaboom.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/kangaroo.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/keystone_kapers.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/king_kong.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/klax.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/koolaid.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/krull.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/kung_fu_master.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/laser_gates.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/lost_luggage.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/mario_bros.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/maze_craze.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/miniature_golf.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/montezuma_revenge.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/mr_do.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/ms_pacman.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/name_this_game.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/othello.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/pacman.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/phoenix.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/pitfall.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/pitfall2.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/pong.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/pooyan.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/private_eye.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/qbert.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/riverraid.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/road_runner.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/robotank.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/seaquest.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/sir_lancelot.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/skiing.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/solaris.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/space_invaders.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/space_war.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/star_gunner.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/superman.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/surround.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/tennis.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/tetris.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/tic_tac_toe_3d.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/time_pilot.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/trondead.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/turmoil.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/tutankham.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/up_n_down.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/venture.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/video_checkers.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/video_chess.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/video_cube.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/video_pinball.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/warlords.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/wizard_of_wor.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/word_zapper.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/yars_revenge.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/zaxxon.bin
# Done!

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
BASE_DIR = "/content/drive/MyDrive/galaxian_rl"
os.makedirs(BASE_DIR, exist_ok=True)
print("Usando carpeta:", BASE_DIR)
# Out:
# Mounted at /content/drive
# Usando carpeta: /content/drive/MyDrive/galaxian_rl

# %%
# env_utils.py
import gymnasium as gym
import ale_py
import numpy as np
import cv2
from collections import deque


class CustomAtariPreprocessing(gym.Wrapper):
    """
    Simplificado: convierte a escala de grises, reescala a (84, 84)
    y aplica frame_skip (por defecto 4).
    """

    def __init__(self, env, frame_skip=4, screen_size=84, grayscale_obs=True):
        super().__init__(env)
        self.frame_skip = frame_skip
        self.screen_size = screen_size
        self.grayscale_obs = grayscale_obs

        obs_shape = (screen_size, screen_size)
        if not grayscale_obs:
            obs_shape += (3,)

        self.observation_space = gym.spaces.Box(
            low=0, high=255, shape=obs_shape, dtype=np.uint8
        )

    def process_frame(self, frame):
        """Convierte y reescala el frame a 84x84"""
        if self.grayscale_obs:
            frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
            frame = cv2.resize(frame, (self.screen_size, self.screen_size), interpolation=cv2.INTER_AREA)
            return frame
        else:
            frame = cv2.resize(frame, (self.screen_size, self.screen_size), interpolation=cv2.INTER_AREA)
            return frame

    def step(self, action):
        """Ejecuta frame_skip pasos y devuelve el último frame procesado"""
        total_reward = 0.0
        terminated = truncated = False
        for _ in range(self.frame_skip):
            obs, reward, term, trunc, info = self.env.step(action)
            total_reward += reward
            terminated |= term
            truncated |= trunc
            if terminated or truncated:
                break
        processed = self.process_frame(obs)
        return processed, total_reward, terminated, truncated, info

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        processed = self.process_frame(obs)
        return processed, info


class CustomFrameStack(gym.Wrapper):
    """
    Apila los últimos N frames para captar la dinámica temporal.
    """

    def __init__(self, env, num_stack=4):
        super().__init__(env)
        self.num_stack = num_stack
        self.frames = deque([], maxlen=num_stack)
        low = np.repeat(env.observation_space.low[np.newaxis, ...], num_stack, axis=0)
        high = np.repeat(env.observation_space.high[np.newaxis, ...], num_stack, axis=0)
        self.observation_space = gym.spaces.Box(
            low=low.min(), high=high.max(), dtype=env.observation_space.dtype, shape=(num_stack, *env.observation_space.shape)
        )

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        for _ in range(self.num_stack):
            self.frames.append(obs)
        return self._get_obs(), info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        self.frames.append(obs)
        return self._get_obs(), reward, terminated, truncated, info

    def _get_obs(self):
        return np.stack(self.frames, axis=0)


def make_galaxian_env(seed: int | None = None, render_mode: str | None = None):
    """
    Crea el entorno ALE/Galaxian-v5 con preprocesamiento manual.
    - Reescalado a 84x84
    - Escala de grises
    - Frame skip = 4
    - Frame stack = 4
    """
    env = gym.make("ALE/Galaxian-v5", render_mode=render_mode)
    if seed is not None:
        env.reset(seed=seed)

    env = CustomAtariPreprocessing(env, frame_skip=4, screen_size=84, grayscale_obs=True)
    env = CustomFrameStack(env, num_stack=4)

    return env

# %%
# dqn_galaxian.py
# ------------------------------------------------------------
# DQN desde cero para ALE/Galaxian-v5 (Gymnasium + ALE-Py)
# Compatible con wrappers personalizados (env_utils.make_galaxian_env)
# - Observación por defecto: (4, 84, 84) (canal-primero)
# - Robusto si viene en (84, 84, 4) (canal-último): auto-detecta y permuta
# - Checkpoints periódicos en 'checkpoint_dir' (útil para Google Drive en Colab)
# ------------------------------------------------------------

import os
import csv
import random
from collections import deque
from typing import Tuple, Deque, List

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib
matplotlib.use("Agg")  # backend sin pantalla para guardar PNG
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# ============================================================
# Red DQN (estilo Nature)
# ============================================================
class DQN(nn.Module):
    """
    Red convolucional para estimar Q(s,a).
    Espera tensores en float normalizados [0,1] con formato (B, C, H, W).
    Si recibe (B, H, W, C) permuta automáticamente a (B, C, H, W).
    """
    def __init__(self, input_shape: Tuple[int, int, int], n_actions: int):
        super().__init__()
        c, h, w = input_shape
        self.expected_c = c  # Para validar/ajustar layout en forward

        self.features = nn.Sequential(
            nn.Conv2d(c, 32, kernel_size=8, stride=4),  # -> (B,32,20,20) aprox con 84x84
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 64, kernel_size=4, stride=2), # -> (B,64,9,9)
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, stride=1), # -> (B,64,7,7)
            nn.ReLU(inplace=True),
            nn.Flatten()
        )

        # Inferir tamaño del flatten de forma programática
        with torch.no_grad():
            dummy = torch.zeros(1, c, h, w)
            n_flat = self.features(dummy).shape[1]

        self.head = nn.Sequential(
            nn.Linear(n_flat, 512),
            nn.ReLU(inplace=True),
            nn.Linear(512, n_actions)
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        x: (B,C,H,W) uint8/float o (B,H,W,C) uint8/float
        Retorna Q(s,·): (B, n_actions)
        """
        if x.ndim != 4:
            raise ValueError(f"Se esperaba un tensor 4D, recibido x.ndim={x.ndim}")

        # Si viene en canal-último (B,H,W,C), permutamos a (B,C,H,W)
        if x.shape[1] != self.expected_c and x.shape[-1] == self.expected_c:
            x = x.permute(0, 3, 1, 2)

        # Asegurar float y normalizar
        x = x.float() / 255.0
        x = self.features(x)
        return self.head(x)


# ============================================================
# Replay Buffer
# ============================================================
class ReplayBuffer:
    def __init__(self, capacity: int):
        self.buffer: Deque = deque(maxlen=capacity)

    def push(self, s, a, r, ns, d):
        # Guardamos en bruto (uint8 para ahorrar memoria)
        self.buffer.append((s, a, r, ns, d))

    def sample(self, batch_size: int):
        batch = random.sample(self.buffer, batch_size)
        s, a, r, ns, d = map(np.array, zip(*batch))
        # Convertimos tipos; estados se quedan en uint8 para pasar a torch y normalizar allí
        return s, a, r, ns, d

    def __len__(self):
        return len(self.buffer)


# ============================================================
# Política para play.py (interfaz: __call__(obs, info) -> action)
# ============================================================
class DQNPolicy:
    def __init__(self, q_net: 'DQN'):
        self.q_net = q_net.to(device)
        self.q_net.eval()

    @torch.no_grad()
    def __call__(self, obs: np.ndarray, info: dict) -> int:
        """
        obs: (C,H,W) uint8 o (H,W,C) uint8
        """
        if obs.ndim != 3:
            raise ValueError(f"Se esperaba obs 3D, recibido obs.ndim={obs.ndim}")

        # Meter batch
        obs_batch = np.expand_dims(obs, axis=0)  # (1, C,H,W) o (1, H,W,C)
        obs_t = torch.from_numpy(obs_batch).to(device)
        q_vals = self.q_net(obs_t)
        return int(torch.argmax(q_vals, dim=1).item())


# ============================================================
# Utilidades de logging
# ============================================================
def _moving_average(x: List[float], k: int = 100):
    """Calcula la media móvil de una lista de valores."""
    if len(x) == 0:
        return []
    out = []
    s = 0.0
    q = []
    for i, v in enumerate(x):
        q.append(v)
        s += v
        if len(q) > k:
            s -= q.pop(0)
        out.append(s / len(q))
    return out

def _save_plot_and_csv(checkpoint_dir: str, rewards: List[float], episode: int):
    """Guarda gráfica de recompensas (PNG) y registro CSV."""
    os.makedirs(checkpoint_dir, exist_ok=True)

    # Guardar CSV
    csv_path = os.path.join(checkpoint_dir, "rewards_log.csv")
    new_file = not os.path.exists(csv_path)
    with open(csv_path, "a", newline="") as f:
        w = csv.writer(f)
        if new_file:
            w.writerow(["episode", "reward"])
        w.writerow([episode, rewards[-1]])

    # Guardar gráfica PNG
    plt.figure(figsize=(8, 4.5))
    plt.plot(rewards, label="Reward")
    ma = _moving_average(rewards, k=100)
    if len(ma) > 0:
        plt.plot(ma, label="Moving Avg (100)")
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.title("Training Rewards - DQN")
    plt.legend()
    png_path = os.path.join(checkpoint_dir, f"rewards_ep{episode}.png")
    plt.tight_layout()
    plt.savefig(png_path, dpi=120)
    plt.close()
    print(f"[LOG] Guardadas gráfica y CSV en: {png_path} / {csv_path}")


# ============================================================
# Entrenamiento DQN
# ============================================================
def train_dqn(
    checkpoint_dir: str,
    total_episodes: int = 500,
    replay_size: int = 100_000,
    batch_size: int = 32,
    gamma: float = 0.99,
    lr: float = 1e-4,
    start_epsilon: float = 1.0,
    end_epsilon: float = 0.1,
    epsilon_decay_episodes: int = 300,
    target_update_interval: int = 1_000,  # en pasos
    train_start: int = 10_000,            # tamaño mínimo de buffer para empezar a entrenar
    save_interval: int = 50,              # guardar checkpoints cada N episodios
    plot_interval: int = 50,              # guardar gráfica y CSV cada N episodios
    max_steps_per_episode: int | None = None,
    seed: int = 42,
):
    """
    Entrena un DQN minimalista para Galaxian.
    Guarda checkpoints periódicos en `checkpoint_dir` (ideal en /content/drive/... en Colab).
    Guarda gráficas de recompensa y CSV cada `plot_interval` episodios.
    Retorna la red Q entrenada (q_net).
    """
    os.makedirs(checkpoint_dir, exist_ok=True)

    # Entorno con wrappers personalizados (sin depender de gymnasium.wrappers)
    env = make_galaxian_env(seed=seed, render_mode=None)

    # Obtenemos shape de la observación y detectamos layout
    obs, _ = env.reset()
    if obs.ndim != 3:
        env.close()
        raise ValueError(f"Observación inesperada: ndim={obs.ndim}, se esperaba 3")

    # Auto-detectar (C,H,W) vs (H,W,C) y construir input_shape=(C,H,W)
    if obs.shape[0] in (1, 3, 4):  # canal-primero típico de CustomFrameStack
        input_shape = (obs.shape[0], obs.shape[1], obs.shape[2])
    else:                           # canal-último
        input_shape = (obs.shape[2], obs.shape[0], obs.shape[1])

    n_actions = env.action_space.n

    q_net = DQN(input_shape, n_actions).to(device)
    target_net = DQN(input_shape, n_actions).to(device)
    target_net.load_state_dict(q_net.state_dict())
    target_net.eval()

    optimizer = optim.Adam(q_net.parameters(), lr=lr)
    buffer = ReplayBuffer(replay_size)

    global_step = 0

    def epsilon_by_episode(ep: int) -> float:
        if ep >= epsilon_decay_episodes:
            return end_epsilon
        frac = ep / float(epsilon_decay_episodes)
        return start_epsilon + frac * (end_epsilon - start_epsilon)

    # (Opcional) logging sencillo
    rewards_log: List[float] = []

    for episode in range(1, total_episodes + 1):
        obs, _ = env.reset()
        done = False
        total_reward = 0.0
        eps = epsilon_by_episode(episode)
        steps_in_ep = 0

        while not done:
            global_step += 1
            steps_in_ep += 1

            # Epsilon-greedy
            if random.random() < eps:
                action = env.action_space.sample()
            else:
                with torch.no_grad():
                    ob = np.expand_dims(obs, axis=0)  # (1, C,H,W) o (1, H,W,C)
                    ob_t = torch.from_numpy(ob).to(device)
                    q_vals = q_net(ob_t)
                    action = int(torch.argmax(q_vals, dim=1).item())

            next_obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total_reward += float(reward)

            # Guardamos en buffer (mantener dtype uint8 en estados y next_estados)
            buffer.push(obs, action, reward, next_obs, done)
            obs = next_obs

            # Entrenar cuando el buffer tenga suficientes transiciones
            if len(buffer) >= train_start:
                s, a, r, ns, d = buffer.sample(batch_size)

                # Convertir a tensores
                s_t = torch.from_numpy(s).to(device)
                ns_t = torch.from_numpy(ns).to(device)
                a_t = torch.from_numpy(a).long().to(device)
                r_t = torch.from_numpy(r).float().to(device)
                d_t = torch.from_numpy(d.astype(np.float32)).to(device)

                # Q(s,a)
                q_vals = q_net(s_t)                       # (B, n_actions)
                q_a = q_vals.gather(1, a_t.unsqueeze(1)).squeeze(1)  # (B,)

                # y = r + gamma * max_a' Q_target(ns, a') * (1 - done)
                with torch.no_grad():
                    next_q = target_net(ns_t).max(1)[0]
                    target = r_t + gamma * next_q * (1.0 - d_t)

                loss = nn.functional.mse_loss(q_a, target)

                optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(q_net.parameters(), 10.0)
                optimizer.step()

            # Actualizar target network cada cierto número de pasos
            if global_step % target_update_interval == 0:
                target_net.load_state_dict(q_net.state_dict())

            # Límite duro de pasos por episodio (opcional)
            if max_steps_per_episode is not None and steps_in_ep >= max_steps_per_episode:
                break

        rewards_log.append(total_reward)
        print(f"[DQN] Episodio {episode}/{total_episodes} | Recompensa: {total_reward:.1f} | eps={eps:.3f} | buffer={len(buffer)}")

        # Guardar checkpoint en Google Drive cada N episodios
        if episode % save_interval == 0:
            ckpt_path = os.path.join(checkpoint_dir, f"dqn_galaxian_ep{episode}.pth")
            torch.save({
                "q_net": q_net.state_dict(),
                "target_net": target_net.state_dict(),
                "optimizer": optimizer.state_dict(),
                "episode": episode,
                "global_step": global_step,
                "rewards": rewards_log,
                "input_shape": input_shape,
                "n_actions": n_actions,
            }, ckpt_path)
            print(f"[DQN] Checkpoint guardado en: {ckpt_path}")

        # Guardar gráfica + CSV cada N episodios
        if episode % plot_interval == 0:
            _save_plot_and_csv(checkpoint_dir, rewards_log, episode)

    env.close()

    # Guardar pesos finales (solo la Q principal para inferencia)
    final_path = os.path.join(checkpoint_dir, "dqn_galaxian_final.pth")
    torch.save(q_net.state_dict(), final_path)
    print(f"[DQN] Modelo final guardado en: {final_path}")

    return q_net

# %%
dqn_dir = f"{BASE_DIR}/dqn"
q_net = train_dqn(checkpoint_dir=dqn_dir, total_episodes=10000, save_interval = 500, plot_interval=500)
# Out:
# [DQN] Episodio 1/10000 | Recompensa: 330.0 | eps=0.997 | buffer=71
# [DQN] Episodio 2/10000 | Recompensa: 390.0 | eps=0.994 | buffer=187
# [DQN] Episodio 3/10000 | Recompensa: 830.0 | eps=0.991 | buffer=426
# [DQN] Episodio 4/10000 | Recompensa: 540.0 | eps=0.988 | buffer=550
# [DQN] Episodio 5/10000 | Recompensa: 490.0 | eps=0.985 | buffer=698
# [DQN] Episodio 6/10000 | Recompensa: 300.0 | eps=0.982 | buffer=776
# [DQN] Episodio 7/10000 | Recompensa: 680.0 | eps=0.979 | buffer=929
# [DQN] Episodio 8/10000 | Recompensa: 580.0 | eps=0.976 | buffer=1054
# [DQN] Episodio 9/10000 | Recompensa: 1010.0 | eps=0.973 | buffer=1243
# [DQN] Episodio 10/10000 | Recompensa: 270.0 | eps=0.970 | buffer=1330
# [DQN] Episodio 11/10000 | Recompensa: 710.0 | eps=0.967 | buffer=1503
# [DQN] Episodio 12/10000 | Recompensa: 360.0 | eps=0.964 | buffer=1631
# [DQN] Episodio 13/10000 | Recompensa: 330.0 | eps=0.961 | buffer=1780
# [DQN] Episodio 14/10000 | Recompensa: 390.0 | eps=0.958 | buffer=1877
# [DQN] Episodio 15/10000 | Recompensa: 520.0 | eps=0.955 | buffer=2035
# [DQN] Episodio 16/10000 | Recompensa: 900.0 | eps=0.952 | buffer=2207
# [DQN] Episodio 17/10000 | Recompensa: 350.0 | eps=0.949 | buffer=2351
# [DQN] Episodio 18/10000 | Recompensa: 720.0 | eps=0.946 | buffer=2503
# [DQN] Episodio 19/10000 | Recompensa: 890.0 | eps=0.943 | buffer=2661
# [DQN] Episodio 20/10000 | Recompensa: 430.0 | eps=0.940 | buffer=2751
# [DQN] Episodio 21/10000 | Recompensa: 950.0 | eps=0.937 | buffer=2923
# [DQN] Episodio 22/10000 | Recompensa: 840.0 | eps=0.934 | buffer=3129
# [DQN] Episodio 23/10000 | Recompensa: 630.0 | eps=0.931 | buffer=3306
# [DQN] Episodio 24/10000 | Recompensa: 500.0 | eps=0.928 | buffer=3430
# [DQN] Episodio 25/10000 | Recompensa: 1060.0 | eps=0.925 | buffer=3575
# [DQN] Episodio 26/10000 | Recompensa: 590.0 | eps=0.922 | buffer=3695
# [DQN] Episodio 27/10000 | Recompensa: 610.0 | eps=0.919 | buffer=3862
# [DQN] Episodio 28/10000 | Recompensa: 690.0 | eps=0.916 | buffer=4040
# [DQN] Episodio 29/10000 | Recompensa: 1110.0 | eps=0.913 | buffer=4288
# [DQN] Episodio 30/10000 | Recompensa: 840.0 | eps=0.910 | buffer=4545
# [DQN] Episodio 31/10000 | Recompensa: 590.0 | eps=0.907 | buffer=4719
# [DQN] Episodio 32/10000 | Recompensa: 450.0 | eps=0.904 | buffer=4848
# [DQN] Episodio 33/10000 | Recompensa: 580.0 | eps=0.901 | buffer=4979
# [DQN] Episodio 34/10000 | Recompensa: 620.0 | eps=0.898 | buffer=5160
# [DQN] Episodio 35/10000 | Recompensa: 300.0 | eps=0.895 | buffer=5261
# [DQN] Episodio 36/10000 | Recompensa: 640.0 | eps=0.892 | buffer=5400
# [DQN] Episodio 37/10000 | Recompensa: 1030.0 | eps=0.889 | buffer=5619
# [DQN] Episodio 38/10000 | Recompensa: 1140.0 | eps=0.886 | buffer=5952
# [DQN] Episodio 39/10000 | Recompensa: 270.0 | eps=0.883 | buffer=6021
# [DQN] Episodio 40/10000 | Recompensa: 810.0 | eps=0.880 | buffer=6231
# [DQN] Episodio 41/10000 | Recompensa: 1370.0 | eps=0.877 | buffer=6578
# [DQN] Episodio 42/10000 | Recompensa: 350.0 | eps=0.874 | buffer=6694
# [DQN] Episodio 43/10000 | Recompensa: 610.0 | eps=0.871 | buffer=6852
# [DQN] Episodio 44/10000 | Recompensa: 630.0 | eps=0.868 | buffer=6990
# [DQN] Episodio 45/10000 | Recompensa: 620.0 | eps=0.865 | buffer=7178
# [DQN] Episodio 46/10000 | Recompensa: 450.0 | eps=0.862 | buffer=7268
# [DQN] Episodio 47/10000 | Recompensa: 420.0 | eps=0.859 | buffer=7406
# [DQN] Episodio 48/10000 | Recompensa: 1110.0 | eps=0.856 | buffer=7617
# [DQN] Episodio 49/10000 | Recompensa: 390.0 | eps=0.853 | buffer=7752
# [DQN] Episodio 50/10000 | Recompensa: 680.0 | eps=0.850 | buffer=7963
# [DQN] Episodio 51/10000 | Recompensa: 830.0 | eps=0.847 | buffer=8128
# [DQN] Episodio 52/10000 | Recompensa: 340.0 | eps=0.844 | buffer=8207
# [DQN] Episodio 53/10000 | Recompensa: 700.0 | eps=0.841 | buffer=8318
# [DQN] Episodio 54/10000 | Recompensa: 1350.0 | eps=0.838 | buffer=8699
# [DQN] Episodio 55/10000 | Recompensa: 330.0 | eps=0.835 | buffer=8766
# [DQN] Episodio 56/10000 | Recompensa: 210.0 | eps=0.832 | buffer=8838
# [DQN] Episodio 57/10000 | Recompensa: 1010.0 | eps=0.829 | buffer=9139
# [DQN] Episodio 58/10000 | Recompensa: 520.0 | eps=0.826 | buffer=9225
# [DQN] Episodio 59/10000 | Recompensa: 740.0 | eps=0.823 | buffer=9364
# [DQN] Episodio 60/10000 | Recompensa: 550.0 | eps=0.820 | buffer=9490
# [DQN] Episodio 61/10000 | Recompensa: 360.0 | eps=0.817 | buffer=9571
# [DQN] Episodio 62/10000 | Recompensa: 310.0 | eps=0.814 | buffer=9660
# [DQN] Episodio 63/10000 | Recompensa: 680.0 | eps=0.811 | buffer=9800
# [DQN] Episodio 64/10000 | Recompensa: 430.0 | eps=0.808 | buffer=9935
# [DQN] Episodio 65/10000 | Recompensa: 510.0 | eps=0.805 | buffer=10083
# [DQN] Episodio 66/10000 | Recompensa: 850.0 | eps=0.802 | buffer=10326
# [DQN] Episodio 67/10000 | Recompensa: 890.0 | eps=0.799 | buffer=10662
# [DQN] Episodio 68/10000 | Recompensa: 420.0 | eps=0.796 | buffer=10780
# [DQN] Episodio 69/10000 | Recompensa: 880.0 | eps=0.793 | buffer=10991
# [DQN] Episodio 70/10000 | Recompensa: 1230.0 | eps=0.790 | buffer=11210
# [DQN] Episodio 71/10000 | Recompensa: 490.0 | eps=0.787 | buffer=11296
# [DQN] Episodio 72/10000 | Recompensa: 590.0 | eps=0.784 | buffer=11423
# [DQN] Episodio 73/10000 | Recompensa: 1280.0 | eps=0.781 | buffer=11742
# [DQN] Episodio 74/10000 | Recompensa: 360.0 | eps=0.778 | buffer=11832
# [DQN] Episodio 75/10000 | Recompensa: 710.0 | eps=0.775 | buffer=11967
# [DQN] Episodio 76/10000 | Recompensa: 1120.0 | eps=0.772 | buffer=12169
# [DQN] Episodio 77/10000 | Recompensa: 390.0 | eps=0.769 | buffer=12240
# [DQN] Episodio 78/10000 | Recompensa: 460.0 | eps=0.766 | buffer=12372
# [DQN] Episodio 79/10000 | Recompensa: 420.0 | eps=0.763 | buffer=12483
# [DQN] Episodio 80/10000 | Recompensa: 760.0 | eps=0.760 | buffer=12663
# [DQN] Episodio 81/10000 | Recompensa: 770.0 | eps=0.757 | buffer=12821
# [DQN] Episodio 82/10000 | Recompensa: 1450.0 | eps=0.754 | buffer=13037
# [DQN] Episodio 83/10000 | Recompensa: 1060.0 | eps=0.751 | buffer=13196
# [DQN] Episodio 84/10000 | Recompensa: 530.0 | eps=0.748 | buffer=13326
# [DQN] Episodio 85/10000 | Recompensa: 530.0 | eps=0.745 | buffer=13421
# [DQN] Episodio 86/10000 | Recompensa: 510.0 | eps=0.742 | buffer=13555
# [DQN] Episodio 87/10000 | Recompensa: 390.0 | eps=0.739 | buffer=13633
# [DQN] Episodio 88/10000 | Recompensa: 600.0 | eps=0.736 | buffer=13778
# [DQN] Episodio 89/10000 | Recompensa: 700.0 | eps=0.733 | buffer=13910
# [DQN] Episodio 90/10000 | Recompensa: 240.0 | eps=0.730 | buffer=13997
# [DQN] Episodio 91/10000 | Recompensa: 270.0 | eps=0.727 | buffer=14065
# [DQN] Episodio 92/10000 | Recompensa: 1010.0 | eps=0.724 | buffer=14332
# [DQN] Episodio 93/10000 | Recompensa: 360.0 | eps=0.721 | buffer=14432
# [DQN] Episodio 94/10000 | Recompensa: 150.0 | eps=0.718 | buffer=14508
# [DQN] Episodio 95/10000 | Recompensa: 210.0 | eps=0.715 | buffer=14580
# [DQN] Episodio 96/10000 | Recompensa: 790.0 | eps=0.712 | buffer=14751
# [DQN] Episodio 97/10000 | Recompensa: 330.0 | eps=0.709 | buffer=14842
# [DQN] Episodio 98/10000 | Recompensa: 680.0 | eps=0.706 | buffer=14990
# [DQN] Episodio 99/10000 | Recompensa: 910.0 | eps=0.703 | buffer=15198
# [DQN] Episodio 100/10000 | Recompensa: 490.0 | eps=0.700 | buffer=15315
# [DQN] Episodio 101/10000 | Recompensa: 1070.0 | eps=0.697 | buffer=15496
# [DQN] Episodio 102/10000 | Recompensa: 1030.0 | eps=0.694 | buffer=15709
# [DQN] Episodio 103/10000 | Recompensa: 680.0 | eps=0.691 | buffer=15838
# [DQN] Episodio 104/10000 | Recompensa: 630.0 | eps=0.688 | buffer=15959
# [DQN] Episodio 105/10000 | Recompensa: 1160.0 | eps=0.685 | buffer=16129
# [DQN] Episodio 106/10000 | Recompensa: 670.0 | eps=0.682 | buffer=16284
# [DQN] Episodio 107/10000 | Recompensa: 500.0 | eps=0.679 | buffer=16399
# [DQN] Episodio 108/10000 | Recompensa: 600.0 | eps=0.676 | buffer=16540
# [DQN] Episodio 109/10000 | Recompensa: 440.0 | eps=0.673 | buffer=16622
# [DQN] Episodio 110/10000 | Recompensa: 370.0 | eps=0.670 | buffer=16727
# [DQN] Episodio 111/10000 | Recompensa: 1040.0 | eps=0.667 | buffer=16924
# [DQN] Episodio 112/10000 | Recompensa: 270.0 | eps=0.664 | buffer=16990
# [DQN] Episodio 113/10000 | Recompensa: 1340.0 | eps=0.661 | buffer=17298
# [DQN] Episodio 114/10000 | Recompensa: 330.0 | eps=0.658 | buffer=17374
# [DQN] Episodio 115/10000 | Recompensa: 650.0 | eps=0.655 | buffer=17508
# [DQN] Episodio 116/10000 | Recompensa: 400.0 | eps=0.652 | buffer=17598
# [DQN] Episodio 117/10000 | Recompensa: 650.0 | eps=0.649 | buffer=17718
# [DQN] Episodio 118/10000 | Recompensa: 1080.0 | eps=0.646 | buffer=17922
# [DQN] Episodio 119/10000 | Recompensa: 520.0 | eps=0.643 | buffer=18078
# [DQN] Episodio 120/10000 | Recompensa: 560.0 | eps=0.640 | buffer=18236
# [DQN] Episodio 121/10000 | Recompensa: 810.0 | eps=0.637 | buffer=18412
# [DQN] Episodio 122/10000 | Recompensa: 950.0 | eps=0.634 | buffer=18583
# [DQN] Episodio 123/10000 | Recompensa: 1350.0 | eps=0.631 | buffer=18833
# [DQN] Episodio 124/10000 | Recompensa: 1650.0 | eps=0.628 | buffer=19162
# [DQN] Episodio 125/10000 | Recompensa: 840.0 | eps=0.625 | buffer=19320
# [DQN] Episodio 126/10000 | Recompensa: 390.0 | eps=0.622 | buffer=19406
# [DQN] Episodio 127/10000 | Recompensa: 980.0 | eps=0.619 | buffer=19600
# [DQN] Episodio 128/10000 | Recompensa: 180.0 | eps=0.616 | buffer=19672
# [DQN] Episodio 129/10000 | Recompensa: 730.0 | eps=0.613 | buffer=19843
# [DQN] Episodio 130/10000 | Recompensa: 690.0 | eps=0.610 | buffer=20044
# [DQN] Episodio 131/10000 | Recompensa: 1100.0 | eps=0.607 | buffer=20222
# [DQN] Episodio 132/10000 | Recompensa: 150.0 | eps=0.604 | buffer=20297
# [DQN] Episodio 133/10000 | Recompensa: 720.0 | eps=0.601 | buffer=20423
# [DQN] Episodio 134/10000 | Recompensa: 920.0 | eps=0.598 | buffer=20608
# [DQN] Episodio 135/10000 | Recompensa: 750.0 | eps=0.595 | buffer=20774
# [DQN] Episodio 136/10000 | Recompensa: 800.0 | eps=0.592 | buffer=20907
# [DQN] Episodio 137/10000 | Recompensa: 750.0 | eps=0.589 | buffer=21031
# [DQN] Episodio 138/10000 | Recompensa: 1180.0 | eps=0.586 | buffer=21267
# [DQN] Episodio 139/10000 | Recompensa: 240.0 | eps=0.583 | buffer=21335
# [DQN] Episodio 140/10000 | Recompensa: 560.0 | eps=0.580 | buffer=21455
# [DQN] Episodio 141/10000 | Recompensa: 370.0 | eps=0.577 | buffer=21562
# [DQN] Episodio 142/10000 | Recompensa: 690.0 | eps=0.574 | buffer=21683
# [DQN] Episodio 143/10000 | Recompensa: 690.0 | eps=0.571 | buffer=21829
# [DQN] Episodio 144/10000 | Recompensa: 720.0 | eps=0.568 | buffer=22035
# [DQN] Episodio 145/10000 | Recompensa: 1110.0 | eps=0.565 | buffer=22247
# [DQN] Episodio 146/10000 | Recompensa: 370.0 | eps=0.562 | buffer=22366
# [DQN] Episodio 147/10000 | Recompensa: 410.0 | eps=0.559 | buffer=22488
# [DQN] Episodio 148/10000 | Recompensa: 510.0 | eps=0.556 | buffer=22608
# [DQN] Episodio 149/10000 | Recompensa: 1250.0 | eps=0.553 | buffer=22906
# [DQN] Episodio 150/10000 | Recompensa: 1190.0 | eps=0.550 | buffer=23130
# [DQN] Episodio 151/10000 | Recompensa: 360.0 | eps=0.547 | buffer=23221
# [DQN] Episodio 152/10000 | Recompensa: 210.0 | eps=0.544 | buffer=23293
# [DQN] Episodio 153/10000 | Recompensa: 450.0 | eps=0.541 | buffer=23417
# [DQN] Episodio 154/10000 | Recompensa: 270.0 | eps=0.538 | buffer=23504
# [DQN] Episodio 155/10000 | Recompensa: 1120.0 | eps=0.535 | buffer=23704
# [DQN] Episodio 156/10000 | Recompensa: 310.0 | eps=0.532 | buffer=23778
# [DQN] Episodio 157/10000 | Recompensa: 240.0 | eps=0.529 | buffer=23846
# [DQN] Episodio 158/10000 | Recompensa: 340.0 | eps=0.526 | buffer=23913
# [DQN] Episodio 159/10000 | Recompensa: 400.0 | eps=0.523 | buffer=23994
# [DQN] Episodio 160/10000 | Recompensa: 1380.0 | eps=0.520 | buffer=24253
# [DQN] Episodio 161/10000 | Recompensa: 370.0 | eps=0.517 | buffer=24376
# [DQN] Episodio 162/10000 | Recompensa: 750.0 | eps=0.514 | buffer=24501
# [DQN] Episodio 163/10000 | Recompensa: 860.0 | eps=0.511 | buffer=24624
# [DQN] Episodio 164/10000 | Recompensa: 450.0 | eps=0.508 | buffer=24718
# [DQN] Episodio 165/10000 | Recompensa: 340.0 | eps=0.505 | buffer=24828
# [DQN] Episodio 166/10000 | Recompensa: 870.0 | eps=0.502 | buffer=24979
# [DQN] Episodio 167/10000 | Recompensa: 870.0 | eps=0.499 | buffer=25149
# [DQN] Episodio 168/10000 | Recompensa: 530.0 | eps=0.496 | buffer=25263
# [DQN] Episodio 169/10000 | Recompensa: 830.0 | eps=0.493 | buffer=25436
# [DQN] Episodio 170/10000 | Recompensa: 840.0 | eps=0.490 | buffer=25644
# [DQN] Episodio 171/10000 | Recompensa: 300.0 | eps=0.487 | buffer=25712
# [DQN] Episodio 172/10000 | Recompensa: 420.0 | eps=0.484 | buffer=25811
# [DQN] Episodio 173/10000 | Recompensa: 660.0 | eps=0.481 | buffer=25931
# [DQN] Episodio 174/10000 | Recompensa: 800.0 | eps=0.478 | buffer=26091
# [DQN] Episodio 175/10000 | Recompensa: 1410.0 | eps=0.475 | buffer=26368
# [DQN] Episodio 176/10000 | Recompensa: 730.0 | eps=0.472 | buffer=26564
# [DQN] Episodio 177/10000 | Recompensa: 450.0 | eps=0.469 | buffer=26651
# [DQN] Episodio 178/10000 | Recompensa: 790.0 | eps=0.466 | buffer=26832
# [DQN] Episodio 179/10000 | Recompensa: 780.0 | eps=0.463 | buffer=26976
# [DQN] Episodio 180/10000 | Recompensa: 830.0 | eps=0.460 | buffer=27145
# [DQN] Episodio 181/10000 | Recompensa: 920.0 | eps=0.457 | buffer=27284
# [DQN] Episodio 182/10000 | Recompensa: 840.0 | eps=0.454 | buffer=27452
# [DQN] Episodio 183/10000 | Recompensa: 1050.0 | eps=0.451 | buffer=27620
# [DQN] Episodio 184/10000 | Recompensa: 640.0 | eps=0.448 | buffer=27736
# [DQN] Episodio 185/10000 | Recompensa: 920.0 | eps=0.445 | buffer=27936
# [DQN] Episodio 186/10000 | Recompensa: 590.0 | eps=0.442 | buffer=28055
# [DQN] Episodio 187/10000 | Recompensa: 1190.0 | eps=0.439 | buffer=28240
# [DQN] Episodio 188/10000 | Recompensa: 1420.0 | eps=0.436 | buffer=28479
# [DQN] Episodio 189/10000 | Recompensa: 810.0 | eps=0.433 | buffer=28646
# [DQN] Episodio 190/10000 | Recompensa: 550.0 | eps=0.430 | buffer=28774
# [DQN] Episodio 191/10000 | Recompensa: 180.0 | eps=0.427 | buffer=28846
# [DQN] Episodio 192/10000 | Recompensa: 760.0 | eps=0.424 | buffer=28990
# [DQN] Episodio 193/10000 | Recompensa: 620.0 | eps=0.421 | buffer=29138
# [DQN] Episodio 194/10000 | Recompensa: 1000.0 | eps=0.418 | buffer=29282
# [DQN] Episodio 195/10000 | Recompensa: 940.0 | eps=0.415 | buffer=29478
# [DQN] Episodio 196/10000 | Recompensa: 360.0 | eps=0.412 | buffer=29560
# [DQN] Episodio 197/10000 | Recompensa: 940.0 | eps=0.409 | buffer=29791
# [DQN] Episodio 198/10000 | Recompensa: 850.0 | eps=0.406 | buffer=29943
# [DQN] Episodio 199/10000 | Recompensa: 430.0 | eps=0.403 | buffer=30017
# [DQN] Episodio 200/10000 | Recompensa: 330.0 | eps=0.400 | buffer=30104
# [DQN] Episodio 201/10000 | Recompensa: 930.0 | eps=0.397 | buffer=30252
# [DQN] Episodio 202/10000 | Recompensa: 1020.0 | eps=0.394 | buffer=30448
# [DQN] Episodio 203/10000 | Recompensa: 1530.0 | eps=0.391 | buffer=30767
# [DQN] Episodio 204/10000 | Recompensa: 1210.0 | eps=0.388 | buffer=31089
# [DQN] Episodio 205/10000 | Recompensa: 1240.0 | eps=0.385 | buffer=31314
# [DQN] Episodio 206/10000 | Recompensa: 730.0 | eps=0.382 | buffer=31461
# [DQN] Episodio 207/10000 | Recompensa: 860.0 | eps=0.379 | buffer=31653
# [DQN] Episodio 208/10000 | Recompensa: 90.0 | eps=0.376 | buffer=31732
# [DQN] Episodio 209/10000 | Recompensa: 580.0 | eps=0.373 | buffer=31884
# [DQN] Episodio 210/10000 | Recompensa: 750.0 | eps=0.370 | buffer=32051
# [DQN] Episodio 211/10000 | Recompensa: 1520.0 | eps=0.367 | buffer=32364
# [DQN] Episodio 212/10000 | Recompensa: 530.0 | eps=0.364 | buffer=32469
# [DQN] Episodio 213/10000 | Recompensa: 1240.0 | eps=0.361 | buffer=32742
# [DQN] Episodio 214/10000 | Recompensa: 1280.0 | eps=0.358 | buffer=32991
# [DQN] Episodio 215/10000 | Recompensa: 750.0 | eps=0.355 | buffer=33108
# [DQN] Episodio 216/10000 | Recompensa: 1230.0 | eps=0.352 | buffer=33342
# [DQN] Episodio 217/10000 | Recompensa: 360.0 | eps=0.349 | buffer=33406
# [DQN] Episodio 218/10000 | Recompensa: 1420.0 | eps=0.346 | buffer=33684
# [DQN] Episodio 219/10000 | Recompensa: 570.0 | eps=0.343 | buffer=33760
# [DQN] Episodio 220/10000 | Recompensa: 1080.0 | eps=0.340 | buffer=33930
# [DQN] Episodio 221/10000 | Recompensa: 1460.0 | eps=0.337 | buffer=34197
# [DQN] Episodio 222/10000 | Recompensa: 850.0 | eps=0.334 | buffer=34346
# [DQN] Episodio 223/10000 | Recompensa: 520.0 | eps=0.331 | buffer=34526
# [DQN] Episodio 224/10000 | Recompensa: 540.0 | eps=0.328 | buffer=34628
# [DQN] Episodio 225/10000 | Recompensa: 1190.0 | eps=0.325 | buffer=34827
# [DQN] Episodio 226/10000 | Recompensa: 960.0 | eps=0.322 | buffer=35042
# [DQN] Episodio 227/10000 | Recompensa: 1220.0 | eps=0.319 | buffer=35218
# [DQN] Episodio 228/10000 | Recompensa: 580.0 | eps=0.316 | buffer=35325
# [DQN] Episodio 229/10000 | Recompensa: 460.0 | eps=0.313 | buffer=35444
# [DQN] Episodio 230/10000 | Recompensa: 800.0 | eps=0.310 | buffer=35564
# [DQN] Episodio 231/10000 | Recompensa: 900.0 | eps=0.307 | buffer=35695
# [DQN] Episodio 232/10000 | Recompensa: 450.0 | eps=0.304 | buffer=35782
# [DQN] Episodio 233/10000 | Recompensa: 500.0 | eps=0.301 | buffer=35894
# [DQN] Episodio 234/10000 | Recompensa: 610.0 | eps=0.298 | buffer=36010
# [DQN] Episodio 235/10000 | Recompensa: 2740.0 | eps=0.295 | buffer=36525
# [DQN] Episodio 236/10000 | Recompensa: 710.0 | eps=0.292 | buffer=36689
# [DQN] Episodio 237/10000 | Recompensa: 570.0 | eps=0.289 | buffer=36779
# [DQN] Episodio 238/10000 | Recompensa: 710.0 | eps=0.286 | buffer=36967
# [DQN] Episodio 239/10000 | Recompensa: 710.0 | eps=0.283 | buffer=37139
# [DQN] Episodio 240/10000 | Recompensa: 650.0 | eps=0.280 | buffer=37318
# [DQN] Episodio 241/10000 | Recompensa: 1110.0 | eps=0.277 | buffer=37542
# [DQN] Episodio 242/10000 | Recompensa: 980.0 | eps=0.274 | buffer=37761
# [DQN] Episodio 243/10000 | Recompensa: 1160.0 | eps=0.271 | buffer=38016
# [DQN] Episodio 244/10000 | Recompensa: 840.0 | eps=0.268 | buffer=38168
# [DQN] Episodio 245/10000 | Recompensa: 850.0 | eps=0.265 | buffer=38282
# [DQN] Episodio 246/10000 | Recompensa: 530.0 | eps=0.262 | buffer=38426
# [DQN] Episodio 247/10000 | Recompensa: 950.0 | eps=0.259 | buffer=38591
# [DQN] Episodio 248/10000 | Recompensa: 450.0 | eps=0.256 | buffer=38701
# [DQN] Episodio 249/10000 | Recompensa: 740.0 | eps=0.253 | buffer=38824
# [DQN] Episodio 250/10000 | Recompensa: 540.0 | eps=0.250 | buffer=38914
# [DQN] Episodio 251/10000 | Recompensa: 1500.0 | eps=0.247 | buffer=39236
# [DQN] Episodio 252/10000 | Recompensa: 1250.0 | eps=0.244 | buffer=39419
# [DQN] Episodio 253/10000 | Recompensa: 1420.0 | eps=0.241 | buffer=39727
# [DQN] Episodio 254/10000 | Recompensa: 660.0 | eps=0.238 | buffer=39874
# [DQN] Episodio 255/10000 | Recompensa: 820.0 | eps=0.235 | buffer=40053
# [DQN] Episodio 256/10000 | Recompensa: 330.0 | eps=0.232 | buffer=40121
# [DQN] Episodio 257/10000 | Recompensa: 1290.0 | eps=0.229 | buffer=40317
# [DQN] Episodio 258/10000 | Recompensa: 1090.0 | eps=0.226 | buffer=40494
# [DQN] Episodio 259/10000 | Recompensa: 390.0 | eps=0.223 | buffer=40573
# [DQN] Episodio 260/10000 | Recompensa: 420.0 | eps=0.220 | buffer=40644
# [DQN] Episodio 261/10000 | Recompensa: 980.0 | eps=0.217 | buffer=40820
# [DQN] Episodio 262/10000 | Recompensa: 550.0 | eps=0.214 | buffer=40936
# [DQN] Episodio 263/10000 | Recompensa: 480.0 | eps=0.211 | buffer=41017
# [DQN] Episodio 264/10000 | Recompensa: 760.0 | eps=0.208 | buffer=41172
# [DQN] Episodio 265/10000 | Recompensa: 1050.0 | eps=0.205 | buffer=41372
# [DQN] Episodio 266/10000 | Recompensa: 390.0 | eps=0.202 | buffer=41477
# [DQN] Episodio 267/10000 | Recompensa: 780.0 | eps=0.199 | buffer=41594
# [DQN] Episodio 268/10000 | Recompensa: 300.0 | eps=0.196 | buffer=41687
# [DQN] Episodio 269/10000 | Recompensa: 760.0 | eps=0.193 | buffer=41817
# [DQN] Episodio 270/10000 | Recompensa: 690.0 | eps=0.190 | buffer=41991
# [DQN] Episodio 271/10000 | Recompensa: 420.0 | eps=0.187 | buffer=42082
# [DQN] Episodio 272/10000 | Recompensa: 880.0 | eps=0.184 | buffer=42253
# [DQN] Episodio 273/10000 | Recompensa: 460.0 | eps=0.181 | buffer=42337
# [DQN] Episodio 274/10000 | Recompensa: 730.0 | eps=0.178 | buffer=42502
# [DQN] Episodio 275/10000 | Recompensa: 420.0 | eps=0.175 | buffer=42602
# [DQN] Episodio 276/10000 | Recompensa: 900.0 | eps=0.172 | buffer=42789
# [DQN] Episodio 277/10000 | Recompensa: 750.0 | eps=0.169 | buffer=42933
# [DQN] Episodio 278/10000 | Recompensa: 800.0 | eps=0.166 | buffer=43109
# [DQN] Episodio 279/10000 | Recompensa: 830.0 | eps=0.163 | buffer=43263
# [DQN] Episodio 280/10000 | Recompensa: 1500.0 | eps=0.160 | buffer=43469
# [DQN] Episodio 281/10000 | Recompensa: 790.0 | eps=0.157 | buffer=43610
# [DQN] Episodio 282/10000 | Recompensa: 890.0 | eps=0.154 | buffer=43760
# [DQN] Episodio 283/10000 | Recompensa: 1360.0 | eps=0.151 | buffer=43963
# [DQN] Episodio 284/10000 | Recompensa: 480.0 | eps=0.148 | buffer=44090
# [DQN] Episodio 285/10000 | Recompensa: 860.0 | eps=0.145 | buffer=44277
# [DQN] Episodio 286/10000 | Recompensa: 710.0 | eps=0.142 | buffer=44418
# [DQN] Episodio 287/10000 | Recompensa: 750.0 | eps=0.139 | buffer=44579
# [DQN] Episodio 288/10000 | Recompensa: 460.0 | eps=0.136 | buffer=44690
# [DQN] Episodio 289/10000 | Recompensa: 580.0 | eps=0.133 | buffer=44832
# [DQN] Episodio 290/10000 | Recompensa: 340.0 | eps=0.130 | buffer=44903
# [DQN] Episodio 291/10000 | Recompensa: 1040.0 | eps=0.127 | buffer=45036
# [DQN] Episodio 292/10000 | Recompensa: 860.0 | eps=0.124 | buffer=45146
# [DQN] Episodio 293/10000 | Recompensa: 830.0 | eps=0.121 | buffer=45292
# [DQN] Episodio 294/10000 | Recompensa: 680.0 | eps=0.118 | buffer=45443
# [DQN] Episodio 295/10000 | Recompensa: 2060.0 | eps=0.115 | buffer=45804
# [DQN] Episodio 296/10000 | Recompensa: 1260.0 | eps=0.112 | buffer=46010
# [DQN] Episodio 297/10000 | Recompensa: 670.0 | eps=0.109 | buffer=46141
# [DQN] Episodio 298/10000 | Recompensa: 1510.0 | eps=0.106 | buffer=46368
# [DQN] Episodio 299/10000 | Recompensa: 1070.0 | eps=0.103 | buffer=46538
# [DQN] Episodio 300/10000 | Recompensa: 790.0 | eps=0.100 | buffer=46669
# [DQN] Episodio 301/10000 | Recompensa: 970.0 | eps=0.100 | buffer=46873
# [DQN] Episodio 302/10000 | Recompensa: 1280.0 | eps=0.100 | buffer=47034
# [DQN] Episodio 303/10000 | Recompensa: 1900.0 | eps=0.100 | buffer=47254
# [DQN] Episodio 304/10000 | Recompensa: 1130.0 | eps=0.100 | buffer=47475
# [DQN] Episodio 305/10000 | Recompensa: 600.0 | eps=0.100 | buffer=47591
# [DQN] Episodio 306/10000 | Recompensa: 650.0 | eps=0.100 | buffer=47725
# [DQN] Episodio 307/10000 | Recompensa: 500.0 | eps=0.100 | buffer=47828
# [DQN] Episodio 308/10000 | Recompensa: 2040.0 | eps=0.100 | buffer=48103
# [DQN] Episodio 309/10000 | Recompensa: 760.0 | eps=0.100 | buffer=48230
# [DQN] Episodio 310/10000 | Recompensa: 910.0 | eps=0.100 | buffer=48381
# [DQN] Episodio 311/10000 | Recompensa: 840.0 | eps=0.100 | buffer=48525
# [DQN] Episodio 312/10000 | Recompensa: 890.0 | eps=0.100 | buffer=48676
# [DQN] Episodio 313/10000 | Recompensa: 270.0 | eps=0.100 | buffer=48760
# [DQN] Episodio 314/10000 | Recompensa: 660.0 | eps=0.100 | buffer=48883
# [DQN] Episodio 315/10000 | Recompensa: 640.0 | eps=0.100 | buffer=48957
# [DQN] Episodio 316/10000 | Recompensa: 1380.0 | eps=0.100 | buffer=49153
# [DQN] Episodio 317/10000 | Recompensa: 780.0 | eps=0.100 | buffer=49296
# [DQN] Episodio 318/10000 | Recompensa: 810.0 | eps=0.100 | buffer=49433
# [DQN] Episodio 319/10000 | Recompensa: 410.0 | eps=0.100 | buffer=49520
# [DQN] Episodio 320/10000 | Recompensa: 2040.0 | eps=0.100 | buffer=49896
# [DQN] Episodio 321/10000 | Recompensa: 520.0 | eps=0.100 | buffer=49985
# [DQN] Episodio 322/10000 | Recompensa: 460.0 | eps=0.100 | buffer=50125
# [DQN] Episodio 323/10000 | Recompensa: 430.0 | eps=0.100 | buffer=50251
# [DQN] Episodio 324/10000 | Recompensa: 510.0 | eps=0.100 | buffer=50340
# [DQN] Episodio 325/10000 | Recompensa: 600.0 | eps=0.100 | buffer=50486
# [DQN] Episodio 326/10000 | Recompensa: 1050.0 | eps=0.100 | buffer=50653
# [DQN] Episodio 327/10000 | Recompensa: 1290.0 | eps=0.100 | buffer=50970
# [DQN] Episodio 328/10000 | Recompensa: 660.0 | eps=0.100 | buffer=51123
# [DQN] Episodio 329/10000 | Recompensa: 420.0 | eps=0.100 | buffer=51198
# [DQN] Episodio 330/10000 | Recompensa: 1360.0 | eps=0.100 | buffer=51432
# [DQN] Episodio 331/10000 | Recompensa: 580.0 | eps=0.100 | buffer=51523
# [DQN] Episodio 332/10000 | Recompensa: 930.0 | eps=0.100 | buffer=51703
# [DQN] Episodio 333/10000 | Recompensa: 910.0 | eps=0.100 | buffer=51888
# [DQN] Episodio 334/10000 | Recompensa: 790.0 | eps=0.100 | buffer=52037
# [DQN] Episodio 335/10000 | Recompensa: 1370.0 | eps=0.100 | buffer=52371
# [DQN] Episodio 336/10000 | Recompensa: 660.0 | eps=0.100 | buffer=52464
# [DQN] Episodio 337/10000 | Recompensa: 1020.0 | eps=0.100 | buffer=52684
# [DQN] Episodio 338/10000 | Recompensa: 830.0 | eps=0.100 | buffer=52825
# [DQN] Episodio 339/10000 | Recompensa: 450.0 | eps=0.100 | buffer=52965
# [DQN] Episodio 340/10000 | Recompensa: 740.0 | eps=0.100 | buffer=53086
# [DQN] Episodio 341/10000 | Recompensa: 1860.0 | eps=0.100 | buffer=53371
# [DQN] Episodio 342/10000 | Recompensa: 460.0 | eps=0.100 | buffer=53455
# [DQN] Episodio 343/10000 | Recompensa: 1290.0 | eps=0.100 | buffer=53702
# [DQN] Episodio 344/10000 | Recompensa: 690.0 | eps=0.100 | buffer=53809
# [DQN] Episodio 345/10000 | Recompensa: 890.0 | eps=0.100 | buffer=53920
# [DQN] Episodio 346/10000 | Recompensa: 790.0 | eps=0.100 | buffer=54026
# [DQN] Episodio 347/10000 | Recompensa: 390.0 | eps=0.100 | buffer=54121
# [DQN] Episodio 348/10000 | Recompensa: 540.0 | eps=0.100 | buffer=54279
# [DQN] Episodio 349/10000 | Recompensa: 1290.0 | eps=0.100 | buffer=54504
# [DQN] Episodio 350/10000 | Recompensa: 1150.0 | eps=0.100 | buffer=54712
# [DQN] Episodio 351/10000 | Recompensa: 370.0 | eps=0.100 | buffer=54804
# [DQN] Episodio 352/10000 | Recompensa: 810.0 | eps=0.100 | buffer=55009
# [DQN] Episodio 353/10000 | Recompensa: 1110.0 | eps=0.100 | buffer=55190
# [DQN] Episodio 354/10000 | Recompensa: 360.0 | eps=0.100 | buffer=55283
# [DQN] Episodio 355/10000 | Recompensa: 1580.0 | eps=0.100 | buffer=55585
# [DQN] Episodio 356/10000 | Recompensa: 550.0 | eps=0.100 | buffer=55712
# [DQN] Episodio 357/10000 | Recompensa: 680.0 | eps=0.100 | buffer=55831
# [DQN] Episodio 358/10000 | Recompensa: 420.0 | eps=0.100 | buffer=55965
# [DQN] Episodio 359/10000 | Recompensa: 770.0 | eps=0.100 | buffer=56115
# [DQN] Episodio 360/10000 | Recompensa: 480.0 | eps=0.100 | buffer=56181
# [DQN] Episodio 361/10000 | Recompensa: 610.0 | eps=0.100 | buffer=56297
# [DQN] Episodio 362/10000 | Recompensa: 1100.0 | eps=0.100 | buffer=56509
# [DQN] Episodio 363/10000 | Recompensa: 900.0 | eps=0.100 | buffer=56676
# [DQN] Episodio 364/10000 | Recompensa: 850.0 | eps=0.100 | buffer=56899
# [DQN] Episodio 365/10000 | Recompensa: 1180.0 | eps=0.100 | buffer=57067
# [DQN] Episodio 366/10000 | Recompensa: 490.0 | eps=0.100 | buffer=57159
# [DQN] Episodio 367/10000 | Recompensa: 860.0 | eps=0.100 | buffer=57306
# [DQN] Episodio 368/10000 | Recompensa: 830.0 | eps=0.100 | buffer=57424
# [DQN] Episodio 369/10000 | Recompensa: 690.0 | eps=0.100 | buffer=57535
# [DQN] Episodio 370/10000 | Recompensa: 990.0 | eps=0.100 | buffer=57703
# [DQN] Episodio 371/10000 | Recompensa: 850.0 | eps=0.100 | buffer=57825
# [DQN] Episodio 372/10000 | Recompensa: 730.0 | eps=0.100 | buffer=57950
# [DQN] Episodio 373/10000 | Recompensa: 390.0 | eps=0.100 | buffer=58056
# [DQN] Episodio 374/10000 | Recompensa: 990.0 | eps=0.100 | buffer=58255
# [DQN] Episodio 375/10000 | Recompensa: 680.0 | eps=0.100 | buffer=58364
# [DQN] Episodio 376/10000 | Recompensa: 1150.0 | eps=0.100 | buffer=58598
# [DQN] Episodio 377/10000 | Recompensa: 1520.0 | eps=0.100 | buffer=58837
# [DQN] Episodio 378/10000 | Recompensa: 500.0 | eps=0.100 | buffer=58931
# [DQN] Episodio 379/10000 | Recompensa: 1150.0 | eps=0.100 | buffer=59131
# [DQN] Episodio 380/10000 | Recompensa: 710.0 | eps=0.100 | buffer=59228
# [DQN] Episodio 381/10000 | Recompensa: 990.0 | eps=0.100 | buffer=59369
# [DQN] Episodio 382/10000 | Recompensa: 640.0 | eps=0.100 | buffer=59504
# [DQN] Episodio 383/10000 | Recompensa: 1050.0 | eps=0.100 | buffer=59690
# [DQN] Episodio 384/10000 | Recompensa: 540.0 | eps=0.100 | buffer=59824
# [DQN] Episodio 385/10000 | Recompensa: 830.0 | eps=0.100 | buffer=59944
# [DQN] Episodio 386/10000 | Recompensa: 720.0 | eps=0.100 | buffer=60059
# [DQN] Episodio 387/10000 | Recompensa: 400.0 | eps=0.100 | buffer=60146
# [DQN] Episodio 388/10000 | Recompensa: 860.0 | eps=0.100 | buffer=60311
# [DQN] Episodio 389/10000 | Recompensa: 1030.0 | eps=0.100 | buffer=60521
# [DQN] Episodio 390/10000 | Recompensa: 860.0 | eps=0.100 | buffer=60700
# [DQN] Episodio 391/10000 | Recompensa: 830.0 | eps=0.100 | buffer=60825
# [DQN] Episodio 392/10000 | Recompensa: 1060.0 | eps=0.100 | buffer=60987
# [DQN] Episodio 393/10000 | Recompensa: 330.0 | eps=0.100 | buffer=61057
# [DQN] Episodio 394/10000 | Recompensa: 960.0 | eps=0.100 | buffer=61176
# [DQN] Episodio 395/10000 | Recompensa: 1360.0 | eps=0.100 | buffer=61405
# [DQN] Episodio 396/10000 | Recompensa: 300.0 | eps=0.100 | buffer=61474
# [DQN] Episodio 397/10000 | Recompensa: 930.0 | eps=0.100 | buffer=61626
# [DQN] Episodio 398/10000 | Recompensa: 300.0 | eps=0.100 | buffer=61729
# [DQN] Episodio 399/10000 | Recompensa: 690.0 | eps=0.100 | buffer=61833
# [DQN] Episodio 400/10000 | Recompensa: 610.0 | eps=0.100 | buffer=61926
# [DQN] Episodio 401/10000 | Recompensa: 490.0 | eps=0.100 | buffer=61994
# [DQN] Episodio 402/10000 | Recompensa: 510.0 | eps=0.100 | buffer=62084
# [DQN] Episodio 403/10000 | Recompensa: 630.0 | eps=0.100 | buffer=62217
# [DQN] Episodio 404/10000 | Recompensa: 1030.0 | eps=0.100 | buffer=62412
# [DQN] Episodio 405/10000 | Recompensa: 560.0 | eps=0.100 | buffer=62527
# [DQN] Episodio 406/10000 | Recompensa: 810.0 | eps=0.100 | buffer=62694
# [DQN] Episodio 407/10000 | Recompensa: 1510.0 | eps=0.100 | buffer=63055
# [DQN] Episodio 408/10000 | Recompensa: 400.0 | eps=0.100 | buffer=63154
# [DQN] Episodio 409/10000 | Recompensa: 590.0 | eps=0.100 | buffer=63270
# [DQN] Episodio 410/10000 | Recompensa: 660.0 | eps=0.100 | buffer=63408
# [DQN] Episodio 411/10000 | Recompensa: 270.0 | eps=0.100 | buffer=63495
# [DQN] Episodio 412/10000 | Recompensa: 320.0 | eps=0.100 | buffer=63564
# [DQN] Episodio 413/10000 | Recompensa: 1020.0 | eps=0.100 | buffer=63746
# [DQN] Episodio 414/10000 | Recompensa: 1060.0 | eps=0.100 | buffer=63904
# [DQN] Episodio 415/10000 | Recompensa: 1100.0 | eps=0.100 | buffer=64183
# [DQN] Episodio 416/10000 | Recompensa: 860.0 | eps=0.100 | buffer=64378
# [DQN] Episodio 417/10000 | Recompensa: 1210.0 | eps=0.100 | buffer=64668
# [DQN] Episodio 418/10000 | Recompensa: 810.0 | eps=0.100 | buffer=64858
# [DQN] Episodio 419/10000 | Recompensa: 480.0 | eps=0.100 | buffer=64944
# [DQN] Episodio 420/10000 | Recompensa: 880.0 | eps=0.100 | buffer=65084
# [DQN] Episodio 421/10000 | Recompensa: 480.0 | eps=0.100 | buffer=65178
# [DQN] Episodio 422/10000 | Recompensa: 540.0 | eps=0.100 | buffer=65263
# [DQN] Episodio 423/10000 | Recompensa: 300.0 | eps=0.100 | buffer=65332
# [DQN] Episodio 424/10000 | Recompensa: 610.0 | eps=0.100 | buffer=65468
# [DQN] Episodio 425/10000 | Recompensa: 520.0 | eps=0.100 | buffer=65542
# [DQN] Episodio 426/10000 | Recompensa: 940.0 | eps=0.100 | buffer=65808
# [DQN] Episodio 427/10000 | Recompensa: 910.0 | eps=0.100 | buffer=65992
# [DQN] Episodio 428/10000 | Recompensa: 710.0 | eps=0.100 | buffer=66106
# [DQN] Episodio 429/10000 | Recompensa: 1420.0 | eps=0.100 | buffer=66425
# [DQN] Episodio 430/10000 | Recompensa: 1110.0 | eps=0.100 | buffer=66607
# [DQN] Episodio 431/10000 | Recompensa: 990.0 | eps=0.100 | buffer=66787
# [DQN] Episodio 432/10000 | Recompensa: 810.0 | eps=0.100 | buffer=66911
# [DQN] Episodio 433/10000 | Recompensa: 810.0 | eps=0.100 | buffer=67081
# [DQN] Episodio 434/10000 | Recompensa: 1390.0 | eps=0.100 | buffer=67330
# [DQN] Episodio 435/10000 | Recompensa: 890.0 | eps=0.100 | buffer=67537
# [DQN] Episodio 436/10000 | Recompensa: 780.0 | eps=0.100 | buffer=67711
# [DQN] Episodio 437/10000 | Recompensa: 880.0 | eps=0.100 | buffer=67848
# [DQN] Episodio 438/10000 | Recompensa: 1460.0 | eps=0.100 | buffer=68097
# [DQN] Episodio 439/10000 | Recompensa: 330.0 | eps=0.100 | buffer=68175
# [DQN] Episodio 440/10000 | Recompensa: 490.0 | eps=0.100 | buffer=68254
# [DQN] Episodio 441/10000 | Recompensa: 640.0 | eps=0.100 | buffer=68387
# [DQN] Episodio 442/10000 | Recompensa: 1050.0 | eps=0.100 | buffer=68544
# [DQN] Episodio 443/10000 | Recompensa: 910.0 | eps=0.100 | buffer=68732
# [DQN] Episodio 444/10000 | Recompensa: 940.0 | eps=0.100 | buffer=68846
# [DQN] Episodio 445/10000 | Recompensa: 590.0 | eps=0.100 | buffer=68925
# [DQN] Episodio 446/10000 | Recompensa: 1300.0 | eps=0.100 | buffer=69209
# [DQN] Episodio 447/10000 | Recompensa: 910.0 | eps=0.100 | buffer=69410
# [DQN] Episodio 448/10000 | Recompensa: 1120.0 | eps=0.100 | buffer=69657
# [DQN] Episodio 449/10000 | Recompensa: 1500.0 | eps=0.100 | buffer=69957
# [DQN] Episodio 450/10000 | Recompensa: 350.0 | eps=0.100 | buffer=70045
# [DQN] Episodio 451/10000 | Recompensa: 1080.0 | eps=0.100 | buffer=70240
# [DQN] Episodio 452/10000 | Recompensa: 1150.0 | eps=0.100 | buffer=70462
# [DQN] Episodio 453/10000 | Recompensa: 800.0 | eps=0.100 | buffer=70704
# [DQN] Episodio 454/10000 | Recompensa: 880.0 | eps=0.100 | buffer=70888
# [DQN] Episodio 455/10000 | Recompensa: 780.0 | eps=0.100 | buffer=71056
# [DQN] Episodio 456/10000 | Recompensa: 770.0 | eps=0.100 | buffer=71207
# [DQN] Episodio 457/10000 | Recompensa: 510.0 | eps=0.100 | buffer=71304
# [DQN] Episodio 458/10000 | Recompensa: 550.0 | eps=0.100 | buffer=71428
# [DQN] Episodio 459/10000 | Recompensa: 1010.0 | eps=0.100 | buffer=71596
# [DQN] Episodio 460/10000 | Recompensa: 660.0 | eps=0.100 | buffer=71740
# [DQN] Episodio 461/10000 | Recompensa: 1080.0 | eps=0.100 | buffer=72087
# [DQN] Episodio 462/10000 | Recompensa: 880.0 | eps=0.100 | buffer=72292
# [DQN] Episodio 463/10000 | Recompensa: 690.0 | eps=0.100 | buffer=72415
# [DQN] Episodio 464/10000 | Recompensa: 930.0 | eps=0.100 | buffer=72571
# [DQN] Episodio 465/10000 | Recompensa: 650.0 | eps=0.100 | buffer=72734
# [DQN] Episodio 466/10000 | Recompensa: 840.0 | eps=0.100 | buffer=72938
# [DQN] Episodio 467/10000 | Recompensa: 1340.0 | eps=0.100 | buffer=73418
# [DQN] Episodio 468/10000 | Recompensa: 1390.0 | eps=0.100 | buffer=73707
# [DQN] Episodio 469/10000 | Recompensa: 1080.0 | eps=0.100 | buffer=73930
# [DQN] Episodio 470/10000 | Recompensa: 670.0 | eps=0.100 | buffer=74143
# [DQN] Episodio 471/10000 | Recompensa: 1190.0 | eps=0.100 | buffer=74428
# [DQN] Episodio 472/10000 | Recompensa: 930.0 | eps=0.100 | buffer=74580
# [DQN] Episodio 473/10000 | Recompensa: 330.0 | eps=0.100 | buffer=74680
# [DQN] Episodio 474/10000 | Recompensa: 1190.0 | eps=0.100 | buffer=74934
# [DQN] Episodio 475/10000 | Recompensa: 1150.0 | eps=0.100 | buffer=75194
# [DQN] Episodio 476/10000 | Recompensa: 1010.0 | eps=0.100 | buffer=75334
# [DQN] Episodio 477/10000 | Recompensa: 1540.0 | eps=0.100 | buffer=75535
# [DQN] Episodio 478/10000 | Recompensa: 1190.0 | eps=0.100 | buffer=75751
# [DQN] Episodio 479/10000 | Recompensa: 1360.0 | eps=0.100 | buffer=75959
# [DQN] Episodio 480/10000 | Recompensa: 1250.0 | eps=0.100 | buffer=76197
# [DQN] Episodio 481/10000 | Recompensa: 940.0 | eps=0.100 | buffer=76338
# [DQN] Episodio 482/10000 | Recompensa: 530.0 | eps=0.100 | buffer=76462
# [DQN] Episodio 483/10000 | Recompensa: 520.0 | eps=0.100 | buffer=76567
# [DQN] Episodio 484/10000 | Recompensa: 840.0 | eps=0.100 | buffer=76744
# [DQN] Episodio 485/10000 | Recompensa: 570.0 | eps=0.100 | buffer=76842
# [DQN] Episodio 486/10000 | Recompensa: 1930.0 | eps=0.100 | buffer=77067
# [DQN] Episodio 487/10000 | Recompensa: 970.0 | eps=0.100 | buffer=77252
# [DQN] Episodio 488/10000 | Recompensa: 1300.0 | eps=0.100 | buffer=77564
# [DQN] Episodio 489/10000 | Recompensa: 700.0 | eps=0.100 | buffer=77707
# [DQN] Episodio 490/10000 | Recompensa: 1600.0 | eps=0.100 | buffer=78074
# [DQN] Episodio 491/10000 | Recompensa: 720.0 | eps=0.100 | buffer=78167
# [DQN] Episodio 492/10000 | Recompensa: 740.0 | eps=0.100 | buffer=78316
# [DQN] Episodio 493/10000 | Recompensa: 1320.0 | eps=0.100 | buffer=78587
# [DQN] Episodio 494/10000 | Recompensa: 1050.0 | eps=0.100 | buffer=78803
# [DQN] Episodio 495/10000 | Recompensa: 1250.0 | eps=0.100 | buffer=79069
# [DQN] Episodio 496/10000 | Recompensa: 540.0 | eps=0.100 | buffer=79164
# [DQN] Episodio 497/10000 | Recompensa: 510.0 | eps=0.100 | buffer=79251
# [DQN] Episodio 498/10000 | Recompensa: 1170.0 | eps=0.100 | buffer=79492
# [DQN] Episodio 499/10000 | Recompensa: 700.0 | eps=0.100 | buffer=79623
# [DQN] Episodio 500/10000 | Recompensa: 600.0 | eps=0.100 | buffer=79730
# [DQN] Checkpoint guardado en: /content/drive/MyDrive/galaxian_rl/dqn/dqn_galaxian_ep500.pth
# [LOG] Guardadas gráfica y CSV en: /content/drive/MyDrive/galaxian_rl/dqn/rewards_ep500.png / /content/drive/MyDrive/galaxian_rl/dqn/rewards_log.csv
# [DQN] Episodio 501/10000 | Recompensa: 700.0 | eps=0.100 | buffer=79893
# [DQN] Episodio 502/10000 | Recompensa: 390.0 | eps=0.100 | buffer=79985
# [DQN] Episodio 503/10000 | Recompensa: 970.0 | eps=0.100 | buffer=80093
# [DQN] Episodio 504/10000 | Recompensa: 1510.0 | eps=0.100 | buffer=80414
# [DQN] Episodio 505/10000 | Recompensa: 1590.0 | eps=0.100 | buffer=80679
# [DQN] Episodio 506/10000 | Recompensa: 860.0 | eps=0.100 | buffer=80790
# [DQN] Episodio 507/10000 | Recompensa: 1430.0 | eps=0.100 | buffer=81074
# [DQN] Episodio 508/10000 | Recompensa: 300.0 | eps=0.100 | buffer=81161
# [DQN] Episodio 509/10000 | Recompensa: 830.0 | eps=0.100 | buffer=81275
# [DQN] Episodio 510/10000 | Recompensa: 480.0 | eps=0.100 | buffer=81388
# [DQN] Episodio 511/10000 | Recompensa: 1200.0 | eps=0.100 | buffer=81562
# [DQN] Episodio 512/10000 | Recompensa: 880.0 | eps=0.100 | buffer=81725
# [DQN] Episodio 513/10000 | Recompensa: 2340.0 | eps=0.100 | buffer=82147
# [DQN] Episodio 514/10000 | Recompensa: 890.0 | eps=0.100 | buffer=82251
# [DQN] Episodio 515/10000 | Recompensa: 960.0 | eps=0.100 | buffer=82414
# [DQN] Episodio 516/10000 | Recompensa: 510.0 | eps=0.100 | buffer=82482
# [DQN] Episodio 517/10000 | Recompensa: 510.0 | eps=0.100 | buffer=82622
# [DQN] Episodio 518/10000 | Recompensa: 1210.0 | eps=0.100 | buffer=82859
# [DQN] Episodio 519/10000 | Recompensa: 860.0 | eps=0.100 | buffer=83042
# [DQN] Episodio 520/10000 | Recompensa: 1190.0 | eps=0.100 | buffer=83312
# [DQN] Episodio 521/10000 | Recompensa: 510.0 | eps=0.100 | buffer=83437
# [DQN] Episodio 522/10000 | Recompensa: 360.0 | eps=0.100 | buffer=83522
# [DQN] Episodio 523/10000 | Recompensa: 900.0 | eps=0.100 | buffer=83689
# [DQN] Episodio 524/10000 | Recompensa: 900.0 | eps=0.100 | buffer=83847
# [DQN] Episodio 525/10000 | Recompensa: 870.0 | eps=0.100 | buffer=83999
# [DQN] Episodio 526/10000 | Recompensa: 670.0 | eps=0.100 | buffer=84085
# [DQN] Episodio 527/10000 | Recompensa: 1070.0 | eps=0.100 | buffer=84346
# [DQN] Episodio 528/10000 | Recompensa: 1160.0 | eps=0.100 | buffer=84549
# [DQN] Episodio 529/10000 | Recompensa: 720.0 | eps=0.100 | buffer=84682
# [DQN] Episodio 530/10000 | Recompensa: 1080.0 | eps=0.100 | buffer=84883
# [DQN] Episodio 531/10000 | Recompensa: 650.0 | eps=0.100 | buffer=85035
# [DQN] Episodio 532/10000 | Recompensa: 370.0 | eps=0.100 | buffer=85137
# [DQN] Episodio 533/10000 | Recompensa: 1410.0 | eps=0.100 | buffer=85412
# [DQN] Episodio 534/10000 | Recompensa: 1120.0 | eps=0.100 | buffer=85733
# [DQN] Episodio 535/10000 | Recompensa: 450.0 | eps=0.100 | buffer=85822
# [DQN] Episodio 536/10000 | Recompensa: 1340.0 | eps=0.100 | buffer=86098
# [DQN] Episodio 537/10000 | Recompensa: 910.0 | eps=0.100 | buffer=86329
# [DQN] Episodio 538/10000 | Recompensa: 1900.0 | eps=0.100 | buffer=87203
# [DQN] Episodio 539/10000 | Recompensa: 1320.0 | eps=0.100 | buffer=87501
# [DQN] Episodio 540/10000 | Recompensa: 1380.0 | eps=0.100 | buffer=87797
# [DQN] Episodio 541/10000 | Recompensa: 1570.0 | eps=0.100 | buffer=88064
# [DQN] Episodio 542/10000 | Recompensa: 570.0 | eps=0.100 | buffer=88146
# [DQN] Episodio 543/10000 | Recompensa: 550.0 | eps=0.100 | buffer=88251
# [DQN] Episodio 544/10000 | Recompensa: 660.0 | eps=0.100 | buffer=88500
# [DQN] Episodio 545/10000 | Recompensa: 940.0 | eps=0.100 | buffer=88632
# [DQN] Episodio 546/10000 | Recompensa: 420.0 | eps=0.100 | buffer=88787
# [DQN] Episodio 547/10000 | Recompensa: 890.0 | eps=0.100 | buffer=88927
# [DQN] Episodio 548/10000 | Recompensa: 450.0 | eps=0.100 | buffer=89031
# [DQN] Episodio 549/10000 | Recompensa: 980.0 | eps=0.100 | buffer=89291
# [DQN] Episodio 550/10000 | Recompensa: 1270.0 | eps=0.100 | buffer=89508
# [DQN] Episodio 551/10000 | Recompensa: 970.0 | eps=0.100 | buffer=89716
# [DQN] Episodio 552/10000 | Recompensa: 1520.0 | eps=0.100 | buffer=90110
# [DQN] Episodio 553/10000 | Recompensa: 1110.0 | eps=0.100 | buffer=90435
# [DQN] Episodio 554/10000 | Recompensa: 750.0 | eps=0.100 | buffer=90571
# [DQN] Episodio 555/10000 | Recompensa: 240.0 | eps=0.100 | buffer=90643
# [DQN] Episodio 556/10000 | Recompensa: 2050.0 | eps=0.100 | buffer=91165
# [DQN] Episodio 557/10000 | Recompensa: 880.0 | eps=0.100 | buffer=91397
# [DQN] Episodio 558/10000 | Recompensa: 420.0 | eps=0.100 | buffer=91511
# [DQN] Episodio 559/10000 | Recompensa: 1340.0 | eps=0.100 | buffer=91790
# [DQN] Episodio 560/10000 | Recompensa: 690.0 | eps=0.100 | buffer=91968
# [DQN] Episodio 561/10000 | Recompensa: 860.0 | eps=0.100 | buffer=92124
# [DQN] Episodio 562/10000 | Recompensa: 1440.0 | eps=0.100 | buffer=92368
# [DQN] Episodio 563/10000 | Recompensa: 520.0 | eps=0.100 | buffer=92482
# [DQN] Episodio 564/10000 | Recompensa: 540.0 | eps=0.100 | buffer=92592
# [DQN] Episodio 565/10000 | Recompensa: 1070.0 | eps=0.100 | buffer=92804
# [DQN] Episodio 566/10000 | Recompensa: 210.0 | eps=0.100 | buffer=92874
# [DQN] Episodio 567/10000 | Recompensa: 590.0 | eps=0.100 | buffer=93005
# [DQN] Episodio 568/10000 | Recompensa: 770.0 | eps=0.100 | buffer=93155
# [DQN] Episodio 569/10000 | Recompensa: 1070.0 | eps=0.100 | buffer=93433
# [DQN] Episodio 570/10000 | Recompensa: 480.0 | eps=0.100 | buffer=93541
# [DQN] Episodio 571/10000 | Recompensa: 640.0 | eps=0.100 | buffer=93669
# [DQN] Episodio 572/10000 | Recompensa: 860.0 | eps=0.100 | buffer=93808
# [DQN] Episodio 573/10000 | Recompensa: 1510.0 | eps=0.100 | buffer=94098
# [DQN] Episodio 574/10000 | Recompensa: 780.0 | eps=0.100 | buffer=94235
# [DQN] Episodio 575/10000 | Recompensa: 330.0 | eps=0.100 | buffer=94302
# [DQN] Episodio 576/10000 | Recompensa: 510.0 | eps=0.100 | buffer=94441
# [DQN] Episodio 577/10000 | Recompensa: 1400.0 | eps=0.100 | buffer=94739
# [DQN] Episodio 578/10000 | Recompensa: 300.0 | eps=0.100 | buffer=94833
# [DQN] Episodio 579/10000 | Recompensa: 710.0 | eps=0.100 | buffer=94999
# [DQN] Episodio 580/10000 | Recompensa: 1260.0 | eps=0.100 | buffer=95213
# [DQN] Episodio 581/10000 | Recompensa: 680.0 | eps=0.100 | buffer=95331
# [DQN] Episodio 582/10000 | Recompensa: 1160.0 | eps=0.100 | buffer=95561
# [DQN] Episodio 583/10000 | Recompensa: 850.0 | eps=0.100 | buffer=95723
# [DQN] Episodio 584/10000 | Recompensa: 1220.0 | eps=0.100 | buffer=95910
# [DQN] Episodio 585/10000 | Recompensa: 340.0 | eps=0.100 | buffer=95993
# [DQN] Episodio 586/10000 | Recompensa: 750.0 | eps=0.100 | buffer=96129
# [DQN] Episodio 587/10000 | Recompensa: 1970.0 | eps=0.100 | buffer=96550
# [DQN] Episodio 588/10000 | Recompensa: 1080.0 | eps=0.100 | buffer=96739
# [DQN] Episodio 589/10000 | Recompensa: 2120.0 | eps=0.100 | buffer=97931
# [DQN] Episodio 590/10000 | Recompensa: 2740.0 | eps=0.100 | buffer=98439
# [DQN] Episodio 591/10000 | Recompensa: 700.0 | eps=0.100 | buffer=98591
# [DQN] Episodio 592/10000 | Recompensa: 1060.0 | eps=0.100 | buffer=98898
# [DQN] Episodio 593/10000 | Recompensa: 990.0 | eps=0.100 | buffer=99138
# [DQN] Episodio 594/10000 | Recompensa: 820.0 | eps=0.100 | buffer=99370
# [DQN] Episodio 595/10000 | Recompensa: 800.0 | eps=0.100 | buffer=99501
# [DQN] Episodio 596/10000 | Recompensa: 680.0 | eps=0.100 | buffer=99615
# [DQN] Episodio 597/10000 | Recompensa: 930.0 | eps=0.100 | buffer=99812
# [DQN] Episodio 598/10000 | Recompensa: 870.0 | eps=0.100 | buffer=99970
# [DQN] Episodio 599/10000 | Recompensa: 1160.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 600/10000 | Recompensa: 1760.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 601/10000 | Recompensa: 700.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 602/10000 | Recompensa: 900.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 603/10000 | Recompensa: 320.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 604/10000 | Recompensa: 1510.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 605/10000 | Recompensa: 1820.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 606/10000 | Recompensa: 1500.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 607/10000 | Recompensa: 180.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 608/10000 | Recompensa: 900.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 609/10000 | Recompensa: 640.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 610/10000 | Recompensa: 850.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 611/10000 | Recompensa: 910.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 612/10000 | Recompensa: 1260.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 613/10000 | Recompensa: 1240.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 614/10000 | Recompensa: 260.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 615/10000 | Recompensa: 920.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 616/10000 | Recompensa: 750.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 617/10000 | Recompensa: 860.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 618/10000 | Recompensa: 960.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 619/10000 | Recompensa: 1440.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 620/10000 | Recompensa: 1170.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 621/10000 | Recompensa: 800.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 622/10000 | Recompensa: 670.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 623/10000 | Recompensa: 1070.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 624/10000 | Recompensa: 860.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 625/10000 | Recompensa: 1090.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 626/10000 | Recompensa: 1240.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 627/10000 | Recompensa: 890.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 628/10000 | Recompensa: 370.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 629/10000 | Recompensa: 370.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 630/10000 | Recompensa: 450.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 631/10000 | Recompensa: 1860.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 632/10000 | Recompensa: 1100.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 633/10000 | Recompensa: 910.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 634/10000 | Recompensa: 830.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 635/10000 | Recompensa: 1380.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 636/10000 | Recompensa: 1070.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 637/10000 | Recompensa: 680.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 638/10000 | Recompensa: 880.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 639/10000 | Recompensa: 1160.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 640/10000 | Recompensa: 1600.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 641/10000 | Recompensa: 980.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 642/10000 | Recompensa: 960.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 643/10000 | Recompensa: 1200.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 644/10000 | Recompensa: 1160.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 645/10000 | Recompensa: 930.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 646/10000 | Recompensa: 920.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 647/10000 | Recompensa: 660.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 648/10000 | Recompensa: 1530.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 649/10000 | Recompensa: 660.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 650/10000 | Recompensa: 1410.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 651/10000 | Recompensa: 560.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 652/10000 | Recompensa: 1150.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 653/10000 | Recompensa: 700.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 654/10000 | Recompensa: 1390.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 655/10000 | Recompensa: 470.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 656/10000 | Recompensa: 950.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 657/10000 | Recompensa: 990.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 658/10000 | Recompensa: 720.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 659/10000 | Recompensa: 830.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 660/10000 | Recompensa: 360.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 661/10000 | Recompensa: 800.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 662/10000 | Recompensa: 920.0 | eps=0.100 | buffer=100000
# ...
# [DQN] Episodio 3022/10000 | Recompensa: 4330.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3023/10000 | Recompensa: 2890.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3024/10000 | Recompensa: 1280.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3025/10000 | Recompensa: 1690.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3026/10000 | Recompensa: 3600.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3027/10000 | Recompensa: 2480.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3028/10000 | Recompensa: 2650.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3029/10000 | Recompensa: 2190.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3030/10000 | Recompensa: 3620.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3031/10000 | Recompensa: 3070.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3032/10000 | Recompensa: 1150.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3033/10000 | Recompensa: 2960.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3034/10000 | Recompensa: 1710.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3035/10000 | Recompensa: 3300.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3036/10000 | Recompensa: 2710.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3037/10000 | Recompensa: 2880.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3038/10000 | Recompensa: 5900.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3039/10000 | Recompensa: 4120.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3040/10000 | Recompensa: 1890.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3041/10000 | Recompensa: 2750.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3042/10000 | Recompensa: 1950.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3043/10000 | Recompensa: 2910.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3044/10000 | Recompensa: 4990.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3045/10000 | Recompensa: 2460.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3046/10000 | Recompensa: 2580.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3047/10000 | Recompensa: 4400.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3048/10000 | Recompensa: 4690.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3049/10000 | Recompensa: 3520.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3050/10000 | Recompensa: 2510.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3051/10000 | Recompensa: 4210.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3052/10000 | Recompensa: 1190.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3053/10000 | Recompensa: 3090.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3054/10000 | Recompensa: 2230.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3055/10000 | Recompensa: 5010.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3056/10000 | Recompensa: 1650.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3057/10000 | Recompensa: 980.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3058/10000 | Recompensa: 2860.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3059/10000 | Recompensa: 2420.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3060/10000 | Recompensa: 3050.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3061/10000 | Recompensa: 2850.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3062/10000 | Recompensa: 4300.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3063/10000 | Recompensa: 1110.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3064/10000 | Recompensa: 1600.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3065/10000 | Recompensa: 3510.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3066/10000 | Recompensa: 1810.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3067/10000 | Recompensa: 1470.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3068/10000 | Recompensa: 2700.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3069/10000 | Recompensa: 1230.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3070/10000 | Recompensa: 1670.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3071/10000 | Recompensa: 1450.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3072/10000 | Recompensa: 3630.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3073/10000 | Recompensa: 4590.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3074/10000 | Recompensa: 3900.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3075/10000 | Recompensa: 2860.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3076/10000 | Recompensa: 4440.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3077/10000 | Recompensa: 2060.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3078/10000 | Recompensa: 3730.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3079/10000 | Recompensa: 1290.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3080/10000 | Recompensa: 4710.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3081/10000 | Recompensa: 2930.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3082/10000 | Recompensa: 2190.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3083/10000 | Recompensa: 5750.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3084/10000 | Recompensa: 1250.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3085/10000 | Recompensa: 3510.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3086/10000 | Recompensa: 2880.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3087/10000 | Recompensa: 1240.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3088/10000 | Recompensa: 4900.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3089/10000 | Recompensa: 4430.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3090/10000 | Recompensa: 3300.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3091/10000 | Recompensa: 1790.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3092/10000 | Recompensa: 3600.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3093/10000 | Recompensa: 1350.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3094/10000 | Recompensa: 4580.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3095/10000 | Recompensa: 5120.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3096/10000 | Recompensa: 4250.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3097/10000 | Recompensa: 3720.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3098/10000 | Recompensa: 1670.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3099/10000 | Recompensa: 1370.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3100/10000 | Recompensa: 2010.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3101/10000 | Recompensa: 1910.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3102/10000 | Recompensa: 3080.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3103/10000 | Recompensa: 4320.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3104/10000 | Recompensa: 4270.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3105/10000 | Recompensa: 4280.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3106/10000 | Recompensa: 1500.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3107/10000 | Recompensa: 3640.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3108/10000 | Recompensa: 1530.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3109/10000 | Recompensa: 3450.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3110/10000 | Recompensa: 3260.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3111/10000 | Recompensa: 4290.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3112/10000 | Recompensa: 3590.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3113/10000 | Recompensa: 3360.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3114/10000 | Recompensa: 5440.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3115/10000 | Recompensa: 3150.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3116/10000 | Recompensa: 2430.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3117/10000 | Recompensa: 2350.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3118/10000 | Recompensa: 4410.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3119/10000 | Recompensa: 2580.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3120/10000 | Recompensa: 1840.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3121/10000 | Recompensa: 2150.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3122/10000 | Recompensa: 4440.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3123/10000 | Recompensa: 1610.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3124/10000 | Recompensa: 3330.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3125/10000 | Recompensa: 3270.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3126/10000 | Recompensa: 4460.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3127/10000 | Recompensa: 870.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3128/10000 | Recompensa: 3140.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3129/10000 | Recompensa: 6660.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3130/10000 | Recompensa: 4300.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3131/10000 | Recompensa: 6720.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3132/10000 | Recompensa: 1580.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3133/10000 | Recompensa: 5490.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3134/10000 | Recompensa: 3560.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3135/10000 | Recompensa: 2490.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3136/10000 | Recompensa: 3540.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3137/10000 | Recompensa: 4600.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3138/10000 | Recompensa: 2780.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3139/10000 | Recompensa: 3590.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3140/10000 | Recompensa: 3460.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3141/10000 | Recompensa: 2520.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3142/10000 | Recompensa: 3130.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3143/10000 | Recompensa: 4890.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3144/10000 | Recompensa: 3520.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3145/10000 | Recompensa: 3280.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3146/10000 | Recompensa: 4640.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3147/10000 | Recompensa: 1460.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3148/10000 | Recompensa: 1680.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3149/10000 | Recompensa: 2940.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3150/10000 | Recompensa: 1310.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3151/10000 | Recompensa: 1440.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3152/10000 | Recompensa: 3220.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3153/10000 | Recompensa: 4170.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3154/10000 | Recompensa: 570.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3155/10000 | Recompensa: 3950.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3156/10000 | Recompensa: 3370.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3157/10000 | Recompensa: 1750.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3158/10000 | Recompensa: 1090.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3159/10000 | Recompensa: 3550.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3160/10000 | Recompensa: 2440.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3161/10000 | Recompensa: 2290.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3162/10000 | Recompensa: 2590.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3163/10000 | Recompensa: 1490.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3164/10000 | Recompensa: 3170.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3165/10000 | Recompensa: 3630.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3166/10000 | Recompensa: 1960.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3167/10000 | Recompensa: 2710.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3168/10000 | Recompensa: 3120.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3169/10000 | Recompensa: 2720.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3170/10000 | Recompensa: 1350.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3171/10000 | Recompensa: 1400.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3172/10000 | Recompensa: 3420.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3173/10000 | Recompensa: 1590.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3174/10000 | Recompensa: 2150.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3175/10000 | Recompensa: 5010.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3176/10000 | Recompensa: 2690.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3177/10000 | Recompensa: 3370.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3178/10000 | Recompensa: 5290.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3179/10000 | Recompensa: 5330.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3180/10000 | Recompensa: 1230.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3181/10000 | Recompensa: 5700.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3182/10000 | Recompensa: 1500.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3183/10000 | Recompensa: 5040.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3184/10000 | Recompensa: 4090.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3185/10000 | Recompensa: 2980.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3186/10000 | Recompensa: 2090.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3187/10000 | Recompensa: 2930.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3188/10000 | Recompensa: 1700.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3189/10000 | Recompensa: 2950.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3190/10000 | Recompensa: 1200.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3191/10000 | Recompensa: 2760.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3192/10000 | Recompensa: 2260.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3193/10000 | Recompensa: 1420.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3194/10000 | Recompensa: 3790.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3195/10000 | Recompensa: 3400.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3196/10000 | Recompensa: 4280.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3197/10000 | Recompensa: 1720.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3198/10000 | Recompensa: 5160.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3199/10000 | Recompensa: 2600.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3200/10000 | Recompensa: 2720.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3201/10000 | Recompensa: 1750.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3202/10000 | Recompensa: 2210.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3203/10000 | Recompensa: 2810.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3204/10000 | Recompensa: 2080.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3205/10000 | Recompensa: 1540.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3206/10000 | Recompensa: 1870.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3207/10000 | Recompensa: 1550.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3208/10000 | Recompensa: 2910.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3209/10000 | Recompensa: 3010.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3210/10000 | Recompensa: 2690.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3211/10000 | Recompensa: 1930.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3212/10000 | Recompensa: 3220.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3213/10000 | Recompensa: 1410.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3214/10000 | Recompensa: 2590.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3215/10000 | Recompensa: 3390.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3216/10000 | Recompensa: 3120.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3217/10000 | Recompensa: 1760.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3218/10000 | Recompensa: 1610.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3219/10000 | Recompensa: 2480.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3220/10000 | Recompensa: 6520.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3221/10000 | Recompensa: 2390.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3222/10000 | Recompensa: 2080.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3223/10000 | Recompensa: 2960.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3224/10000 | Recompensa: 2770.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3225/10000 | Recompensa: 2330.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3226/10000 | Recompensa: 4100.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3227/10000 | Recompensa: 2490.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3228/10000 | Recompensa: 2000.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3229/10000 | Recompensa: 1530.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3230/10000 | Recompensa: 2040.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3231/10000 | Recompensa: 1520.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3232/10000 | Recompensa: 2000.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3233/10000 | Recompensa: 2460.0 | eps=0.100 | buffer=100000
# [DQN] Episodio 3234/10000 | Recompensa: 4110.0 | eps=0.100 | buffer=100000

# %%
# a2c_galaxian.py
# ------------------------------------------------------------
# A2C desde cero para ALE/Galaxian-v5 (Gymnasium + ALE-Py)
# Compatible con wrappers personalizados (env_utils.make_galaxian_env)
# - Observación por defecto: (4, 84, 84) (canal-primero)
# - Robusto si llega en (84, 84, 4) (canal-último): auto-detecta y permuta
# - Checkpoints periódicos en 'checkpoint_dir' (útil para Google Drive en Colab)
# ------------------------------------------------------------

import os
from typing import Tuple, List

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# ============================================================
# Red Actor-Crítico (backbone conv compartido)
# ============================================================
class A2CNet(nn.Module):
    """
    Red Actor-Crítico con backbone convolucional estilo Nature.
    Espera tensores en float normalizados [0,1] con formato (B, C, H, W).
    Si recibe (B, H, W, C), permuta automáticamente a (B, C, H, W).
    """
    def __init__(self, input_shape: Tuple[int, int, int], n_actions: int):
        super().__init__()
        c, h, w = input_shape
        self.expected_c = c  # para validar/ajustar layout en forward

        self.features = nn.Sequential(
            nn.Conv2d(c, 32, kernel_size=8, stride=4),  # -> (B,32,20,20) aprox con 84x84
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 64, kernel_size=4, stride=2), # -> (B,64,9,9)
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, stride=1), # -> (B,64,7,7)
            nn.ReLU(inplace=True),
            nn.Flatten()
        )

        with torch.no_grad():
            dummy = torch.zeros(1, c, h, w)
            n_flat = self.features(dummy).shape[1]

        self.actor = nn.Sequential(
            nn.Linear(n_flat, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, n_actions)
        )
        self.critic = nn.Sequential(
            nn.Linear(n_flat, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, 1)
        )

    def forward(self, x: torch.Tensor):
        """
        x: (B,C,H,W) uint8/float o (B,H,W,C) uint8/float
        Retorna:
          - logits de la política: (B, n_actions)
          - valores V(s): (B,)
        """
        if x.ndim != 4:
            raise ValueError(f"Se esperaba un tensor 4D, recibido x.ndim={x.ndim}")

        # Si viene en canal-último (B,H,W,C), permutamos a (B,C,H,W)
        if x.shape[1] != self.expected_c and x.shape[-1] == self.expected_c:
            x = x.permute(0, 3, 1, 2)

        x = x.float() / 255.0
        feat = self.features(x)
        logits = self.actor(feat)
        values = self.critic(feat).squeeze(-1)
        return logits, values


# ============================================================
# Política para play.py (interfaz: __call__(obs, info) -> action)
# ============================================================
class A2CPolicy:
    def __init__(self, net: 'A2CNet'):
        self.net = net.to(device)
        self.net.eval()

    @torch.no_grad()
    def __call__(self, obs: np.ndarray, info: dict) -> int:
        """
        obs: (C,H,W) uint8 o (H,W,C) uint8
        Estrategia greedy (argmax) para evaluación/competencia.
        """
        if obs.ndim != 3:
            raise ValueError(f"Se esperaba obs 3D, recibido obs.ndim={obs.ndim}")

        obs_batch = np.expand_dims(obs, axis=0)  # (1, C,H,W) o (1, H,W,C)
        obs_t = torch.from_numpy(obs_batch).to(device)
        logits, _ = self.net(obs_t)
        probs = torch.softmax(logits, dim=-1)
        action = torch.argmax(probs, dim=-1).item()
        return int(action)


# ============================================================
# Entrenamiento A2C
# ============================================================
def train_a2c(
    checkpoint_dir: str,
    total_episodes: int = 500,
    gamma: float = 0.99,
    lr: float = 2.5e-4,
    entropy_coef: float = 0.01,
    value_coef: float = 0.5,
    rollout_length: int = 5,
    save_interval: int = 50,
    max_steps_per_episode: int | None = None,
    seed: int = 123,
    gae_lambda: float = 0.95,
):
    """
    Entrena un A2C minimalista para Galaxian con rollouts cortos (n-steps) y GAE(λ).
    Guarda checkpoints periódicos en `checkpoint_dir` (ideal Drive en Colab).
    Retorna la red A2C entrenada.
    """
    os.makedirs(checkpoint_dir, exist_ok=True)

    env = make_galaxian_env(seed=seed, render_mode=None)

    # Detectar layout y shape de entrada
    obs, _ = env.reset()
    if obs.ndim != 3:
        env.close()
        raise ValueError(f"Observación inesperada: ndim={obs.ndim}, se esperaba 3")

    if obs.shape[0] in (1, 3, 4):  # canal-primero típico de CustomFrameStack
        input_shape = (obs.shape[0], obs.shape[1], obs.shape[2])
    else:                           # canal-último
        input_shape = (obs.shape[2], obs.shape[0], obs.shape[1])

    n_actions = env.action_space.n

    net = A2CNet(input_shape, n_actions).to(device)
    optimizer = optim.RMSprop(net.parameters(), lr=lr, eps=1e-5)

    episode_idx = 0
    rewards_log: List[float] = []

    while episode_idx < total_episodes:
        obs, _ = env.reset()
        done = False
        ep_reward = 0.0
        steps_in_ep = 0

        while not done:
            # Trajectoria corta (rollout)
            log_probs = []
            values = []
            rewards = []
            dones = []
            entropies = []

            for _ in range(rollout_length):
                if done:
                    break

                ob = np.expand_dims(obs, axis=0)             # (1, C,H,W) o (1, H,W,C)
                ob_t = torch.from_numpy(ob).to(device)

                logits, value = net(ob_t)
                probs = torch.softmax(logits, dim=-1)
                dist = torch.distributions.Categorical(probs)

                action = dist.sample()
                entropy = dist.entropy().mean()

                next_obs, reward, terminated, truncated, _ = env.step(action.item())
                done = terminated or truncated

                log_probs.append(dist.log_prob(action).squeeze(0))
                values.append(value.squeeze(0))
                rewards.append(torch.tensor(reward, dtype=torch.float32, device=device))
                dones.append(torch.tensor(float(done), device=device))
                entropies.append(entropy)

                obs = next_obs
                ep_reward += float(reward)
                steps_in_ep += 1

                if max_steps_per_episode is not None and steps_in_ep >= max_steps_per_episode:
                    done = True
                    break

            # Bootstrap del valor para el último estado
            if done:
                next_value = torch.zeros(1, device=device)
            else:
                nb = np.expand_dims(obs, axis=0)
                nb_t = torch.from_numpy(nb).to(device)
                _, nv = net(nb_t)
                next_value = nv.detach()

            # GAE(λ) + retornos
            returns = []
            gae = 0
            # Usamos next_value como V(s_{t+T})
            v_next = next_value
            for r, d, v in zip(reversed(rewards), reversed(dones), reversed(values)):
                v_next = v_next * (1.0 - d)  # si done==1, no bootstrap
                delta = r + gamma * v_next - v
                gae = delta + gamma * gae_lambda * (1.0 - d) * gae
                v_next = v
                returns.insert(0, gae + v)

            returns = torch.stack(returns)
            values_t = torch.stack(values)
            log_probs_t = torch.stack(log_probs)
            entropies_t = torch.stack(entropies) if len(entropies) > 0 else torch.tensor(0.0, device=device)

            advantage = returns - values_t

            policy_loss = -(log_probs_t * advantage.detach()).mean()
            value_loss = advantage.pow(2).mean()
            entropy_loss = entropies_t.mean() if entropies_t.ndim > 0 else entropies_t

            loss = policy_loss + value_coef * value_loss - entropy_coef * entropy_loss

            optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(net.parameters(), 0.5)
            optimizer.step()

            if done:
                break  # salir al cierre del episodio

        episode_idx += 1
        rewards_log.append(ep_reward)
        print(f"[A2C] Episodio {episode_idx}/{total_episodes} | Recompensa: {ep_reward:.1f}")

        # Guardar checkpoint cada N episodios
        if episode_idx % save_interval == 0:
            ckpt_path = os.path.join(checkpoint_dir, f"a2c_galaxian_ep{episode_idx}.pth")
            torch.save({
                "net": net.state_dict(),
                "optimizer": optimizer.state_dict(),
                "episode": episode_idx,
                "rewards": rewards_log,
                "input_shape": input_shape,
                "n_actions": n_actions,
            }, ckpt_path)
            print(f"[A2C] Checkpoint guardado en: {ckpt_path}")

    env.close()

    # Guardar pesos finales para inferencia
    final_path = os.path.join(checkpoint_dir, "a2c_galaxian_final.pth")
    torch.save(net.state_dict(), final_path)
    print(f"[A2C] Modelo final guardado en: {final_path}")

    return net

# %%
a2c_dir = f"{BASE_DIR}/a2c"
a2c_net = train_a2c(checkpoint_dir=a2c_dir, total_episodes=50)
# Out:
# [A2C] Episodio 1/50 | Recompensa: 490.0
# [A2C] Episodio 2/50 | Recompensa: 800.0
# [A2C] Episodio 3/50 | Recompensa: 400.0
# [A2C] Episodio 4/50 | Recompensa: 390.0
# [A2C] Episodio 5/50 | Recompensa: 600.0
# [A2C] Episodio 6/50 | Recompensa: 540.0
# [A2C] Episodio 7/50 | Recompensa: 450.0
# [A2C] Episodio 8/50 | Recompensa: 500.0
# [A2C] Episodio 9/50 | Recompensa: 980.0
# [A2C] Episodio 10/50 | Recompensa: 590.0
# [A2C] Episodio 11/50 | Recompensa: 810.0
# [A2C] Episodio 12/50 | Recompensa: 530.0
# [A2C] Episodio 13/50 | Recompensa: 1020.0
# [A2C] Episodio 14/50 | Recompensa: 890.0
# [A2C] Episodio 15/50 | Recompensa: 660.0
# [A2C] Episodio 16/50 | Recompensa: 420.0
# [A2C] Episodio 17/50 | Recompensa: 240.0
# [A2C] Episodio 18/50 | Recompensa: 710.0
# [A2C] Episodio 19/50 | Recompensa: 1170.0
# [A2C] Episodio 20/50 | Recompensa: 870.0
# [A2C] Episodio 21/50 | Recompensa: 650.0
# [A2C] Episodio 22/50 | Recompensa: 600.0
# [A2C] Episodio 23/50 | Recompensa: 560.0
# [A2C] Episodio 24/50 | Recompensa: 570.0
# [A2C] Episodio 25/50 | Recompensa: 460.0
# [A2C] Episodio 26/50 | Recompensa: 350.0
# [A2C] Episodio 27/50 | Recompensa: 660.0
# [A2C] Episodio 28/50 | Recompensa: 780.0
# [A2C] Episodio 29/50 | Recompensa: 1130.0
# [A2C] Episodio 30/50 | Recompensa: 1350.0
# [A2C] Episodio 31/50 | Recompensa: 590.0
# [A2C] Episodio 32/50 | Recompensa: 900.0
# [A2C] Episodio 33/50 | Recompensa: 890.0
# [A2C] Episodio 34/50 | Recompensa: 1060.0
# [A2C] Episodio 35/50 | Recompensa: 960.0
# [A2C] Episodio 36/50 | Recompensa: 730.0
# [A2C] Episodio 37/50 | Recompensa: 1000.0
# [A2C] Episodio 38/50 | Recompensa: 640.0
# [A2C] Episodio 39/50 | Recompensa: 610.0
# [A2C] Episodio 40/50 | Recompensa: 390.0
# [A2C] Episodio 41/50 | Recompensa: 910.0
# [A2C] Episodio 42/50 | Recompensa: 810.0
# [A2C] Episodio 43/50 | Recompensa: 820.0
# [A2C] Episodio 44/50 | Recompensa: 1200.0
# [A2C] Episodio 45/50 | Recompensa: 980.0
# [A2C] Episodio 46/50 | Recompensa: 660.0
# [A2C] Episodio 47/50 | Recompensa: 870.0
# [A2C] Episodio 48/50 | Recompensa: 360.0
# [A2C] Episodio 49/50 | Recompensa: 650.0
# [A2C] Episodio 50/50 | Recompensa: 590.0
# [A2C] Checkpoint guardado en: /content/drive/MyDrive/galaxian_rl/a2c/a2c_galaxian_ep50.pth
# [A2C] Modelo final guardado en: /content/drive/MyDrive/galaxian_rl/a2c/a2c_galaxian_final.pth

# %%
# dqn_dueling_per.py
# ------------------------------------------------------------
# Dueling Double DQN con Prioritized Experience Replay (PER)
# - Compatible con env_utils.make_galaxian_env (custom wrappers)
# - Robusto a (C,H,W) o (H,W,C)
# - Checkpoints periódicos en Google Drive
# - Gráficas de recompensa y media móvil (PNG) + log CSV
# ------------------------------------------------------------

import os
import csv
import math
import random
from typing import Tuple, List

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib
matplotlib.use("Agg")  # backend sin pantalla para guardar PNG
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# ===========================
#  Segment Trees para PER
# ===========================
class SegmentTree:
    def __init__(self, capacity, fn):
        assert capacity > 0 and (capacity & (capacity - 1)) == 0, \
            "capacity debe ser potencia de 2"
        self.capacity = capacity
        self.tree = np.zeros(2 * capacity, dtype=np.float32)
        self.fn = fn

    def update(self, idx, value):
        i = idx + self.capacity
        self.tree[i] = value
        i //= 2
        while i >= 1:
            self.tree[i] = self.fn(self.tree[2 * i], self.tree[2 * i + 1])
            i //= 2

    def reduce(self, start, end):
        res_left = None
        res_right = None
        start += self.capacity
        end += self.capacity
        while start <= end:
            if (start % 2) == 1:
                res_left = self.tree[start] if res_left is None else self.fn(res_left, self.tree[start])
                start += 1
            if (end % 2) == 0:
                res_right = self.tree[end] if res_right is None else self.fn(self.tree[end], res_right)
                end -= 1
            start //= 2
            end //= 2
        if res_left is None:
            return res_right
        if res_right is None:
            return res_left
        return self.fn(res_left, res_right)

    def __getitem__(self, idx):
        return self.tree[idx + self.capacity]


class SumSegmentTree(SegmentTree):
    def __init__(self, capacity):
        super().__init__(capacity, fn=lambda a, b: a + b)

    def sum(self):
        return self.tree[1]

    def find_prefixsum_idx(self, prefixsum):
        """Devuelve el índice i tal que sum(0..i) >= prefixsum."""
        idx = 1
        while idx < self.capacity:
            left = 2 * idx
            if self.tree[left] >= prefixsum:
                idx = left
            else:
                prefixsum -= self.tree[left]
                idx = left + 1
        return idx - self.capacity


class MinSegmentTree(SegmentTree):
    def __init__(self, capacity):
        super().__init__(capacity, fn=min)

    def min(self):
        return self.tree[1]


# =======================================
#  Prioritized Replay Buffer (proportional)
# =======================================
class PrioritizedReplayBuffer:
    def __init__(self, capacity: int, alpha: float = 0.6, eps: float = 1e-6):
        # capacity → potencia de 2 para segment tree
        pow2 = 1
        while pow2 < capacity:
            pow2 *= 2
        self.capacity = pow2
        self.alpha = alpha
        self.eps = eps

        self.pos = 0
        self.size = 0

        self.states = [None] * self.capacity
        self.actions = np.zeros(self.capacity, dtype=np.int64)
        self.rewards = np.zeros(self.capacity, dtype=np.float32)
        self.next_states = [None] * self.capacity
        self.dones = np.zeros(self.capacity, dtype=np.bool_)

        self.sum_tree = SumSegmentTree(self.capacity)
        self.min_tree = MinSegmentTree(self.capacity)
        self.max_priority = 1.0

        # Inicializa árboles con prioridad mínima
        for i in range(self.capacity):
            self.sum_tree.update(i, 0.0)
            self.min_tree.update(i, float("inf"))

    def __len__(self):
        return self.size

    def add(self, s, a, r, ns, d):
        idx = self.pos
        self.states[idx] = s
        self.actions[idx] = a
        self.rewards[idx] = r
        self.next_states[idx] = ns
        self.dones[idx] = d

        p = (self.max_priority + self.eps) ** self.alpha
        self.sum_tree.update(idx, p)
        self.min_tree.update(idx, p)

        self.pos = (self.pos + 1) % self.capacity
        self.size = min(self.size + 1, self.capacity)

    def sample(self, batch_size: int, beta: float = 0.4):
        """Devuelve (indices, w, batch) con pesos de importancia."""
        out_idx = []
        out_s = []
        out_a = np.empty(batch_size, dtype=np.int64)
        out_r = np.empty(batch_size, dtype=np.float32)
        out_ns = []
        out_d = np.empty(batch_size, dtype=np.float32)

        total = self.sum_tree.sum()
        segment = total / batch_size
        min_prob = self.min_tree.min() / total
        max_w = (min_prob * self.size) ** (-beta)

        for i in range(batch_size):
            a = segment * i
            b = segment * (i + 1)
            mass = random.random() * (b - a) + a
            idx = self.sum_tree.find_prefixsum_idx(mass)
            out_idx.append(idx)
            out_s.append(self.states[idx])
            out_a[i] = self.actions[idx]
            out_r[i] = self.rewards[idx]
            out_ns.append(self.next_states[idx])
            out_d[i] = float(self.dones[idx])

        # pesos de importancia
        probs = np.array([self.sum_tree[idx] / total for idx in out_idx], dtype=np.float32)
        w = (probs * self.size) ** (-beta)
        w = w / max_w
        w = w.astype(np.float32)

        return np.array(out_idx), w, (np.array(out_s), out_a, out_r, np.array(out_ns), out_d)

    def update_priorities(self, idxs, priorities):
        for i, p in zip(idxs, priorities):
            p = float(p + self.eps)
            self.sum_tree.update(i, (p) ** self.alpha)
            self.min_tree.update(i, (p) ** self.alpha)
            self.max_priority = max(self.max_priority, p)


# ===========================
#  Red Dueling
# ===========================
class DuelingDQN(nn.Module):
    """
    Backbone conv + (stream Valor) + (stream Ventaja). Q = V + (A - mean(A))
    Espera tensores (B,C,H,W) float/uint8; si llega (B,H,W,C) permuta.
    """
    def __init__(self, input_shape: Tuple[int, int, int], n_actions: int):
        super().__init__()
        c, h, w = input_shape
        self.expected_c = c

        self.features = nn.Sequential(
            nn.Conv2d(c, 32, kernel_size=8, stride=4),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU(inplace=True),
            nn.Flatten()
        )
        with torch.no_grad():
            n_flat = self.features(torch.zeros(1, c, h, w)).shape[1]

        self.value = nn.Sequential(
            nn.Linear(n_flat, 512), nn.ReLU(inplace=True),
            nn.Linear(512, 1)
        )
        self.advantage = nn.Sequential(
            nn.Linear(n_flat, 512), nn.ReLU(inplace=True),
            nn.Linear(512, n_actions)
        )

    def forward(self, x):
        if x.ndim != 4:
            raise ValueError(f"x.ndim={x.ndim}, esperado 4")
        if x.shape[1] != self.expected_c and x.shape[-1] == self.expected_c:
            x = x.permute(0, 3, 1, 2)
        x = x.float() / 255.0
        feat = self.features(x)
        v = self.value(feat)                  # (B,1)
        a = self.advantage(feat)              # (B,A)
        q = v + (a - a.mean(dim=1, keepdim=True))
        return q


# ===========================
#  Política para play.py
# ===========================
class DQNPolicy:
    def __init__(self, q_net: 'DuelingDQN'):
        self.q_net = q_net.to(device)
        self.q_net.eval()

    @torch.no_grad()
    def __call__(self, obs: np.ndarray, info: dict) -> int:
        if obs.ndim != 3:
            raise ValueError("obs debe ser 3D")
        ob = np.expand_dims(obs, axis=0)
        ob_t = torch.from_numpy(ob).to(device)
        q = self.q_net(ob_t)
        return int(torch.argmax(q, dim=1).item())


# ===========================
#  Utilidades de logging
# ===========================
def _moving_average(x: List[float], k: int = 100):
    if len(x) == 0:
        return []
    out = []
    s = 0.0
    q = []
    for i, v in enumerate(x):
        q.append(v)
        s += v
        if len(q) > k:
            s -= q.pop(0)
        out.append(s / len(q))
    return out

def _save_plot_and_csv(checkpoint_dir: str, rewards: List[float], episode: int):
    os.makedirs(checkpoint_dir, exist_ok=True)
    # CSV
    csv_path = os.path.join(checkpoint_dir, "rewards_log.csv")
    new_file = not os.path.exists(csv_path)
    with open(csv_path, "a", newline="") as f:
        w = csv.writer(f)
        if new_file:
            w.writerow(["episode", "reward"])
        w.writerow([episode, rewards[-1]])

    # PNG
    plt.figure(figsize=(8,4.5))
    plt.plot(rewards, label="Reward")
    ma = _moving_average(rewards, k=100)
    if len(ma) > 0:
        plt.plot(ma, label="Moving Avg (100)")
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.title("Training Rewards")
    plt.legend()
    png_path = os.path.join(checkpoint_dir, f"rewards_ep{episode}.png")
    plt.tight_layout()
    plt.savefig(png_path, dpi=120)
    plt.close()
    print(f"[LOG] Guardadas gráfica y CSV en: {png_path} / {csv_path}")


# ===========================
#  Entrenamiento
# ===========================
def train_dueling_double_dqn_per(
    checkpoint_dir: str,
    total_episodes: int = 50000,
    buffer_capacity: int = 100_000,
    batch_size: int = 32,
    gamma: float = 0.99,
    lr: float = 1e-4,
    start_epsilon: float = 1.0,
    end_epsilon: float = 0.1,
    epsilon_decay_episodes: int = 30000,
    target_update_interval: int = 1000,     # en pasos
    train_start: int = 10_000,
    per_alpha: float = 0.6,
    per_beta_start: float = 0.4,
    per_beta_end: float = 1.0,
    per_beta_anneal_episodes: int = 50000,
    per_eps: float = 1e-6,
    save_interval: int = 500,               # guardar modelo
    plot_interval: int = 200,               # guardar PNG/CSV
    max_steps_per_episode: int | None = None,
    seed: int = 42,
):
    os.makedirs(checkpoint_dir, exist_ok=True)

    env = make_galaxian_env(seed=seed, render_mode=None)

    # Detecta layout y fija input_shape=(C,H,W)
    obs, _ = env.reset()
    if obs.ndim != 3:
        env.close()
        raise ValueError("obs.ndim inesperado")
    if obs.shape[0] in (1,3,4):
        input_shape = (obs.shape[0], obs.shape[1], obs.shape[2])
    else:
        input_shape = (obs.shape[2], obs.shape[0], obs.shape[1])
    n_actions = env.action_space.n

    q_net = DuelingDQN(input_shape, n_actions).to(device)
    target_net = DuelingDQN(input_shape, n_actions).to(device)
    target_net.load_state_dict(q_net.state_dict())
    target_net.eval()

    optimizer = optim.Adam(q_net.parameters(), lr=lr)
    buffer = PrioritizedReplayBuffer(buffer_capacity, alpha=per_alpha, eps=per_eps)

    rewards_log: List[float] = []
    global_step = 0

    def epsilon_by_episode(ep):
        if ep >= epsilon_decay_episodes:
            return end_epsilon
        frac = ep / float(epsilon_decay_episodes)
        return start_epsilon + frac * (end_epsilon - start_epsilon)

    def beta_by_episode(ep):
        # lineal de per_beta_start -> per_beta_end
        frac = min(1.0, ep / float(per_beta_anneal_episodes))
        return per_beta_start + frac * (per_beta_end - per_beta_start)

    for episode in range(1, total_episodes + 1):
        obs, _ = env.reset()
        done = False
        total_reward = 0.0
        steps_in_ep = 0

        eps = epsilon_by_episode(episode)
        beta = beta_by_episode(episode)

        while not done:
            global_step += 1
            steps_in_ep += 1

            # ε-greedy sobre q_net
            if random.random() < eps:
                action = env.action_space.sample()
            else:
                with torch.no_grad():
                    ob = np.expand_dims(obs, axis=0)
                    ob_t = torch.from_numpy(ob).to(device)
                    q_vals = q_net(ob_t)
                    action = int(torch.argmax(q_vals, dim=1).item())

            next_obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total_reward += float(reward)

            buffer.add(obs, action, reward, next_obs, done)
            obs = next_obs

            # Entrenamiento (cuando hay suficientes muestras)
            if len(buffer) >= train_start:
                idxs, isw, batch = buffer.sample(batch_size, beta=beta)
                s, a, r, ns, d = batch

                s_t  = torch.from_numpy(s).to(device)
                ns_t = torch.from_numpy(ns).to(device)
                a_t  = torch.from_numpy(a).long().to(device)
                r_t  = torch.from_numpy(r).float().to(device)
                d_t  = torch.from_numpy(d).float().to(device)
                w_t  = torch.from_numpy(isw).float().to(device)

                # Q_online(s,a)
                q = q_net(s_t).gather(1, a_t.unsqueeze(1)).squeeze(1)

                # Double DQN target:
                # a* = argmax_a Q_online(ns,a)
                with torch.no_grad():
                    q_online_ns = q_net(ns_t)
                    a_star = torch.argmax(q_online_ns, dim=1, keepdim=True)

                    q_target_ns = target_net(ns_t)
                    next_q = q_target_ns.gather(1, a_star).squeeze(1)

                    target = r_t + gamma * next_q * (1.0 - d_t)

                td_error = target - q
                loss = (w_t * td_error.pow(2)).mean()

                optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(q_net.parameters(), 10.0)
                optimizer.step()

                # actualizar prioridades con |TD error|
                new_prios = td_error.detach().abs().cpu().numpy() + per_eps
                buffer.update_priorities(idxs, new_prios)

            # sync target
            if global_step % target_update_interval == 0:
                target_net.load_state_dict(q_net.state_dict())

            if max_steps_per_episode is not None and steps_in_ep >= max_steps_per_episode:
                break

        rewards_log.append(total_reward)
        print(f"[Dueling-DDQN+PER] Ep {episode}/{total_episodes} | R: {total_reward:.1f} | eps={eps:.3f} | beta={beta:.3f} | buf={len(buffer)}")

        # Guardar checkpoint
        if episode % save_interval == 0:
            ckpt_path = os.path.join(checkpoint_dir, f"dueling_ddqn_per_ep{episode}.pth")
            torch.save({
                "q_net": q_net.state_dict(),
                "target_net": target_net.state_dict(),
                "optimizer": optimizer.state_dict(),
                "episode": episode,
                "global_step": global_step,
                "rewards": rewards_log,
                "input_shape": input_shape,
                "n_actions": n_actions,
            }, ckpt_path)
            print(f"[CKPT] Guardado: {ckpt_path}")

        # Guardar gráfica + CSV
        if episode % plot_interval == 0:
            _save_plot_and_csv(checkpoint_dir, rewards_log, episode)

    env.close()

    # Guardar modelo final
    final_path = os.path.join(checkpoint_dir, "dueling_ddqn_per_final.pth")
    torch.save(q_net.state_dict(), final_path)
    print(f"[DONE] Modelo final guardado en: {final_path}")

    # Gráfica final
    _save_plot_and_csv(checkpoint_dir, rewards_log, total_episodes)

    return q_net

# %%
model = train_dueling_double_dqn_per(
    checkpoint_dir=f"{BASE_DIR}/dueling_ddqn_per",
    total_episodes=100000,            # ajusta según GPU/tiempo
    save_interval=500,
    plot_interval=500
)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# [Dueling-DDQN+PER] Ep 1892/100000 | R: 600.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1893/100000 | R: 1440.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1894/100000 | R: 740.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1895/100000 | R: 430.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1896/100000 | R: 1100.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1897/100000 | R: 680.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1898/100000 | R: 330.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1899/100000 | R: 990.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1900/100000 | R: 510.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1901/100000 | R: 670.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1902/100000 | R: 900.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1903/100000 | R: 820.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1904/100000 | R: 430.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1905/100000 | R: 940.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1906/100000 | R: 320.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1907/100000 | R: 1050.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1908/100000 | R: 530.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1909/100000 | R: 1290.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1910/100000 | R: 360.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1911/100000 | R: 690.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1912/100000 | R: 710.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1913/100000 | R: 470.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1914/100000 | R: 420.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1915/100000 | R: 450.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1916/100000 | R: 1440.0 | eps=0.943 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1917/100000 | R: 1530.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1918/100000 | R: 480.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1919/100000 | R: 640.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1920/100000 | R: 690.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1921/100000 | R: 740.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1922/100000 | R: 460.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1923/100000 | R: 1550.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1924/100000 | R: 630.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1925/100000 | R: 890.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1926/100000 | R: 640.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1927/100000 | R: 360.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1928/100000 | R: 1030.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1929/100000 | R: 1050.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1930/100000 | R: 390.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1931/100000 | R: 1100.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1932/100000 | R: 570.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1933/100000 | R: 950.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1934/100000 | R: 1030.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1935/100000 | R: 950.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1936/100000 | R: 330.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1937/100000 | R: 480.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1938/100000 | R: 940.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1939/100000 | R: 720.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1940/100000 | R: 420.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1941/100000 | R: 1100.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1942/100000 | R: 610.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1943/100000 | R: 670.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1944/100000 | R: 340.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1945/100000 | R: 910.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1946/100000 | R: 280.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1947/100000 | R: 660.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1948/100000 | R: 270.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1949/100000 | R: 740.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1950/100000 | R: 610.0 | eps=0.942 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1951/100000 | R: 690.0 | eps=0.941 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1952/100000 | R: 970.0 | eps=0.941 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1953/100000 | R: 1210.0 | eps=0.941 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1954/100000 | R: 1130.0 | eps=0.941 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1955/100000 | R: 530.0 | eps=0.941 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1956/100000 | R: 830.0 | eps=0.941 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1957/100000 | R: 810.0 | eps=0.941 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1958/100000 | R: 1130.0 | eps=0.941 | beta=0.423 | buf=131072
# [Dueling-DDQN+PER] Ep 1959/100000 | R: 1330.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1960/100000 | R: 420.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1961/100000 | R: 750.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1962/100000 | R: 550.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1963/100000 | R: 910.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1964/100000 | R: 590.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1965/100000 | R: 380.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1966/100000 | R: 790.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1967/100000 | R: 1300.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1968/100000 | R: 210.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1969/100000 | R: 1030.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1970/100000 | R: 270.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1971/100000 | R: 700.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1972/100000 | R: 210.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1973/100000 | R: 210.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1974/100000 | R: 1380.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1975/100000 | R: 730.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1976/100000 | R: 270.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1977/100000 | R: 980.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1978/100000 | R: 590.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1979/100000 | R: 570.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1980/100000 | R: 910.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1981/100000 | R: 710.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1982/100000 | R: 590.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1983/100000 | R: 1860.0 | eps=0.941 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1984/100000 | R: 520.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1985/100000 | R: 850.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1986/100000 | R: 510.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1987/100000 | R: 1100.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1988/100000 | R: 1110.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1989/100000 | R: 340.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1990/100000 | R: 770.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1991/100000 | R: 460.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1992/100000 | R: 860.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1993/100000 | R: 150.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1994/100000 | R: 1460.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1995/100000 | R: 530.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1996/100000 | R: 720.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1997/100000 | R: 510.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1998/100000 | R: 830.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 1999/100000 | R: 940.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2000/100000 | R: 1070.0 | eps=0.940 | beta=0.424 | buf=131072
# [CKPT] Guardado: /content/drive/MyDrive/galaxian_rl/dueling_ddqn_per/dueling_ddqn_per_ep2000.pth
# [LOG] Guardadas gráfica y CSV en: /content/drive/MyDrive/galaxian_rl/dueling_ddqn_per/rewards_ep2000.png / /content/drive/MyDrive/galaxian_rl/dueling_ddqn_per/rewards_log.csv
# [Dueling-DDQN+PER] Ep 2001/100000 | R: 520.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2002/100000 | R: 270.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2003/100000 | R: 430.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2004/100000 | R: 1680.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2005/100000 | R: 220.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2006/100000 | R: 820.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2007/100000 | R: 390.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2008/100000 | R: 720.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2009/100000 | R: 670.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2010/100000 | R: 910.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2011/100000 | R: 1040.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2012/100000 | R: 910.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2013/100000 | R: 1110.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2014/100000 | R: 270.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2015/100000 | R: 490.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2016/100000 | R: 250.0 | eps=0.940 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2017/100000 | R: 990.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2018/100000 | R: 920.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2019/100000 | R: 480.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2020/100000 | R: 270.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2021/100000 | R: 610.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2022/100000 | R: 420.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2023/100000 | R: 330.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2024/100000 | R: 700.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2025/100000 | R: 940.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2026/100000 | R: 550.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2027/100000 | R: 550.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2028/100000 | R: 300.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2029/100000 | R: 1070.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2030/100000 | R: 590.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2031/100000 | R: 300.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2032/100000 | R: 790.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2033/100000 | R: 1530.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2034/100000 | R: 600.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2035/100000 | R: 390.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2036/100000 | R: 660.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2037/100000 | R: 330.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2038/100000 | R: 490.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2039/100000 | R: 550.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2040/100000 | R: 1000.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2041/100000 | R: 770.0 | eps=0.939 | beta=0.424 | buf=131072
# [Dueling-DDQN+PER] Ep 2042/100000 | R: 660.0 | eps=0.939 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2043/100000 | R: 910.0 | eps=0.939 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2044/100000 | R: 570.0 | eps=0.939 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2045/100000 | R: 790.0 | eps=0.939 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2046/100000 | R: 300.0 | eps=0.939 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2047/100000 | R: 880.0 | eps=0.939 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2048/100000 | R: 540.0 | eps=0.939 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2049/100000 | R: 610.0 | eps=0.939 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2050/100000 | R: 640.0 | eps=0.939 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2051/100000 | R: 180.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2052/100000 | R: 400.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2053/100000 | R: 370.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2054/100000 | R: 280.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2055/100000 | R: 450.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2056/100000 | R: 180.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2057/100000 | R: 860.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2058/100000 | R: 1010.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2059/100000 | R: 150.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2060/100000 | R: 360.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2061/100000 | R: 490.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2062/100000 | R: 750.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2063/100000 | R: 340.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2064/100000 | R: 1590.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2065/100000 | R: 990.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2066/100000 | R: 710.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2067/100000 | R: 330.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2068/100000 | R: 720.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2069/100000 | R: 240.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2070/100000 | R: 490.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2071/100000 | R: 270.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2072/100000 | R: 1410.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2073/100000 | R: 810.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2074/100000 | R: 1310.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2075/100000 | R: 240.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2076/100000 | R: 820.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2077/100000 | R: 510.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2078/100000 | R: 450.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2079/100000 | R: 610.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2080/100000 | R: 960.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2081/100000 | R: 390.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2082/100000 | R: 1090.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2083/100000 | R: 990.0 | eps=0.938 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2084/100000 | R: 960.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2085/100000 | R: 270.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2086/100000 | R: 580.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2087/100000 | R: 270.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2088/100000 | R: 380.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2089/100000 | R: 760.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2090/100000 | R: 860.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2091/100000 | R: 520.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2092/100000 | R: 870.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2093/100000 | R: 1020.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2094/100000 | R: 510.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2095/100000 | R: 360.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2096/100000 | R: 780.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2097/100000 | R: 1200.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2098/100000 | R: 290.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2099/100000 | R: 360.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2100/100000 | R: 790.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2101/100000 | R: 360.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2102/100000 | R: 680.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2103/100000 | R: 880.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2104/100000 | R: 520.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2105/100000 | R: 970.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2106/100000 | R: 900.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2107/100000 | R: 280.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2108/100000 | R: 520.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2109/100000 | R: 590.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2110/100000 | R: 720.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2111/100000 | R: 1210.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2112/100000 | R: 740.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2113/100000 | R: 540.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2114/100000 | R: 1030.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2115/100000 | R: 680.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2116/100000 | R: 730.0 | eps=0.937 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2117/100000 | R: 1030.0 | eps=0.936 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2118/100000 | R: 1320.0 | eps=0.936 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2119/100000 | R: 210.0 | eps=0.936 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2120/100000 | R: 450.0 | eps=0.936 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2121/100000 | R: 420.0 | eps=0.936 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2122/100000 | R: 570.0 | eps=0.936 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2123/100000 | R: 1080.0 | eps=0.936 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2124/100000 | R: 870.0 | eps=0.936 | beta=0.425 | buf=131072
# [Dueling-DDQN+PER] Ep 2125/100000 | R: 180.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2126/100000 | R: 150.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2127/100000 | R: 150.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2128/100000 | R: 1030.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2129/100000 | R: 510.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2130/100000 | R: 330.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2131/100000 | R: 210.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2132/100000 | R: 1010.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2133/100000 | R: 370.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2134/100000 | R: 1260.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2135/100000 | R: 420.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2136/100000 | R: 810.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2137/100000 | R: 520.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2138/100000 | R: 630.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2139/100000 | R: 330.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2140/100000 | R: 540.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2141/100000 | R: 450.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2142/100000 | R: 1090.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2143/100000 | R: 1260.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2144/100000 | R: 590.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2145/100000 | R: 520.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2146/100000 | R: 370.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2147/100000 | R: 990.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2148/100000 | R: 410.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2149/100000 | R: 500.0 | eps=0.936 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2150/100000 | R: 800.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2151/100000 | R: 500.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2152/100000 | R: 390.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2153/100000 | R: 680.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2154/100000 | R: 780.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2155/100000 | R: 1120.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2156/100000 | R: 750.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2157/100000 | R: 650.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2158/100000 | R: 770.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2159/100000 | R: 850.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2160/100000 | R: 540.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2161/100000 | R: 360.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2162/100000 | R: 410.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2163/100000 | R: 520.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2164/100000 | R: 690.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2165/100000 | R: 1170.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2166/100000 | R: 540.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2167/100000 | R: 1080.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2168/100000 | R: 430.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2169/100000 | R: 1000.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2170/100000 | R: 870.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2171/100000 | R: 400.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2172/100000 | R: 780.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2173/100000 | R: 1200.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2174/100000 | R: 390.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2175/100000 | R: 1030.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2176/100000 | R: 590.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2177/100000 | R: 750.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2178/100000 | R: 400.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2179/100000 | R: 710.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2180/100000 | R: 1060.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2181/100000 | R: 770.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2182/100000 | R: 860.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2183/100000 | R: 1090.0 | eps=0.935 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2184/100000 | R: 480.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2185/100000 | R: 180.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2186/100000 | R: 750.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2187/100000 | R: 360.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2188/100000 | R: 770.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2189/100000 | R: 480.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2190/100000 | R: 450.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2191/100000 | R: 300.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2192/100000 | R: 320.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2193/100000 | R: 450.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2194/100000 | R: 760.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2195/100000 | R: 520.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2196/100000 | R: 1480.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2197/100000 | R: 890.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2198/100000 | R: 1310.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2199/100000 | R: 1790.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2200/100000 | R: 300.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2201/100000 | R: 420.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2202/100000 | R: 150.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2203/100000 | R: 630.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2204/100000 | R: 280.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2205/100000 | R: 830.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2206/100000 | R: 680.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2207/100000 | R: 590.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2208/100000 | R: 310.0 | eps=0.934 | beta=0.426 | buf=131072
# [Dueling-DDQN+PER] Ep 2209/100000 | R: 90.0 | eps=0.934 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2210/100000 | R: 1100.0 | eps=0.934 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2211/100000 | R: 810.0 | eps=0.934 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2212/100000 | R: 830.0 | eps=0.934 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2213/100000 | R: 720.0 | eps=0.934 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2214/100000 | R: 510.0 | eps=0.934 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2215/100000 | R: 660.0 | eps=0.934 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2216/100000 | R: 920.0 | eps=0.934 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2217/100000 | R: 390.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2218/100000 | R: 1090.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2219/100000 | R: 1150.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2220/100000 | R: 530.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2221/100000 | R: 540.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2222/100000 | R: 770.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2223/100000 | R: 880.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2224/100000 | R: 830.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2225/100000 | R: 1040.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2226/100000 | R: 260.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2227/100000 | R: 240.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2228/100000 | R: 470.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2229/100000 | R: 730.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2230/100000 | R: 1520.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2231/100000 | R: 1280.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2232/100000 | R: 330.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2233/100000 | R: 390.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2234/100000 | R: 330.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2235/100000 | R: 430.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2236/100000 | R: 240.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2237/100000 | R: 690.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2238/100000 | R: 150.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2239/100000 | R: 900.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2240/100000 | R: 2100.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2241/100000 | R: 820.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2242/100000 | R: 610.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2243/100000 | R: 390.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2244/100000 | R: 860.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2245/100000 | R: 760.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2246/100000 | R: 300.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2247/100000 | R: 1020.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2248/100000 | R: 310.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2249/100000 | R: 760.0 | eps=0.933 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2250/100000 | R: 1330.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2251/100000 | R: 270.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2252/100000 | R: 1000.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2253/100000 | R: 550.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2254/100000 | R: 670.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2255/100000 | R: 800.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2256/100000 | R: 460.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2257/100000 | R: 1410.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2258/100000 | R: 390.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2259/100000 | R: 270.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2260/100000 | R: 180.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2261/100000 | R: 720.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2262/100000 | R: 910.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2263/100000 | R: 590.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2264/100000 | R: 430.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2265/100000 | R: 650.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2266/100000 | R: 810.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2267/100000 | R: 760.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2268/100000 | R: 810.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2269/100000 | R: 1620.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2270/100000 | R: 300.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2271/100000 | R: 850.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2272/100000 | R: 530.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2273/100000 | R: 150.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2274/100000 | R: 910.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2275/100000 | R: 270.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2276/100000 | R: 860.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2277/100000 | R: 700.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2278/100000 | R: 510.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2279/100000 | R: 210.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2280/100000 | R: 760.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2281/100000 | R: 550.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2282/100000 | R: 870.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2283/100000 | R: 150.0 | eps=0.932 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2284/100000 | R: 1270.0 | eps=0.931 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2285/100000 | R: 770.0 | eps=0.931 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2286/100000 | R: 610.0 | eps=0.931 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2287/100000 | R: 210.0 | eps=0.931 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2288/100000 | R: 710.0 | eps=0.931 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2289/100000 | R: 680.0 | eps=0.931 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2290/100000 | R: 1330.0 | eps=0.931 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2291/100000 | R: 670.0 | eps=0.931 | beta=0.427 | buf=131072
# [Dueling-DDQN+PER] Ep 2292/100000 | R: 870.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2293/100000 | R: 1200.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2294/100000 | R: 580.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2295/100000 | R: 340.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2296/100000 | R: 440.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2297/100000 | R: 390.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2298/100000 | R: 1040.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2299/100000 | R: 850.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2300/100000 | R: 760.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2301/100000 | R: 570.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2302/100000 | R: 450.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2303/100000 | R: 810.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2304/100000 | R: 600.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2305/100000 | R: 440.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2306/100000 | R: 460.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2307/100000 | R: 1020.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2308/100000 | R: 610.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2309/100000 | R: 1000.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2310/100000 | R: 650.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2311/100000 | R: 900.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2312/100000 | R: 810.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2313/100000 | R: 430.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2314/100000 | R: 980.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2315/100000 | R: 640.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2316/100000 | R: 600.0 | eps=0.931 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2317/100000 | R: 510.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2318/100000 | R: 1000.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2319/100000 | R: 360.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2320/100000 | R: 770.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2321/100000 | R: 840.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2322/100000 | R: 420.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2323/100000 | R: 570.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2324/100000 | R: 970.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2325/100000 | R: 980.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2326/100000 | R: 660.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2327/100000 | R: 900.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2328/100000 | R: 740.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2329/100000 | R: 660.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2330/100000 | R: 450.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2331/100000 | R: 1110.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2332/100000 | R: 240.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2333/100000 | R: 630.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2334/100000 | R: 650.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2335/100000 | R: 660.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2336/100000 | R: 1170.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2337/100000 | R: 520.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2338/100000 | R: 910.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2339/100000 | R: 1030.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2340/100000 | R: 590.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2341/100000 | R: 390.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2342/100000 | R: 370.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2343/100000 | R: 300.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2344/100000 | R: 1030.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2345/100000 | R: 610.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2346/100000 | R: 1080.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2347/100000 | R: 760.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2348/100000 | R: 270.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2349/100000 | R: 460.0 | eps=0.930 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2350/100000 | R: 540.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2351/100000 | R: 1230.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2352/100000 | R: 690.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2353/100000 | R: 600.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2354/100000 | R: 880.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2355/100000 | R: 650.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2356/100000 | R: 720.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2357/100000 | R: 920.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2358/100000 | R: 420.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2359/100000 | R: 700.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2360/100000 | R: 950.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2361/100000 | R: 300.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2362/100000 | R: 1010.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2363/100000 | R: 930.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2364/100000 | R: 1470.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2365/100000 | R: 480.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2366/100000 | R: 1340.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2367/100000 | R: 1200.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2368/100000 | R: 420.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2369/100000 | R: 990.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2370/100000 | R: 300.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2371/100000 | R: 600.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2372/100000 | R: 810.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2373/100000 | R: 460.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2374/100000 | R: 620.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2375/100000 | R: 300.0 | eps=0.929 | beta=0.428 | buf=131072
# [Dueling-DDQN+PER] Ep 2376/100000 | R: 890.0 | eps=0.929 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2377/100000 | R: 330.0 | eps=0.929 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2378/100000 | R: 730.0 | eps=0.929 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2379/100000 | R: 330.0 | eps=0.929 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2380/100000 | R: 420.0 | eps=0.929 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2381/100000 | R: 660.0 | eps=0.929 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2382/100000 | R: 460.0 | eps=0.929 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2383/100000 | R: 1110.0 | eps=0.929 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2384/100000 | R: 1230.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2385/100000 | R: 480.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2386/100000 | R: 1410.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2387/100000 | R: 720.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2388/100000 | R: 150.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2389/100000 | R: 420.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2390/100000 | R: 730.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2391/100000 | R: 640.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2392/100000 | R: 860.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2393/100000 | R: 620.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2394/100000 | R: 670.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2395/100000 | R: 1340.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2396/100000 | R: 180.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2397/100000 | R: 1000.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2398/100000 | R: 300.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2399/100000 | R: 270.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2400/100000 | R: 270.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2401/100000 | R: 620.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2402/100000 | R: 680.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2403/100000 | R: 400.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2404/100000 | R: 300.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2405/100000 | R: 570.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2406/100000 | R: 300.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2407/100000 | R: 670.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2408/100000 | R: 650.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2409/100000 | R: 1010.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2410/100000 | R: 680.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2411/100000 | R: 1050.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2412/100000 | R: 1070.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2413/100000 | R: 480.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2414/100000 | R: 530.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2415/100000 | R: 980.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2416/100000 | R: 460.0 | eps=0.928 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2417/100000 | R: 450.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2418/100000 | R: 300.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2419/100000 | R: 500.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2420/100000 | R: 450.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2421/100000 | R: 810.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2422/100000 | R: 270.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2423/100000 | R: 240.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2424/100000 | R: 270.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2425/100000 | R: 1080.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2426/100000 | R: 270.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2427/100000 | R: 780.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2428/100000 | R: 1360.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2429/100000 | R: 1120.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2430/100000 | R: 1080.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2431/100000 | R: 430.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2432/100000 | R: 480.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2433/100000 | R: 650.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2434/100000 | R: 500.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2435/100000 | R: 890.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2436/100000 | R: 860.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2437/100000 | R: 620.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2438/100000 | R: 300.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2439/100000 | R: 300.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2440/100000 | R: 1110.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2441/100000 | R: 120.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2442/100000 | R: 240.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2443/100000 | R: 690.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2444/100000 | R: 620.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2445/100000 | R: 360.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2446/100000 | R: 910.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2447/100000 | R: 690.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2448/100000 | R: 850.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2449/100000 | R: 680.0 | eps=0.927 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2450/100000 | R: 660.0 | eps=0.926 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2451/100000 | R: 910.0 | eps=0.926 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2452/100000 | R: 1100.0 | eps=0.926 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2453/100000 | R: 860.0 | eps=0.926 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2454/100000 | R: 150.0 | eps=0.926 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2455/100000 | R: 750.0 | eps=0.926 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2456/100000 | R: 750.0 | eps=0.926 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2457/100000 | R: 400.0 | eps=0.926 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2458/100000 | R: 890.0 | eps=0.926 | beta=0.429 | buf=131072
# [Dueling-DDQN+PER] Ep 2459/100000 | R: 520.0 | eps=0.926 | beta=0.430 | buf=131072
# [Dueling-DDQN+PER] Ep 2460/100000 | R: 1070.0 | eps=0.926 | beta=0.430 | buf=131072
# [Dueling-DDQN+PER] Ep 2461/100000 | R: 910.0 | eps=0.926 | beta=0.430 | buf=131072
# [Dueling-DDQN+PER] Ep 2462/100000 | R: 940.0 | eps=0.926 | beta=0.430 | buf=131072
# [Dueling-DDQN+PER] Ep 2463/100000 | R: 580.0 | eps=0.926 | beta=0.430 | buf=131072
# [Dueling-DDQN+PER] Ep 2464/100000 | R: 500.0 | eps=0.926 | beta=0.430 | buf=131072
# ...
# [Dueling-DDQN+PER] Ep 6680/100000 | R: 270.0 | eps=0.800 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6681/100000 | R: 910.0 | eps=0.800 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6682/100000 | R: 970.0 | eps=0.800 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6683/100000 | R: 830.0 | eps=0.800 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6684/100000 | R: 330.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6685/100000 | R: 690.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6686/100000 | R: 210.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6687/100000 | R: 910.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6688/100000 | R: 300.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6689/100000 | R: 590.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6690/100000 | R: 360.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6691/100000 | R: 620.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6692/100000 | R: 490.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6693/100000 | R: 1200.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6694/100000 | R: 620.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6695/100000 | R: 570.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6696/100000 | R: 950.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6697/100000 | R: 940.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6698/100000 | R: 390.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6699/100000 | R: 360.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6700/100000 | R: 450.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6701/100000 | R: 210.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6702/100000 | R: 390.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6703/100000 | R: 660.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6704/100000 | R: 210.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6705/100000 | R: 270.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6706/100000 | R: 900.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6707/100000 | R: 550.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6708/100000 | R: 460.0 | eps=0.799 | beta=0.480 | buf=131072
# [Dueling-DDQN+PER] Ep 6709/100000 | R: 470.0 | eps=0.799 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6710/100000 | R: 970.0 | eps=0.799 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6711/100000 | R: 610.0 | eps=0.799 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6712/100000 | R: 660.0 | eps=0.799 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6713/100000 | R: 240.0 | eps=0.799 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6714/100000 | R: 1400.0 | eps=0.799 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6715/100000 | R: 540.0 | eps=0.799 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6716/100000 | R: 460.0 | eps=0.799 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6717/100000 | R: 1160.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6718/100000 | R: 680.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6719/100000 | R: 510.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6720/100000 | R: 360.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6721/100000 | R: 620.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6722/100000 | R: 830.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6723/100000 | R: 820.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6724/100000 | R: 360.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6725/100000 | R: 650.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6726/100000 | R: 430.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6727/100000 | R: 620.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6728/100000 | R: 360.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6729/100000 | R: 440.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6730/100000 | R: 750.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6731/100000 | R: 810.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6732/100000 | R: 360.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6733/100000 | R: 780.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6734/100000 | R: 760.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6735/100000 | R: 640.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6736/100000 | R: 580.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6737/100000 | R: 730.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6738/100000 | R: 300.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6739/100000 | R: 770.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6740/100000 | R: 420.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6741/100000 | R: 680.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6742/100000 | R: 660.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6743/100000 | R: 330.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6744/100000 | R: 270.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6745/100000 | R: 560.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6746/100000 | R: 370.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6747/100000 | R: 770.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6748/100000 | R: 840.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6749/100000 | R: 1100.0 | eps=0.798 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6750/100000 | R: 360.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6751/100000 | R: 510.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6752/100000 | R: 490.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6753/100000 | R: 330.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6754/100000 | R: 950.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6755/100000 | R: 330.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6756/100000 | R: 210.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6757/100000 | R: 700.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6758/100000 | R: 280.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6759/100000 | R: 800.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6760/100000 | R: 760.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6761/100000 | R: 330.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6762/100000 | R: 350.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6763/100000 | R: 960.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6764/100000 | R: 120.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6765/100000 | R: 670.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6766/100000 | R: 520.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6767/100000 | R: 330.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6768/100000 | R: 690.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6769/100000 | R: 900.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6770/100000 | R: 1050.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6771/100000 | R: 240.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6772/100000 | R: 710.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6773/100000 | R: 970.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6774/100000 | R: 1390.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6775/100000 | R: 540.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6776/100000 | R: 440.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6777/100000 | R: 240.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6778/100000 | R: 600.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6779/100000 | R: 180.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6780/100000 | R: 350.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6781/100000 | R: 520.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6782/100000 | R: 850.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6783/100000 | R: 700.0 | eps=0.797 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6784/100000 | R: 970.0 | eps=0.796 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6785/100000 | R: 660.0 | eps=0.796 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6786/100000 | R: 1270.0 | eps=0.796 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6787/100000 | R: 370.0 | eps=0.796 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6788/100000 | R: 700.0 | eps=0.796 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6789/100000 | R: 720.0 | eps=0.796 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6790/100000 | R: 600.0 | eps=0.796 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6791/100000 | R: 410.0 | eps=0.796 | beta=0.481 | buf=131072
# [Dueling-DDQN+PER] Ep 6792/100000 | R: 580.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6793/100000 | R: 830.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6794/100000 | R: 360.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6795/100000 | R: 950.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6796/100000 | R: 330.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6797/100000 | R: 550.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6798/100000 | R: 240.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6799/100000 | R: 1150.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6800/100000 | R: 920.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6801/100000 | R: 890.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6802/100000 | R: 690.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6803/100000 | R: 560.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6804/100000 | R: 470.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6805/100000 | R: 490.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6806/100000 | R: 1090.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6807/100000 | R: 920.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6808/100000 | R: 530.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6809/100000 | R: 800.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6810/100000 | R: 360.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6811/100000 | R: 690.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6812/100000 | R: 430.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6813/100000 | R: 510.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6814/100000 | R: 470.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6815/100000 | R: 270.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6816/100000 | R: 950.0 | eps=0.796 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6817/100000 | R: 500.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6818/100000 | R: 330.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6819/100000 | R: 610.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6820/100000 | R: 700.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6821/100000 | R: 520.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6822/100000 | R: 710.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6823/100000 | R: 300.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6824/100000 | R: 300.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6825/100000 | R: 390.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6826/100000 | R: 440.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6827/100000 | R: 1020.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6828/100000 | R: 350.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6829/100000 | R: 240.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6830/100000 | R: 60.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6831/100000 | R: 1300.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6832/100000 | R: 350.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6833/100000 | R: 580.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6834/100000 | R: 1040.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6835/100000 | R: 810.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6836/100000 | R: 760.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6837/100000 | R: 370.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6838/100000 | R: 690.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6839/100000 | R: 690.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6840/100000 | R: 580.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6841/100000 | R: 210.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6842/100000 | R: 620.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6843/100000 | R: 510.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6844/100000 | R: 270.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6845/100000 | R: 750.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6846/100000 | R: 880.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6847/100000 | R: 460.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6848/100000 | R: 810.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6849/100000 | R: 770.0 | eps=0.795 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6850/100000 | R: 890.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6851/100000 | R: 180.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6852/100000 | R: 1460.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6853/100000 | R: 450.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6854/100000 | R: 460.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6855/100000 | R: 530.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6856/100000 | R: 660.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6857/100000 | R: 420.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6858/100000 | R: 450.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6859/100000 | R: 620.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6860/100000 | R: 700.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6861/100000 | R: 270.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6862/100000 | R: 420.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6863/100000 | R: 500.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6864/100000 | R: 390.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6865/100000 | R: 720.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6866/100000 | R: 240.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6867/100000 | R: 240.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6868/100000 | R: 120.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6869/100000 | R: 390.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6870/100000 | R: 1130.0 | eps=0.794 | beta=0.482 | buf=131072
# [Dueling-DDQN+PER] Ep 6871/100000 | R: 630.0 | eps=0.794 | beta=0.482 | buf=131072

# %%
def train_dueling_double_dqn_per(
    checkpoint_dir: str,
    total_episodes: int = 5000,
    buffer_capacity: int = 100_000,
    batch_size: int = 32,
    gamma: float = 0.99,
    lr: float = 5e-5,
    start_epsilon: float = 1.0,
    end_epsilon: float = 0.05,
    epsilon_decay_episodes: int = 500,
    target_update_interval: int = 1000,     # en pasos
    train_start: int = 1000,
    per_alpha: float = 0.6,
    per_beta_start: float = 0.4,
    per_beta_end: float = 1.0,
    per_beta_anneal_episodes: int = 500,
    per_eps: float = 1e-6,
    save_interval: int = 500,               # guardar modelo
    plot_interval: int = 200,               # guardar PNG/CSV
    max_steps_per_episode: int | None = None,
    seed: int = 42,
    resume_from: str | None = None,         # <-- NUEVO: ruta a checkpoint .pth
):
    os.makedirs(checkpoint_dir, exist_ok=True)

    # Creamos el entorno
    env = make_galaxian_env(seed=seed, render_mode=None)

    # Detectar layout de observación
    obs, _ = env.reset()
    if obs.ndim != 3:
        env.close()
        raise ValueError("obs.ndim inesperado")
    if obs.shape[0] in (1, 3, 4):
        detected_input_shape = (obs.shape[0], obs.shape[1], obs.shape[2])
    else:
        detected_input_shape = (obs.shape[2], obs.shape[0], obs.shape[1])
    detected_n_actions = env.action_space.n

    # ------------------------------
    # Inicializar redes, optimizador, logs
    # ------------------------------
    start_episode = 1
    global_step = 0
    rewards_log: List[float] = []

    if resume_from is not None:
        print(f"[RESUME] Cargando checkpoint desde {resume_from}")
        ckpt = torch.load(resume_from, map_location=device, weights_only=False)

        # Usar input_shape / n_actions del checkpoint (más confiable)
        input_shape = tuple(ckpt.get("input_shape", detected_input_shape))
        n_actions = int(ckpt.get("n_actions", detected_n_actions))

        q_net = DuelingDQN(input_shape, n_actions).to(device)
        target_net = DuelingDQN(input_shape, n_actions).to(device)

        q_net.load_state_dict(ckpt["q_net"])
        target_net.load_state_dict(ckpt["target_net"])

        optimizer = optim.Adam(q_net.parameters(), lr=lr)
        optimizer.load_state_dict(ckpt["optimizer"])

        start_episode = int(ckpt["episode"]) + 1
        global_step = int(ckpt.get("global_step", 0))
        rewards_log = list(ckpt.get("rewards", []))

        print(f"[RESUME] Reanudando desde episodio {start_episode}, global_step={global_step}")
    else:
        # Entrenamiento desde cero
        input_shape = detected_input_shape
        n_actions = detected_n_actions

        q_net = DuelingDQN(input_shape, n_actions).to(device)
        target_net = DuelingDQN(input_shape, n_actions).to(device)
        target_net.load_state_dict(q_net.state_dict())
        target_net.eval()

        optimizer = optim.Adam(q_net.parameters(), lr=lr)
        start_episode = 1
        global_step = 0
        rewards_log = []

    # Replay buffer PER NUEVO (no se guardó en el checkpoint)
    buffer = PrioritizedReplayBuffer(buffer_capacity, alpha=per_alpha, eps=per_eps)

    def epsilon_by_episode(ep):
        if ep >= epsilon_decay_episodes:
            return end_epsilon
        frac = ep / float(epsilon_decay_episodes)
        return start_epsilon + frac * (end_epsilon - start_epsilon)

    def beta_by_episode(ep):
        frac = min(1.0, ep / float(per_beta_anneal_episodes))
        return per_beta_start + frac * (per_beta_end - per_beta_start)

    # ------------------------------
    # Bucle principal de entrenamiento
    # ------------------------------
    for episode in range(start_episode, total_episodes + 1):
        obs, _ = env.reset()
        done = False
        total_reward = 0.0
        steps_in_ep = 0

        eps = epsilon_by_episode(episode)
        beta = beta_by_episode(episode)

        while not done:
            global_step += 1
            steps_in_ep += 1

            # Política ε-greedy sobre q_net
            if random.random() < eps:
                action = env.action_space.sample()
            else:
                with torch.no_grad():
                    ob = np.expand_dims(obs, axis=0)
                    ob_t = torch.from_numpy(ob).to(device)
                    q_vals = q_net(ob_t)
                    action = int(torch.argmax(q_vals, dim=1).item())

            next_obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            total_reward += float(reward)

            buffer.add(obs, action, reward, next_obs, done)
            obs = next_obs

            # Entrenamiento solo si hay suficientes muestras
            if len(buffer) >= train_start:
                idxs, isw, batch = buffer.sample(batch_size, beta=beta)
                s, a, r, ns, d = batch

                s_t  = torch.from_numpy(s).to(device)
                ns_t = torch.from_numpy(ns).to(device)
                a_t  = torch.from_numpy(a).long().to(device)
                r_t  = torch.from_numpy(r).float().to(device)
                d_t  = torch.from_numpy(d).float().to(device)
                w_t  = torch.from_numpy(isw).float().to(device)

                # Q(s,a) online
                q = q_net(s_t).gather(1, a_t.unsqueeze(1)).squeeze(1)

                # Double DQN: a* con q_net, eval con target_net
                with torch.no_grad():
                    q_online_ns = q_net(ns_t)
                    a_star = torch.argmax(q_online_ns, dim=1, keepdim=True)

                    q_target_ns = target_net(ns_t)
                    next_q = q_target_ns.gather(1, a_star).squeeze(1)

                    target = r_t + gamma * next_q * (1.0 - d_t)

                td_error = target - q
                loss = (w_t * td_error.pow(2)).mean()

                optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(q_net.parameters(), 10.0)
                optimizer.step()

                new_prios = td_error.detach().abs().cpu().numpy() + per_eps
                buffer.update_priorities(idxs, new_prios)

            if global_step % target_update_interval == 0:
                target_net.load_state_dict(q_net.state_dict())

            if max_steps_per_episode is not None and steps_in_ep >= max_steps_per_episode:
                break

        rewards_log.append(total_reward)
        print(f"[Dueling-DDQN+PER] Ep {episode}/{total_episodes} | R: {total_reward:.1f} | eps={eps:.3f} | beta={beta:.3f} | buf={len(buffer)}")

        # Guardar checkpoint
        if episode % save_interval == 0:
            ckpt_path = os.path.join(checkpoint_dir, f"dueling_ddqn_per_ep{episode}.pth")
            torch.save({
                "q_net": q_net.state_dict(),
                "target_net": target_net.state_dict(),
                "optimizer": optimizer.state_dict(),
                "episode": episode,
                "global_step": global_step,
                "rewards": rewards_log,
                "input_shape": input_shape,
                "n_actions": n_actions,
            }, ckpt_path)
            print(f"[CKPT] Guardado: {ckpt_path}")

        # Guardar gráfica + CSV
        if episode % plot_interval == 0:
            _save_plot_and_csv(checkpoint_dir, rewards_log, episode)

    env.close()

    final_path = os.path.join(checkpoint_dir, "dueling_ddqn_per_final.pth")
    torch.save(q_net.state_dict(), final_path)
    print(f"[DONE] Modelo final guardado en: {final_path}")
    _save_plot_and_csv(checkpoint_dir, rewards_log, total_episodes)

    return q_net

# %%
BASE_DIR = "/content/drive/MyDrive/galaxian_rl"
ckpt = f"{BASE_DIR}/dueling_ddqn_per/dueling_ddqn_per_ep9500.pth"

q_net = train_dueling_double_dqn_per(
    checkpoint_dir=f"{BASE_DIR}/dueling_ddqn_per",
    total_episodes=20000,          # el total final que quieres alcanzar
    resume_from=ckpt,              # <-- aquí se reanuda
    save_interval=500,
    plot_interval=500
)
# Out:
# [RESUME] Cargando checkpoint desde /content/drive/MyDrive/galaxian_rl/dueling_ddqn_per/dueling_ddqn_per_ep9500.pth
# [RESUME] Reanudando desde episodio 9501, global_step=1774076
# [Dueling-DDQN+PER] Ep 9501/20000 | R: 3630.0 | eps=0.050 | beta=1.000 | buf=507
# [Dueling-DDQN+PER] Ep 9502/20000 | R: 2380.0 | eps=0.050 | beta=1.000 | buf=850
# [Dueling-DDQN+PER] Ep 9503/20000 | R: 1460.0 | eps=0.050 | beta=1.000 | buf=1141
# [Dueling-DDQN+PER] Ep 9504/20000 | R: 2570.0 | eps=0.050 | beta=1.000 | buf=1485
# [Dueling-DDQN+PER] Ep 9505/20000 | R: 590.0 | eps=0.050 | beta=1.000 | buf=1637
# [Dueling-DDQN+PER] Ep 9506/20000 | R: 2130.0 | eps=0.050 | beta=1.000 | buf=1991
# [Dueling-DDQN+PER] Ep 9507/20000 | R: 740.0 | eps=0.050 | beta=1.000 | buf=2141
# [Dueling-DDQN+PER] Ep 9508/20000 | R: 1760.0 | eps=0.050 | beta=1.000 | buf=2400
# [Dueling-DDQN+PER] Ep 9509/20000 | R: 2670.0 | eps=0.050 | beta=1.000 | buf=2819
# [Dueling-DDQN+PER] Ep 9510/20000 | R: 1530.0 | eps=0.050 | beta=1.000 | buf=3165
# [Dueling-DDQN+PER] Ep 9511/20000 | R: 550.0 | eps=0.050 | beta=1.000 | buf=3253
# [Dueling-DDQN+PER] Ep 9512/20000 | R: 2790.0 | eps=0.050 | beta=1.000 | buf=3705
# [Dueling-DDQN+PER] Ep 9513/20000 | R: 1660.0 | eps=0.050 | beta=1.000 | buf=4008
# [Dueling-DDQN+PER] Ep 9514/20000 | R: 420.0 | eps=0.050 | beta=1.000 | buf=4087
# [Dueling-DDQN+PER] Ep 9515/20000 | R: 920.0 | eps=0.050 | beta=1.000 | buf=4220
# [Dueling-DDQN+PER] Ep 9516/20000 | R: 1130.0 | eps=0.050 | beta=1.000 | buf=4428
# [Dueling-DDQN+PER] Ep 9517/20000 | R: 1440.0 | eps=0.050 | beta=1.000 | buf=4699
# [Dueling-DDQN+PER] Ep 9518/20000 | R: 1530.0 | eps=0.050 | beta=1.000 | buf=4996
# [Dueling-DDQN+PER] Ep 9519/20000 | R: 1340.0 | eps=0.050 | beta=1.000 | buf=5300
# [Dueling-DDQN+PER] Ep 9520/20000 | R: 1430.0 | eps=0.050 | beta=1.000 | buf=5581
# [Dueling-DDQN+PER] Ep 9521/20000 | R: 980.0 | eps=0.050 | beta=1.000 | buf=5723
# [Dueling-DDQN+PER] Ep 9522/20000 | R: 2320.0 | eps=0.050 | beta=1.000 | buf=6126
# [Dueling-DDQN+PER] Ep 9523/20000 | R: 1710.0 | eps=0.050 | beta=1.000 | buf=6389
# [Dueling-DDQN+PER] Ep 9524/20000 | R: 1280.0 | eps=0.050 | beta=1.000 | buf=6622
# [Dueling-DDQN+PER] Ep 9525/20000 | R: 1430.0 | eps=0.050 | beta=1.000 | buf=6966
# [Dueling-DDQN+PER] Ep 9526/20000 | R: 1460.0 | eps=0.050 | beta=1.000 | buf=7182
# [Dueling-DDQN+PER] Ep 9527/20000 | R: 2300.0 | eps=0.050 | beta=1.000 | buf=7622
# [Dueling-DDQN+PER] Ep 9528/20000 | R: 2430.0 | eps=0.050 | beta=1.000 | buf=8110
# [Dueling-DDQN+PER] Ep 9529/20000 | R: 2630.0 | eps=0.050 | beta=1.000 | buf=8513
# [Dueling-DDQN+PER] Ep 9530/20000 | R: 1350.0 | eps=0.050 | beta=1.000 | buf=8744
# [Dueling-DDQN+PER] Ep 9531/20000 | R: 3450.0 | eps=0.050 | beta=1.000 | buf=9239
# [Dueling-DDQN+PER] Ep 9532/20000 | R: 980.0 | eps=0.050 | beta=1.000 | buf=9412
# [Dueling-DDQN+PER] Ep 9533/20000 | R: 3070.0 | eps=0.050 | beta=1.000 | buf=9915
# [Dueling-DDQN+PER] Ep 9534/20000 | R: 1490.0 | eps=0.050 | beta=1.000 | buf=10177
# [Dueling-DDQN+PER] Ep 9535/20000 | R: 980.0 | eps=0.050 | beta=1.000 | buf=10361
# [Dueling-DDQN+PER] Ep 9536/20000 | R: 1240.0 | eps=0.050 | beta=1.000 | buf=10541
# [Dueling-DDQN+PER] Ep 9537/20000 | R: 2520.0 | eps=0.050 | beta=1.000 | buf=11021
# [Dueling-DDQN+PER] Ep 9538/20000 | R: 2310.0 | eps=0.050 | beta=1.000 | buf=11366
# [Dueling-DDQN+PER] Ep 9539/20000 | R: 1630.0 | eps=0.050 | beta=1.000 | buf=11663
# [Dueling-DDQN+PER] Ep 9540/20000 | R: 910.0 | eps=0.050 | beta=1.000 | buf=11812
# [Dueling-DDQN+PER] Ep 9541/20000 | R: 1290.0 | eps=0.050 | beta=1.000 | buf=12110
# [Dueling-DDQN+PER] Ep 9542/20000 | R: 2180.0 | eps=0.050 | beta=1.000 | buf=12510
# [Dueling-DDQN+PER] Ep 9543/20000 | R: 1860.0 | eps=0.050 | beta=1.000 | buf=12953
# [Dueling-DDQN+PER] Ep 9544/20000 | R: 820.0 | eps=0.050 | beta=1.000 | buf=13086
# [Dueling-DDQN+PER] Ep 9545/20000 | R: 1740.0 | eps=0.050 | beta=1.000 | buf=13487
# [Dueling-DDQN+PER] Ep 9546/20000 | R: 690.0 | eps=0.050 | beta=1.000 | buf=13587
# [Dueling-DDQN+PER] Ep 9547/20000 | R: 1380.0 | eps=0.050 | beta=1.000 | buf=13831
# [Dueling-DDQN+PER] Ep 9548/20000 | R: 1940.0 | eps=0.050 | beta=1.000 | buf=14188
# [Dueling-DDQN+PER] Ep 9549/20000 | R: 1530.0 | eps=0.050 | beta=1.000 | buf=14423
# [Dueling-DDQN+PER] Ep 9550/20000 | R: 2010.0 | eps=0.050 | beta=1.000 | buf=14772
# [Dueling-DDQN+PER] Ep 9551/20000 | R: 1580.0 | eps=0.050 | beta=1.000 | buf=15002
# [Dueling-DDQN+PER] Ep 9552/20000 | R: 430.0 | eps=0.050 | beta=1.000 | buf=15115
# [Dueling-DDQN+PER] Ep 9553/20000 | R: 1440.0 | eps=0.050 | beta=1.000 | buf=15444
# [Dueling-DDQN+PER] Ep 9554/20000 | R: 960.0 | eps=0.050 | beta=1.000 | buf=15610
# [Dueling-DDQN+PER] Ep 9555/20000 | R: 2460.0 | eps=0.050 | beta=1.000 | buf=16045
# [Dueling-DDQN+PER] Ep 9556/20000 | R: 1170.0 | eps=0.050 | beta=1.000 | buf=16324
# [Dueling-DDQN+PER] Ep 9557/20000 | R: 860.0 | eps=0.050 | beta=1.000 | buf=16486
# [Dueling-DDQN+PER] Ep 9558/20000 | R: 1500.0 | eps=0.050 | beta=1.000 | buf=16893
# [Dueling-DDQN+PER] Ep 9559/20000 | R: 2800.0 | eps=0.050 | beta=1.000 | buf=17472
# [Dueling-DDQN+PER] Ep 9560/20000 | R: 750.0 | eps=0.050 | beta=1.000 | buf=17574
# [Dueling-DDQN+PER] Ep 9561/20000 | R: 1000.0 | eps=0.050 | beta=1.000 | buf=17757
# [Dueling-DDQN+PER] Ep 9562/20000 | R: 1490.0 | eps=0.050 | beta=1.000 | buf=18032
# [Dueling-DDQN+PER] Ep 9563/20000 | R: 3050.0 | eps=0.050 | beta=1.000 | buf=18694
# [Dueling-DDQN+PER] Ep 9564/20000 | R: 730.0 | eps=0.050 | beta=1.000 | buf=18831
# [Dueling-DDQN+PER] Ep 9565/20000 | R: 3230.0 | eps=0.050 | beta=1.000 | buf=19415
# [Dueling-DDQN+PER] Ep 9566/20000 | R: 1360.0 | eps=0.050 | beta=1.000 | buf=19648
# [Dueling-DDQN+PER] Ep 9567/20000 | R: 1410.0 | eps=0.050 | beta=1.000 | buf=19910
# [Dueling-DDQN+PER] Ep 9568/20000 | R: 2700.0 | eps=0.050 | beta=1.000 | buf=20398
# [Dueling-DDQN+PER] Ep 9569/20000 | R: 2050.0 | eps=0.050 | beta=1.000 | buf=20669
# [Dueling-DDQN+PER] Ep 9570/20000 | R: 3290.0 | eps=0.050 | beta=1.000 | buf=21243
# [Dueling-DDQN+PER] Ep 9571/20000 | R: 1040.0 | eps=0.050 | beta=1.000 | buf=21397
# [Dueling-DDQN+PER] Ep 9572/20000 | R: 2040.0 | eps=0.050 | beta=1.000 | buf=21648
# [Dueling-DDQN+PER] Ep 9573/20000 | R: 2500.0 | eps=0.050 | beta=1.000 | buf=22210
# [Dueling-DDQN+PER] Ep 9574/20000 | R: 860.0 | eps=0.050 | beta=1.000 | buf=22349
# [Dueling-DDQN+PER] Ep 9575/20000 | R: 1040.0 | eps=0.050 | beta=1.000 | buf=22552
# [Dueling-DDQN+PER] Ep 9576/20000 | R: 2690.0 | eps=0.050 | beta=1.000 | buf=22934
# [Dueling-DDQN+PER] Ep 9577/20000 | R: 1090.0 | eps=0.050 | beta=1.000 | buf=23186
# [Dueling-DDQN+PER] Ep 9578/20000 | R: 1340.0 | eps=0.050 | beta=1.000 | buf=23353
# [Dueling-DDQN+PER] Ep 9579/20000 | R: 2290.0 | eps=0.050 | beta=1.000 | buf=23762
# [Dueling-DDQN+PER] Ep 9580/20000 | R: 1380.0 | eps=0.050 | beta=1.000 | buf=24002
# [Dueling-DDQN+PER] Ep 9581/20000 | R: 1420.0 | eps=0.050 | beta=1.000 | buf=24222
# [Dueling-DDQN+PER] Ep 9582/20000 | R: 2310.0 | eps=0.050 | beta=1.000 | buf=24674
# [Dueling-DDQN+PER] Ep 9583/20000 | R: 1580.0 | eps=0.050 | beta=1.000 | buf=25019
# [Dueling-DDQN+PER] Ep 9584/20000 | R: 1340.0 | eps=0.050 | beta=1.000 | buf=25304
# [Dueling-DDQN+PER] Ep 9585/20000 | R: 1360.0 | eps=0.050 | beta=1.000 | buf=25543
# [Dueling-DDQN+PER] Ep 9586/20000 | R: 1810.0 | eps=0.050 | beta=1.000 | buf=25863
# [Dueling-DDQN+PER] Ep 9587/20000 | R: 460.0 | eps=0.050 | beta=1.000 | buf=25991
# [Dueling-DDQN+PER] Ep 9588/20000 | R: 1630.0 | eps=0.050 | beta=1.000 | buf=26270
# [Dueling-DDQN+PER] Ep 9589/20000 | R: 1620.0 | eps=0.050 | beta=1.000 | buf=26560
# [Dueling-DDQN+PER] Ep 9590/20000 | R: 980.0 | eps=0.050 | beta=1.000 | buf=26680
# [Dueling-DDQN+PER] Ep 9591/20000 | R: 1310.0 | eps=0.050 | beta=1.000 | buf=26886
# [Dueling-DDQN+PER] Ep 9592/20000 | R: 1550.0 | eps=0.050 | beta=1.000 | buf=27162
# [Dueling-DDQN+PER] Ep 9593/20000 | R: 2040.0 | eps=0.050 | beta=1.000 | buf=27646
# [Dueling-DDQN+PER] Ep 9594/20000 | R: 3840.0 | eps=0.050 | beta=1.000 | buf=28216
# [Dueling-DDQN+PER] Ep 9595/20000 | R: 620.0 | eps=0.050 | beta=1.000 | buf=28342
# [Dueling-DDQN+PER] Ep 9596/20000 | R: 790.0 | eps=0.050 | beta=1.000 | buf=28528
# [Dueling-DDQN+PER] Ep 9597/20000 | R: 1000.0 | eps=0.050 | beta=1.000 | buf=28676
# [Dueling-DDQN+PER] Ep 9598/20000 | R: 1700.0 | eps=0.050 | beta=1.000 | buf=28949
# [Dueling-DDQN+PER] Ep 9599/20000 | R: 1190.0 | eps=0.050 | beta=1.000 | buf=29192
# [Dueling-DDQN+PER] Ep 9600/20000 | R: 1410.0 | eps=0.050 | beta=1.000 | buf=29486
# [Dueling-DDQN+PER] Ep 9601/20000 | R: 810.0 | eps=0.050 | beta=1.000 | buf=29663
# [Dueling-DDQN+PER] Ep 9602/20000 | R: 1900.0 | eps=0.050 | beta=1.000 | buf=30052
# [Dueling-DDQN+PER] Ep 9603/20000 | R: 2480.0 | eps=0.050 | beta=1.000 | buf=30497
# [Dueling-DDQN+PER] Ep 9604/20000 | R: 850.0 | eps=0.050 | beta=1.000 | buf=30636
# [Dueling-DDQN+PER] Ep 9605/20000 | R: 2820.0 | eps=0.050 | beta=1.000 | buf=31040
# [Dueling-DDQN+PER] Ep 9606/20000 | R: 1810.0 | eps=0.050 | beta=1.000 | buf=31296
# [Dueling-DDQN+PER] Ep 9607/20000 | R: 4790.0 | eps=0.050 | beta=1.000 | buf=32013
# [Dueling-DDQN+PER] Ep 9608/20000 | R: 1250.0 | eps=0.050 | beta=1.000 | buf=32208
# [Dueling-DDQN+PER] Ep 9609/20000 | R: 4330.0 | eps=0.050 | beta=1.000 | buf=32943
# [Dueling-DDQN+PER] Ep 9610/20000 | R: 810.0 | eps=0.050 | beta=1.000 | buf=33080
# [Dueling-DDQN+PER] Ep 9611/20000 | R: 2600.0 | eps=0.050 | beta=1.000 | buf=33523
# [Dueling-DDQN+PER] Ep 9612/20000 | R: 2150.0 | eps=0.050 | beta=1.000 | buf=33879
# [Dueling-DDQN+PER] Ep 9613/20000 | R: 1060.0 | eps=0.050 | beta=1.000 | buf=34095
# [Dueling-DDQN+PER] Ep 9614/20000 | R: 1710.0 | eps=0.050 | beta=1.000 | buf=34413
# [Dueling-DDQN+PER] Ep 9615/20000 | R: 1530.0 | eps=0.050 | beta=1.000 | buf=34641
# [Dueling-DDQN+PER] Ep 9616/20000 | R: 2550.0 | eps=0.050 | beta=1.000 | buf=35056
# [Dueling-DDQN+PER] Ep 9617/20000 | R: 1330.0 | eps=0.050 | beta=1.000 | buf=35333
# [Dueling-DDQN+PER] Ep 9618/20000 | R: 2570.0 | eps=0.050 | beta=1.000 | buf=35698
# [Dueling-DDQN+PER] Ep 9619/20000 | R: 1150.0 | eps=0.050 | beta=1.000 | buf=35961
# [Dueling-DDQN+PER] Ep 9620/20000 | R: 2490.0 | eps=0.050 | beta=1.000 | buf=36389
# [Dueling-DDQN+PER] Ep 9621/20000 | R: 2070.0 | eps=0.050 | beta=1.000 | buf=36716
# [Dueling-DDQN+PER] Ep 9622/20000 | R: 1340.0 | eps=0.050 | beta=1.000 | buf=36949
# [Dueling-DDQN+PER] Ep 9623/20000 | R: 1950.0 | eps=0.050 | beta=1.000 | buf=37329
# [Dueling-DDQN+PER] Ep 9624/20000 | R: 1360.0 | eps=0.050 | beta=1.000 | buf=37552
# [Dueling-DDQN+PER] Ep 9625/20000 | R: 2550.0 | eps=0.050 | beta=1.000 | buf=37923
# [Dueling-DDQN+PER] Ep 9626/20000 | R: 1300.0 | eps=0.050 | beta=1.000 | buf=38191
# [Dueling-DDQN+PER] Ep 9627/20000 | R: 1370.0 | eps=0.050 | beta=1.000 | buf=38451
# [Dueling-DDQN+PER] Ep 9628/20000 | R: 1000.0 | eps=0.050 | beta=1.000 | buf=38569
# [Dueling-DDQN+PER] Ep 9629/20000 | R: 1040.0 | eps=0.050 | beta=1.000 | buf=38717
# [Dueling-DDQN+PER] Ep 9630/20000 | R: 2220.0 | eps=0.050 | beta=1.000 | buf=39053
# [Dueling-DDQN+PER] Ep 9631/20000 | R: 1010.0 | eps=0.050 | beta=1.000 | buf=39275
# [Dueling-DDQN+PER] Ep 9632/20000 | R: 1020.0 | eps=0.050 | beta=1.000 | buf=39460
# [Dueling-DDQN+PER] Ep 9633/20000 | R: 2170.0 | eps=0.050 | beta=1.000 | buf=39798
# [Dueling-DDQN+PER] Ep 9634/20000 | R: 1630.0 | eps=0.050 | beta=1.000 | buf=40101
# [Dueling-DDQN+PER] Ep 9635/20000 | R: 2390.0 | eps=0.050 | beta=1.000 | buf=40506
# [Dueling-DDQN+PER] Ep 9636/20000 | R: 790.0 | eps=0.050 | beta=1.000 | buf=40658
# [Dueling-DDQN+PER] Ep 9637/20000 | R: 810.0 | eps=0.050 | beta=1.000 | buf=40799
# [Dueling-DDQN+PER] Ep 9638/20000 | R: 2890.0 | eps=0.050 | beta=1.000 | buf=41308
# [Dueling-DDQN+PER] Ep 9639/20000 | R: 690.0 | eps=0.050 | beta=1.000 | buf=41452
# [Dueling-DDQN+PER] Ep 9640/20000 | R: 1550.0 | eps=0.050 | beta=1.000 | buf=41762
# [Dueling-DDQN+PER] Ep 9641/20000 | R: 1260.0 | eps=0.050 | beta=1.000 | buf=41963
# [Dueling-DDQN+PER] Ep 9642/20000 | R: 1480.0 | eps=0.050 | beta=1.000 | buf=42273
# [Dueling-DDQN+PER] Ep 9643/20000 | R: 440.0 | eps=0.050 | beta=1.000 | buf=42403
# [Dueling-DDQN+PER] Ep 9644/20000 | R: 1030.0 | eps=0.050 | beta=1.000 | buf=42600
# [Dueling-DDQN+PER] Ep 9645/20000 | R: 950.0 | eps=0.050 | beta=1.000 | buf=42770
# [Dueling-DDQN+PER] Ep 9646/20000 | R: 1220.0 | eps=0.050 | beta=1.000 | buf=42925
# [Dueling-DDQN+PER] Ep 9647/20000 | R: 1220.0 | eps=0.050 | beta=1.000 | buf=43137
# [Dueling-DDQN+PER] Ep 9648/20000 | R: 1520.0 | eps=0.050 | beta=1.000 | buf=43385
# [Dueling-DDQN+PER] Ep 9649/20000 | R: 1670.0 | eps=0.050 | beta=1.000 | buf=43897
# [Dueling-DDQN+PER] Ep 9650/20000 | R: 1170.0 | eps=0.050 | beta=1.000 | buf=44073
# [Dueling-DDQN+PER] Ep 9651/20000 | R: 1090.0 | eps=0.050 | beta=1.000 | buf=44234
# [Dueling-DDQN+PER] Ep 9652/20000 | R: 1290.0 | eps=0.050 | beta=1.000 | buf=44521
# [Dueling-DDQN+PER] Ep 9653/20000 | R: 650.0 | eps=0.050 | beta=1.000 | buf=44625
# [Dueling-DDQN+PER] Ep 9654/20000 | R: 1110.0 | eps=0.050 | beta=1.000 | buf=44749
# [Dueling-DDQN+PER] Ep 9655/20000 | R: 2370.0 | eps=0.050 | beta=1.000 | buf=45073
# [Dueling-DDQN+PER] Ep 9656/20000 | R: 2540.0 | eps=0.050 | beta=1.000 | buf=45554
# [Dueling-DDQN+PER] Ep 9657/20000 | R: 660.0 | eps=0.050 | beta=1.000 | buf=45663
# [Dueling-DDQN+PER] Ep 9658/20000 | R: 2550.0 | eps=0.050 | beta=1.000 | buf=46298
# [Dueling-DDQN+PER] Ep 9659/20000 | R: 1220.0 | eps=0.050 | beta=1.000 | buf=46485
# [Dueling-DDQN+PER] Ep 9660/20000 | R: 2360.0 | eps=0.050 | beta=1.000 | buf=46849
# [Dueling-DDQN+PER] Ep 9661/20000 | R: 2060.0 | eps=0.050 | beta=1.000 | buf=47327
# [Dueling-DDQN+PER] Ep 9662/20000 | R: 1220.0 | eps=0.050 | beta=1.000 | buf=47540
# [Dueling-DDQN+PER] Ep 9663/20000 | R: 970.0 | eps=0.050 | beta=1.000 | buf=47677
# [Dueling-DDQN+PER] Ep 9664/20000 | R: 1220.0 | eps=0.050 | beta=1.000 | buf=47883
# [Dueling-DDQN+PER] Ep 9665/20000 | R: 2710.0 | eps=0.050 | beta=1.000 | buf=48385
# [Dueling-DDQN+PER] Ep 9666/20000 | R: 1560.0 | eps=0.050 | beta=1.000 | buf=48647
# [Dueling-DDQN+PER] Ep 9667/20000 | R: 660.0 | eps=0.050 | beta=1.000 | buf=48818
# [Dueling-DDQN+PER] Ep 9668/20000 | R: 2070.0 | eps=0.050 | beta=1.000 | buf=49102
# [Dueling-DDQN+PER] Ep 9669/20000 | R: 2190.0 | eps=0.050 | beta=1.000 | buf=49469
# [Dueling-DDQN+PER] Ep 9670/20000 | R: 1480.0 | eps=0.050 | beta=1.000 | buf=49728
# [Dueling-DDQN+PER] Ep 9671/20000 | R: 1570.0 | eps=0.050 | beta=1.000 | buf=50116
# [Dueling-DDQN+PER] Ep 9672/20000 | R: 1720.0 | eps=0.050 | beta=1.000 | buf=50481
# [Dueling-DDQN+PER] Ep 9673/20000 | R: 870.0 | eps=0.050 | beta=1.000 | buf=50619
# [Dueling-DDQN+PER] Ep 9674/20000 | R: 1370.0 | eps=0.050 | beta=1.000 | buf=50810
# [Dueling-DDQN+PER] Ep 9675/20000 | R: 820.0 | eps=0.050 | beta=1.000 | buf=50982
# [Dueling-DDQN+PER] Ep 9676/20000 | R: 4620.0 | eps=0.050 | beta=1.000 | buf=51572
# [Dueling-DDQN+PER] Ep 9677/20000 | R: 1190.0 | eps=0.050 | beta=1.000 | buf=51757
# [Dueling-DDQN+PER] Ep 9678/20000 | R: 740.0 | eps=0.050 | beta=1.000 | buf=51873
# [Dueling-DDQN+PER] Ep 9679/20000 | R: 1570.0 | eps=0.050 | beta=1.000 | buf=52136
# [Dueling-DDQN+PER] Ep 9680/20000 | R: 3080.0 | eps=0.050 | beta=1.000 | buf=52644
# [Dueling-DDQN+PER] Ep 9681/20000 | R: 1390.0 | eps=0.050 | beta=1.000 | buf=52951
# [Dueling-DDQN+PER] Ep 9682/20000 | R: 1890.0 | eps=0.050 | beta=1.000 | buf=53290
# [Dueling-DDQN+PER] Ep 9683/20000 | R: 2280.0 | eps=0.050 | beta=1.000 | buf=53811
# [Dueling-DDQN+PER] Ep 9684/20000 | R: 1950.0 | eps=0.050 | beta=1.000 | buf=54127
# [Dueling-DDQN+PER] Ep 9685/20000 | R: 3560.0 | eps=0.050 | beta=1.000 | buf=54707
# [Dueling-DDQN+PER] Ep 9686/20000 | R: 1160.0 | eps=0.050 | beta=1.000 | buf=54882
# [Dueling-DDQN+PER] Ep 9687/20000 | R: 2850.0 | eps=0.050 | beta=1.000 | buf=55481
# [Dueling-DDQN+PER] Ep 9688/20000 | R: 1440.0 | eps=0.050 | beta=1.000 | buf=55743
# [Dueling-DDQN+PER] Ep 9689/20000 | R: 1180.0 | eps=0.050 | beta=1.000 | buf=55928
# [Dueling-DDQN+PER] Ep 9690/20000 | R: 2800.0 | eps=0.050 | beta=1.000 | buf=56274
# [Dueling-DDQN+PER] Ep 9691/20000 | R: 2040.0 | eps=0.050 | beta=1.000 | buf=56529
# [Dueling-DDQN+PER] Ep 9692/20000 | R: 1060.0 | eps=0.050 | beta=1.000 | buf=56713
# [Dueling-DDQN+PER] Ep 9693/20000 | R: 1310.0 | eps=0.050 | beta=1.000 | buf=56980
# [Dueling-DDQN+PER] Ep 9694/20000 | R: 2800.0 | eps=0.050 | beta=1.000 | buf=57426
# [Dueling-DDQN+PER] Ep 9695/20000 | R: 1910.0 | eps=0.050 | beta=1.000 | buf=57805
# [Dueling-DDQN+PER] Ep 9696/20000 | R: 2090.0 | eps=0.050 | beta=1.000 | buf=58207
# [Dueling-DDQN+PER] Ep 9697/20000 | R: 1350.0 | eps=0.050 | beta=1.000 | buf=58451
# [Dueling-DDQN+PER] Ep 9698/20000 | R: 920.0 | eps=0.050 | beta=1.000 | buf=58609
# [Dueling-DDQN+PER] Ep 9699/20000 | R: 840.0 | eps=0.050 | beta=1.000 | buf=58808
# [Dueling-DDQN+PER] Ep 9700/20000 | R: 2130.0 | eps=0.050 | beta=1.000 | buf=59147
# [Dueling-DDQN+PER] Ep 9701/20000 | R: 2920.0 | eps=0.050 | beta=1.000 | buf=59708
# [Dueling-DDQN+PER] Ep 9702/20000 | R: 1480.0 | eps=0.050 | beta=1.000 | buf=59990
# [Dueling-DDQN+PER] Ep 9703/20000 | R: 2100.0 | eps=0.050 | beta=1.000 | buf=60333
# [Dueling-DDQN+PER] Ep 9704/20000 | R: 1250.0 | eps=0.050 | beta=1.000 | buf=60526
# [Dueling-DDQN+PER] Ep 9705/20000 | R: 1220.0 | eps=0.050 | beta=1.000 | buf=60843
# [Dueling-DDQN+PER] Ep 9706/20000 | R: 4190.0 | eps=0.050 | beta=1.000 | buf=61470
# [Dueling-DDQN+PER] Ep 9707/20000 | R: 2580.0 | eps=0.050 | beta=1.000 | buf=61979
# [Dueling-DDQN+PER] Ep 9708/20000 | R: 1520.0 | eps=0.050 | beta=1.000 | buf=62299
# [Dueling-DDQN+PER] Ep 9709/20000 | R: 2100.0 | eps=0.050 | beta=1.000 | buf=62652
# [Dueling-DDQN+PER] Ep 9710/20000 | R: 1540.0 | eps=0.050 | beta=1.000 | buf=63030
# [Dueling-DDQN+PER] Ep 9711/20000 | R: 1160.0 | eps=0.050 | beta=1.000 | buf=63219
# [Dueling-DDQN+PER] Ep 9712/20000 | R: 1960.0 | eps=0.050 | beta=1.000 | buf=63554
# [Dueling-DDQN+PER] Ep 9713/20000 | R: 4910.0 | eps=0.050 | beta=1.000 | buf=64364
# [Dueling-DDQN+PER] Ep 9714/20000 | R: 550.0 | eps=0.050 | beta=1.000 | buf=64454
# [Dueling-DDQN+PER] Ep 9715/20000 | R: 3590.0 | eps=0.050 | beta=1.000 | buf=65023
# [Dueling-DDQN+PER] Ep 9716/20000 | R: 1460.0 | eps=0.050 | beta=1.000 | buf=65281
# [Dueling-DDQN+PER] Ep 9717/20000 | R: 1500.0 | eps=0.050 | beta=1.000 | buf=65598
# [Dueling-DDQN+PER] Ep 9718/20000 | R: 1300.0 | eps=0.050 | beta=1.000 | buf=65811
# [Dueling-DDQN+PER] Ep 9719/20000 | R: 2580.0 | eps=0.050 | beta=1.000 | buf=66129
# [Dueling-DDQN+PER] Ep 9720/20000 | R: 1390.0 | eps=0.050 | beta=1.000 | buf=66396
# [Dueling-DDQN+PER] Ep 9721/20000 | R: 1780.0 | eps=0.050 | beta=1.000 | buf=66823
# [Dueling-DDQN+PER] Ep 9722/20000 | R: 1600.0 | eps=0.050 | beta=1.000 | buf=67140
# [Dueling-DDQN+PER] Ep 9723/20000 | R: 2480.0 | eps=0.050 | beta=1.000 | buf=67503
# [Dueling-DDQN+PER] Ep 9724/20000 | R: 2670.0 | eps=0.050 | beta=1.000 | buf=67995
# [Dueling-DDQN+PER] Ep 9725/20000 | R: 2800.0 | eps=0.050 | beta=1.000 | buf=68450
# [Dueling-DDQN+PER] Ep 9726/20000 | R: 990.0 | eps=0.050 | beta=1.000 | buf=68591
# [Dueling-DDQN+PER] Ep 9727/20000 | R: 2130.0 | eps=0.050 | beta=1.000 | buf=69019
# [Dueling-DDQN+PER] Ep 9728/20000 | R: 1500.0 | eps=0.050 | beta=1.000 | buf=69307
# [Dueling-DDQN+PER] Ep 9729/20000 | R: 2860.0 | eps=0.050 | beta=1.000 | buf=69839
# [Dueling-DDQN+PER] Ep 9730/20000 | R: 1550.0 | eps=0.050 | beta=1.000 | buf=70143
# [Dueling-DDQN+PER] Ep 9731/20000 | R: 1740.0 | eps=0.050 | beta=1.000 | buf=70367
# [Dueling-DDQN+PER] Ep 9732/20000 | R: 2690.0 | eps=0.050 | beta=1.000 | buf=70737
# [Dueling-DDQN+PER] Ep 9733/20000 | R: 2670.0 | eps=0.050 | beta=1.000 | buf=71287
# [Dueling-DDQN+PER] Ep 9734/20000 | R: 1540.0 | eps=0.050 | beta=1.000 | buf=71553
# [Dueling-DDQN+PER] Ep 9735/20000 | R: 1010.0 | eps=0.050 | beta=1.000 | buf=71694
# [Dueling-DDQN+PER] Ep 9736/20000 | R: 1580.0 | eps=0.050 | beta=1.000 | buf=72063
# [Dueling-DDQN+PER] Ep 9737/20000 | R: 1530.0 | eps=0.050 | beta=1.000 | buf=72357
# [Dueling-DDQN+PER] Ep 9738/20000 | R: 1360.0 | eps=0.050 | beta=1.000 | buf=72579
# [Dueling-DDQN+PER] Ep 9739/20000 | R: 1400.0 | eps=0.050 | beta=1.000 | buf=72771
# [Dueling-DDQN+PER] Ep 9740/20000 | R: 2350.0 | eps=0.050 | beta=1.000 | buf=73123
# [Dueling-DDQN+PER] Ep 9741/20000 | R: 2160.0 | eps=0.050 | beta=1.000 | buf=73484
# [Dueling-DDQN+PER] Ep 9742/20000 | R: 1270.0 | eps=0.050 | beta=1.000 | buf=73712
# [Dueling-DDQN+PER] Ep 9743/20000 | R: 2730.0 | eps=0.050 | beta=1.000 | buf=74138
# [Dueling-DDQN+PER] Ep 9744/20000 | R: 1790.0 | eps=0.050 | beta=1.000 | buf=74390
# [Dueling-DDQN+PER] Ep 9745/20000 | R: 3410.0 | eps=0.050 | beta=1.000 | buf=74978
# [Dueling-DDQN+PER] Ep 9746/20000 | R: 1450.0 | eps=0.050 | beta=1.000 | buf=75177
# [Dueling-DDQN+PER] Ep 9747/20000 | R: 1290.0 | eps=0.050 | beta=1.000 | buf=75423
# [Dueling-DDQN+PER] Ep 9748/20000 | R: 810.0 | eps=0.050 | beta=1.000 | buf=75566
# [Dueling-DDQN+PER] Ep 9749/20000 | R: 960.0 | eps=0.050 | beta=1.000 | buf=75784
# [Dueling-DDQN+PER] Ep 9750/20000 | R: 950.0 | eps=0.050 | beta=1.000 | buf=75935
# [Dueling-DDQN+PER] Ep 9751/20000 | R: 1440.0 | eps=0.050 | beta=1.000 | buf=76176
# [Dueling-DDQN+PER] Ep 9752/20000 | R: 880.0 | eps=0.050 | beta=1.000 | buf=76307
# [Dueling-DDQN+PER] Ep 9753/20000 | R: 1180.0 | eps=0.050 | beta=1.000 | buf=76567
# [Dueling-DDQN+PER] Ep 9754/20000 | R: 1190.0 | eps=0.050 | beta=1.000 | buf=76730
# [Dueling-DDQN+PER] Ep 9755/20000 | R: 1130.0 | eps=0.050 | beta=1.000 | buf=76933
# [Dueling-DDQN+PER] Ep 9756/20000 | R: 450.0 | eps=0.050 | beta=1.000 | buf=77027
# [Dueling-DDQN+PER] Ep 9757/20000 | R: 3350.0 | eps=0.050 | beta=1.000 | buf=77580
# [Dueling-DDQN+PER] Ep 9758/20000 | R: 2220.0 | eps=0.050 | beta=1.000 | buf=78008
# [Dueling-DDQN+PER] Ep 9759/20000 | R: 1660.0 | eps=0.050 | beta=1.000 | buf=78254
# [Dueling-DDQN+PER] Ep 9760/20000 | R: 3020.0 | eps=0.050 | beta=1.000 | buf=78710
# [Dueling-DDQN+PER] Ep 9761/20000 | R: 2250.0 | eps=0.050 | beta=1.000 | buf=79122
# [Dueling-DDQN+PER] Ep 9762/20000 | R: 2570.0 | eps=0.050 | beta=1.000 | buf=79573
# [Dueling-DDQN+PER] Ep 9763/20000 | R: 1300.0 | eps=0.050 | beta=1.000 | buf=79750
# [Dueling-DDQN+PER] Ep 9764/20000 | R: 1490.0 | eps=0.050 | beta=1.000 | buf=80003
# [Dueling-DDQN+PER] Ep 9765/20000 | R: 1460.0 | eps=0.050 | beta=1.000 | buf=80261
# [Dueling-DDQN+PER] Ep 9766/20000 | R: 980.0 | eps=0.050 | beta=1.000 | buf=80455
# [Dueling-DDQN+PER] Ep 9767/20000 | R: 1170.0 | eps=0.050 | beta=1.000 | buf=80648
# [Dueling-DDQN+PER] Ep 9768/20000 | R: 1120.0 | eps=0.050 | beta=1.000 | buf=80841
# [Dueling-DDQN+PER] Ep 9769/20000 | R: 1230.0 | eps=0.050 | beta=1.000 | buf=81075
# [Dueling-DDQN+PER] Ep 9770/20000 | R: 2260.0 | eps=0.050 | beta=1.000 | buf=81573
# [Dueling-DDQN+PER] Ep 9771/20000 | R: 420.0 | eps=0.050 | beta=1.000 | buf=81696
# [Dueling-DDQN+PER] Ep 9772/20000 | R: 3740.0 | eps=0.050 | beta=1.000 | buf=82163
# [Dueling-DDQN+PER] Ep 9773/20000 | R: 1170.0 | eps=0.050 | beta=1.000 | buf=82372
# [Dueling-DDQN+PER] Ep 9774/20000 | R: 1860.0 | eps=0.050 | beta=1.000 | buf=82763
# [Dueling-DDQN+PER] Ep 9775/20000 | R: 900.0 | eps=0.050 | beta=1.000 | buf=82900
# [Dueling-DDQN+PER] Ep 9776/20000 | R: 1380.0 | eps=0.050 | beta=1.000 | buf=83131
# [Dueling-DDQN+PER] Ep 9777/20000 | R: 2600.0 | eps=0.050 | beta=1.000 | buf=83635
# [Dueling-DDQN+PER] Ep 9778/20000 | R: 1070.0 | eps=0.050 | beta=1.000 | buf=83777
# [Dueling-DDQN+PER] Ep 9779/20000 | R: 1540.0 | eps=0.050 | beta=1.000 | buf=84156
# [Dueling-DDQN+PER] Ep 9780/20000 | R: 720.0 | eps=0.050 | beta=1.000 | buf=84274
# [Dueling-DDQN+PER] Ep 9781/20000 | R: 1500.0 | eps=0.050 | beta=1.000 | buf=84549
# [Dueling-DDQN+PER] Ep 9782/20000 | R: 4190.0 | eps=0.050 | beta=1.000 | buf=85104
# [Dueling-DDQN+PER] Ep 9783/20000 | R: 1470.0 | eps=0.050 | beta=1.000 | buf=85338
# [Dueling-DDQN+PER] Ep 9784/20000 | R: 3010.0 | eps=0.050 | beta=1.000 | buf=85785
# [Dueling-DDQN+PER] Ep 9785/20000 | R: 660.0 | eps=0.050 | beta=1.000 | buf=85937
# [Dueling-DDQN+PER] Ep 9786/20000 | R: 1670.0 | eps=0.050 | beta=1.000 | buf=86220
# [Dueling-DDQN+PER] Ep 9787/20000 | R: 3170.0 | eps=0.050 | beta=1.000 | buf=86751
# [Dueling-DDQN+PER] Ep 9788/20000 | R: 1870.0 | eps=0.050 | beta=1.000 | buf=87054
# [Dueling-DDQN+PER] Ep 9789/20000 | R: 390.0 | eps=0.050 | beta=1.000 | buf=87154
# [Dueling-DDQN+PER] Ep 9790/20000 | R: 1480.0 | eps=0.050 | beta=1.000 | buf=87406
# [Dueling-DDQN+PER] Ep 9791/20000 | R: 980.0 | eps=0.050 | beta=1.000 | buf=87609
# [Dueling-DDQN+PER] Ep 9792/20000 | R: 1040.0 | eps=0.050 | beta=1.000 | buf=87770
# [Dueling-DDQN+PER] Ep 9793/20000 | R: 2580.0 | eps=0.050 | beta=1.000 | buf=88168
# [Dueling-DDQN+PER] Ep 9794/20000 | R: 690.0 | eps=0.050 | beta=1.000 | buf=88293
# [Dueling-DDQN+PER] Ep 9795/20000 | R: 1660.0 | eps=0.050 | beta=1.000 | buf=88665
# [Dueling-DDQN+PER] Ep 9796/20000 | R: 710.0 | eps=0.050 | beta=1.000 | buf=88784
# [Dueling-DDQN+PER] Ep 9797/20000 | R: 970.0 | eps=0.050 | beta=1.000 | buf=88964
# [Dueling-DDQN+PER] Ep 9798/20000 | R: 2850.0 | eps=0.050 | beta=1.000 | buf=89469
# [Dueling-DDQN+PER] Ep 9799/20000 | R: 1620.0 | eps=0.050 | beta=1.000 | buf=89741
# [Dueling-DDQN+PER] Ep 9800/20000 | R: 2390.0 | eps=0.050 | beta=1.000 | buf=90008
# [Dueling-DDQN+PER] Ep 9801/20000 | R: 2390.0 | eps=0.050 | beta=1.000 | buf=90444
# [Dueling-DDQN+PER] Ep 9802/20000 | R: 1080.0 | eps=0.050 | beta=1.000 | buf=90618
# [Dueling-DDQN+PER] Ep 9803/20000 | R: 2000.0 | eps=0.050 | beta=1.000 | buf=90969
# [Dueling-DDQN+PER] Ep 9804/20000 | R: 920.0 | eps=0.050 | beta=1.000 | buf=91124
# [Dueling-DDQN+PER] Ep 9805/20000 | R: 2830.0 | eps=0.050 | beta=1.000 | buf=91641
# [Dueling-DDQN+PER] Ep 9806/20000 | R: 4630.0 | eps=0.050 | beta=1.000 | buf=92315
# [Dueling-DDQN+PER] Ep 9807/20000 | R: 1050.0 | eps=0.050 | beta=1.000 | buf=92523
# [Dueling-DDQN+PER] Ep 9808/20000 | R: 1850.0 | eps=0.050 | beta=1.000 | buf=92995
# [Dueling-DDQN+PER] Ep 9809/20000 | R: 1270.0 | eps=0.050 | beta=1.000 | buf=93187
# [Dueling-DDQN+PER] Ep 9810/20000 | R: 510.0 | eps=0.050 | beta=1.000 | buf=93281
# [Dueling-DDQN+PER] Ep 9811/20000 | R: 1260.0 | eps=0.050 | beta=1.000 | buf=93457
# [Dueling-DDQN+PER] Ep 9812/20000 | R: 1750.0 | eps=0.050 | beta=1.000 | buf=93816
# [Dueling-DDQN+PER] Ep 9813/20000 | R: 1700.0 | eps=0.050 | beta=1.000 | buf=94125
# [Dueling-DDQN+PER] Ep 9814/20000 | R: 1510.0 | eps=0.050 | beta=1.000 | buf=94406
# [Dueling-DDQN+PER] Ep 9815/20000 | R: 1360.0 | eps=0.050 | beta=1.000 | buf=94611
# [Dueling-DDQN+PER] Ep 9816/20000 | R: 1600.0 | eps=0.050 | beta=1.000 | buf=94891
# [Dueling-DDQN+PER] Ep 9817/20000 | R: 1050.0 | eps=0.050 | beta=1.000 | buf=95137
# [Dueling-DDQN+PER] Ep 9818/20000 | R: 890.0 | eps=0.050 | beta=1.000 | buf=95289
# [Dueling-DDQN+PER] Ep 9819/20000 | R: 1560.0 | eps=0.050 | beta=1.000 | buf=95536
# [Dueling-DDQN+PER] Ep 9820/20000 | R: 540.0 | eps=0.050 | beta=1.000 | buf=95626
# [Dueling-DDQN+PER] Ep 9821/20000 | R: 2600.0 | eps=0.050 | beta=1.000 | buf=95966
# [Dueling-DDQN+PER] Ep 9822/20000 | R: 570.0 | eps=0.050 | beta=1.000 | buf=96064
# [Dueling-DDQN+PER] Ep 9823/20000 | R: 2370.0 | eps=0.050 | beta=1.000 | buf=96593
# [Dueling-DDQN+PER] Ep 9824/20000 | R: 1080.0 | eps=0.050 | beta=1.000 | buf=96788
# [Dueling-DDQN+PER] Ep 9825/20000 | R: 770.0 | eps=0.050 | beta=1.000 | buf=96910
# [Dueling-DDQN+PER] Ep 9826/20000 | R: 1030.0 | eps=0.050 | beta=1.000 | buf=97049
# [Dueling-DDQN+PER] Ep 9827/20000 | R: 1660.0 | eps=0.050 | beta=1.000 | buf=97331
# [Dueling-DDQN+PER] Ep 9828/20000 | R: 2100.0 | eps=0.050 | beta=1.000 | buf=97727
# [Dueling-DDQN+PER] Ep 9829/20000 | R: 3100.0 | eps=0.050 | beta=1.000 | buf=98117
# [Dueling-DDQN+PER] Ep 9830/20000 | R: 1650.0 | eps=0.050 | beta=1.000 | buf=98401
# [Dueling-DDQN+PER] Ep 9831/20000 | R: 1660.0 | eps=0.050 | beta=1.000 | buf=98700
# [Dueling-DDQN+PER] Ep 9832/20000 | R: 1840.0 | eps=0.050 | beta=1.000 | buf=98994
# [Dueling-DDQN+PER] Ep 9833/20000 | R: 2680.0 | eps=0.050 | beta=1.000 | buf=99504
# [Dueling-DDQN+PER] Ep 9834/20000 | R: 2140.0 | eps=0.050 | beta=1.000 | buf=99985
# [Dueling-DDQN+PER] Ep 9835/20000 | R: 3560.0 | eps=0.050 | beta=1.000 | buf=100605
# [Dueling-DDQN+PER] Ep 9836/20000 | R: 2220.0 | eps=0.050 | beta=1.000 | buf=101009
# [Dueling-DDQN+PER] Ep 9837/20000 | R: 850.0 | eps=0.050 | beta=1.000 | buf=101147
# [Dueling-DDQN+PER] Ep 9838/20000 | R: 2920.0 | eps=0.050 | beta=1.000 | buf=101608
# [Dueling-DDQN+PER] Ep 9839/20000 | R: 1680.0 | eps=0.050 | beta=1.000 | buf=101935
# [Dueling-DDQN+PER] Ep 9840/20000 | R: 660.0 | eps=0.050 | beta=1.000 | buf=102042
# [Dueling-DDQN+PER] Ep 9841/20000 | R: 1530.0 | eps=0.050 | beta=1.000 | buf=102319
# [Dueling-DDQN+PER] Ep 9842/20000 | R: 650.0 | eps=0.050 | beta=1.000 | buf=102463
# [Dueling-DDQN+PER] Ep 9843/20000 | R: 2020.0 | eps=0.050 | beta=1.000 | buf=102770
# [Dueling-DDQN+PER] Ep 9844/20000 | R: 1110.0 | eps=0.050 | beta=1.000 | buf=102946
# [Dueling-DDQN+PER] Ep 9845/20000 | R: 1490.0 | eps=0.050 | beta=1.000 | buf=103164
# [Dueling-DDQN+PER] Ep 9846/20000 | R: 1160.0 | eps=0.050 | beta=1.000 | buf=103362
# [Dueling-DDQN+PER] Ep 9847/20000 | R: 2160.0 | eps=0.050 | beta=1.000 | buf=103804
# [Dueling-DDQN+PER] Ep 9848/20000 | R: 2610.0 | eps=0.050 | beta=1.000 | buf=104208
# [Dueling-DDQN+PER] Ep 9849/20000 | R: 2690.0 | eps=0.050 | beta=1.000 | buf=104672
# [Dueling-DDQN+PER] Ep 9850/20000 | R: 2330.0 | eps=0.050 | beta=1.000 | buf=105060
# [Dueling-DDQN+PER] Ep 9851/20000 | R: 1400.0 | eps=0.050 | beta=1.000 | buf=105290
# [Dueling-DDQN+PER] Ep 9852/20000 | R: 3860.0 | eps=0.050 | beta=1.000 | buf=105927
# [Dueling-DDQN+PER] Ep 9853/20000 | R: 2400.0 | eps=0.050 | beta=1.000 | buf=106344
# [Dueling-DDQN+PER] Ep 9854/20000 | R: 2180.0 | eps=0.050 | beta=1.000 | buf=106840
# [Dueling-DDQN+PER] Ep 9855/20000 | R: 3760.0 | eps=0.050 | beta=1.000 | buf=107492
# [Dueling-DDQN+PER] Ep 9856/20000 | R: 840.0 | eps=0.050 | beta=1.000 | buf=107657
# [Dueling-DDQN+PER] Ep 9857/20000 | R: 1730.0 | eps=0.050 | beta=1.000 | buf=107988
# [Dueling-DDQN+PER] Ep 9858/20000 | R: 1010.0 | eps=0.050 | beta=1.000 | buf=108174
# [Dueling-DDQN+PER] Ep 9859/20000 | R: 2470.0 | eps=0.050 | beta=1.000 | buf=108403
# [Dueling-DDQN+PER] Ep 9860/20000 | R: 1080.0 | eps=0.050 | beta=1.000 | buf=108625
# [Dueling-DDQN+PER] Ep 9861/20000 | R: 2380.0 | eps=0.050 | beta=1.000 | buf=109017
# [Dueling-DDQN+PER] Ep 9862/20000 | R: 1100.0 | eps=0.050 | beta=1.000 | buf=109211
# [Dueling-DDQN+PER] Ep 9863/20000 | R: 2950.0 | eps=0.050 | beta=1.000 | buf=109759
# [Dueling-DDQN+PER] Ep 9864/20000 | R: 2820.0 | eps=0.050 | beta=1.000 | buf=110128
# [Dueling-DDQN+PER] Ep 9865/20000 | R: 1340.0 | eps=0.050 | beta=1.000 | buf=110383
# [Dueling-DDQN+PER] Ep 9866/20000 | R: 1360.0 | eps=0.050 | beta=1.000 | buf=110634
# [Dueling-DDQN+PER] Ep 9867/20000 | R: 2500.0 | eps=0.050 | beta=1.000 | buf=111048
# [Dueling-DDQN+PER] Ep 9868/20000 | R: 1090.0 | eps=0.050 | beta=1.000 | buf=111287
# [Dueling-DDQN+PER] Ep 9869/20000 | R: 1730.0 | eps=0.050 | beta=1.000 | buf=111582
# [Dueling-DDQN+PER] Ep 9870/20000 | R: 1470.0 | eps=0.050 | beta=1.000 | buf=111818
# [Dueling-DDQN+PER] Ep 9871/20000 | R: 2990.0 | eps=0.050 | beta=1.000 | buf=112208
# [Dueling-DDQN+PER] Ep 9872/20000 | R: 2570.0 | eps=0.050 | beta=1.000 | buf=112631
# [Dueling-DDQN+PER] Ep 9873/20000 | R: 2440.0 | eps=0.050 | beta=1.000 | buf=113044
# [Dueling-DDQN+PER] Ep 9874/20000 | R: 3600.0 | eps=0.050 | beta=1.000 | buf=113661
# [Dueling-DDQN+PER] Ep 9875/20000 | R: 1020.0 | eps=0.050 | beta=1.000 | buf=113821
# [Dueling-DDQN+PER] Ep 9876/20000 | R: 1140.0 | eps=0.050 | beta=1.000 | buf=113999
# [Dueling-DDQN+PER] Ep 9877/20000 | R: 1020.0 | eps=0.050 | beta=1.000 | buf=114214
# [Dueling-DDQN+PER] Ep 9878/20000 | R: 1250.0 | eps=0.050 | beta=1.000 | buf=114480
# [Dueling-DDQN+PER] Ep 9879/20000 | R: 2100.0 | eps=0.050 | beta=1.000 | buf=114959
# [Dueling-DDQN+PER] Ep 9880/20000 | R: 2220.0 | eps=0.050 | beta=1.000 | buf=115320
# [Dueling-DDQN+PER] Ep 9881/20000 | R: 1120.0 | eps=0.050 | beta=1.000 | buf=115454
# [Dueling-DDQN+PER] Ep 9882/20000 | R: 1530.0 | eps=0.050 | beta=1.000 | buf=115765
# [Dueling-DDQN+PER] Ep 9883/20000 | R: 2530.0 | eps=0.050 | beta=1.000 | buf=116180
# [Dueling-DDQN+PER] Ep 9884/20000 | R: 1710.0 | eps=0.050 | beta=1.000 | buf=116575
# [Dueling-DDQN+PER] Ep 9885/20000 | R: 1200.0 | eps=0.050 | beta=1.000 | buf=116788
# [Dueling-DDQN+PER] Ep 9886/20000 | R: 1720.0 | eps=0.050 | beta=1.000 | buf=117120
# [Dueling-DDQN+PER] Ep 9887/20000 | R: 1880.0 | eps=0.050 | beta=1.000 | buf=117476
# [Dueling-DDQN+PER] Ep 9888/20000 | R: 1040.0 | eps=0.050 | beta=1.000 | buf=117635
# [Dueling-DDQN+PER] Ep 9889/20000 | R: 2470.0 | eps=0.050 | beta=1.000 | buf=118115
# [Dueling-DDQN+PER] Ep 9890/20000 | R: 840.0 | eps=0.050 | beta=1.000 | buf=118272
# [Dueling-DDQN+PER] Ep 9891/20000 | R: 1430.0 | eps=0.050 | beta=1.000 | buf=118484
# [Dueling-DDQN+PER] Ep 9892/20000 | R: 2890.0 | eps=0.050 | beta=1.000 | buf=119141
# [Dueling-DDQN+PER] Ep 9893/20000 | R: 1430.0 | eps=0.050 | beta=1.000 | buf=119394
# [Dueling-DDQN+PER] Ep 9894/20000 | R: 2530.0 | eps=0.050 | beta=1.000 | buf=119901
# [Dueling-DDQN+PER] Ep 9895/20000 | R: 2810.0 | eps=0.050 | beta=1.000 | buf=120453
# [Dueling-DDQN+PER] Ep 9896/20000 | R: 2670.0 | eps=0.050 | beta=1.000 | buf=120932
# [Dueling-DDQN+PER] Ep 9897/20000 | R: 2310.0 | eps=0.050 | beta=1.000 | buf=121271
# [Dueling-DDQN+PER] Ep 9898/20000 | R: 3290.0 | eps=0.050 | beta=1.000 | buf=121665
# [Dueling-DDQN+PER] Ep 9899/20000 | R: 2290.0 | eps=0.050 | beta=1.000 | buf=122085
# [Dueling-DDQN+PER] Ep 9900/20000 | R: 2060.0 | eps=0.050 | beta=1.000 | buf=122542
# [Dueling-DDQN+PER] Ep 9901/20000 | R: 1980.0 | eps=0.050 | beta=1.000 | buf=122823
# [Dueling-DDQN+PER] Ep 9902/20000 | R: 1470.0 | eps=0.050 | beta=1.000 | buf=123070
# [Dueling-DDQN+PER] Ep 9903/20000 | R: 1980.0 | eps=0.050 | beta=1.000 | buf=123462
# [Dueling-DDQN+PER] Ep 9904/20000 | R: 2160.0 | eps=0.050 | beta=1.000 | buf=123810
# [Dueling-DDQN+PER] Ep 9905/20000 | R: 1730.0 | eps=0.050 | beta=1.000 | buf=124192
# [Dueling-DDQN+PER] Ep 9906/20000 | R: 570.0 | eps=0.050 | beta=1.000 | buf=124295
# [Dueling-DDQN+PER] Ep 9907/20000 | R: 2110.0 | eps=0.050 | beta=1.000 | buf=124617
# [Dueling-DDQN+PER] Ep 9908/20000 | R: 2090.0 | eps=0.050 | beta=1.000 | buf=125009
# [Dueling-DDQN+PER] Ep 9909/20000 | R: 1450.0 | eps=0.050 | beta=1.000 | buf=125384
# [Dueling-DDQN+PER] Ep 9910/20000 | R: 2110.0 | eps=0.050 | beta=1.000 | buf=125896
# [Dueling-DDQN+PER] Ep 9911/20000 | R: 2230.0 | eps=0.050 | beta=1.000 | buf=126340
# [Dueling-DDQN+PER] Ep 9912/20000 | R: 4570.0 | eps=0.050 | beta=1.000 | buf=127121
# [Dueling-DDQN+PER] Ep 9913/20000 | R: 1580.0 | eps=0.050 | beta=1.000 | buf=127448
# [Dueling-DDQN+PER] Ep 9914/20000 | R: 1360.0 | eps=0.050 | beta=1.000 | buf=127681
# [Dueling-DDQN+PER] Ep 9915/20000 | R: 3360.0 | eps=0.050 | beta=1.000 | buf=128234
# [Dueling-DDQN+PER] Ep 9916/20000 | R: 990.0 | eps=0.050 | beta=1.000 | buf=128385
# [Dueling-DDQN+PER] Ep 9917/20000 | R: 1860.0 | eps=0.050 | beta=1.000 | buf=128747
# [Dueling-DDQN+PER] Ep 9918/20000 | R: 3270.0 | eps=0.050 | beta=1.000 | buf=129406
# [Dueling-DDQN+PER] Ep 9919/20000 | R: 1290.0 | eps=0.050 | beta=1.000 | buf=129643
# [Dueling-DDQN+PER] Ep 9920/20000 | R: 4030.0 | eps=0.050 | beta=1.000 | buf=130260
# [Dueling-DDQN+PER] Ep 9921/20000 | R: 880.0 | eps=0.050 | beta=1.000 | buf=130372
# [Dueling-DDQN+PER] Ep 9922/20000 | R: 1440.0 | eps=0.050 | beta=1.000 | buf=130618
# [Dueling-DDQN+PER] Ep 9923/20000 | R: 1240.0 | eps=0.050 | beta=1.000 | buf=130824
# [Dueling-DDQN+PER] Ep 9924/20000 | R: 1630.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9925/20000 | R: 1760.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9926/20000 | R: 1750.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9927/20000 | R: 1360.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9928/20000 | R: 1620.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9929/20000 | R: 790.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9930/20000 | R: 1360.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9931/20000 | R: 1850.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9932/20000 | R: 1330.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9933/20000 | R: 2630.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9934/20000 | R: 2500.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9935/20000 | R: 1220.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9936/20000 | R: 740.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9937/20000 | R: 1080.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9938/20000 | R: 3010.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9939/20000 | R: 2420.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9940/20000 | R: 2390.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9941/20000 | R: 1600.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9942/20000 | R: 2090.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9943/20000 | R: 1580.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9944/20000 | R: 2040.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9945/20000 | R: 1650.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9946/20000 | R: 2420.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9947/20000 | R: 1660.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9948/20000 | R: 3170.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9949/20000 | R: 790.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9950/20000 | R: 1140.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9951/20000 | R: 3210.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9952/20000 | R: 1310.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9953/20000 | R: 3890.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9954/20000 | R: 2410.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9955/20000 | R: 3360.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9956/20000 | R: 2240.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9957/20000 | R: 2210.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9958/20000 | R: 400.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9959/20000 | R: 2650.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9960/20000 | R: 3260.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9961/20000 | R: 4070.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9962/20000 | R: 1540.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9963/20000 | R: 1100.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9964/20000 | R: 2720.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9965/20000 | R: 860.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9966/20000 | R: 480.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9967/20000 | R: 1510.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9968/20000 | R: 2620.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9969/20000 | R: 1580.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9970/20000 | R: 1920.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9971/20000 | R: 2900.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9972/20000 | R: 1000.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9973/20000 | R: 1990.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9974/20000 | R: 1380.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9975/20000 | R: 1910.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9976/20000 | R: 750.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9977/20000 | R: 710.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9978/20000 | R: 1940.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9979/20000 | R: 2370.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9980/20000 | R: 1060.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9981/20000 | R: 1440.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9982/20000 | R: 480.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9983/20000 | R: 1510.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9984/20000 | R: 2560.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9985/20000 | R: 2750.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9986/20000 | R: 650.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9987/20000 | R: 1900.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9988/20000 | R: 1780.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9989/20000 | R: 2350.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9990/20000 | R: 790.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9991/20000 | R: 800.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9992/20000 | R: 2000.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9993/20000 | R: 2770.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9994/20000 | R: 1200.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9995/20000 | R: 3410.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9996/20000 | R: 3800.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9997/20000 | R: 3180.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9998/20000 | R: 1360.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 9999/20000 | R: 950.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10000/20000 | R: 4060.0 | eps=0.050 | beta=1.000 | buf=131072
# [CKPT] Guardado: /content/drive/MyDrive/galaxian_rl/dueling_ddqn_per/dueling_ddqn_per_ep10000.pth
# [LOG] Guardadas gráfica y CSV en: /content/drive/MyDrive/galaxian_rl/dueling_ddqn_per/rewards_ep10000.png / /content/drive/MyDrive/galaxian_rl/dueling_ddqn_per/rewards_log.csv
# [Dueling-DDQN+PER] Ep 10001/20000 | R: 2360.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10002/20000 | R: 1310.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10003/20000 | R: 1340.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10004/20000 | R: 1550.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10005/20000 | R: 3060.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10006/20000 | R: 1770.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10007/20000 | R: 2140.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10008/20000 | R: 2610.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10009/20000 | R: 1720.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10010/20000 | R: 1930.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10011/20000 | R: 1000.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10012/20000 | R: 1960.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10013/20000 | R: 3630.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10014/20000 | R: 1480.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10015/20000 | R: 2230.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10016/20000 | R: 1480.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10017/20000 | R: 1560.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10018/20000 | R: 1850.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10019/20000 | R: 3720.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10020/20000 | R: 1500.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10021/20000 | R: 2610.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10022/20000 | R: 1550.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10023/20000 | R: 2780.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10024/20000 | R: 3430.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10025/20000 | R: 1680.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10026/20000 | R: 1480.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10027/20000 | R: 2280.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10028/20000 | R: 2350.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10029/20000 | R: 630.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10030/20000 | R: 3040.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10031/20000 | R: 600.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10032/20000 | R: 1930.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10033/20000 | R: 2160.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10034/20000 | R: 400.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10035/20000 | R: 2330.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10036/20000 | R: 3210.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10037/20000 | R: 2440.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10038/20000 | R: 840.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10039/20000 | R: 620.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10040/20000 | R: 1940.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10041/20000 | R: 1410.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10042/20000 | R: 870.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10043/20000 | R: 1580.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10044/20000 | R: 1220.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10045/20000 | R: 2170.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10046/20000 | R: 750.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10047/20000 | R: 1250.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10048/20000 | R: 2990.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10049/20000 | R: 870.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10050/20000 | R: 3250.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10051/20000 | R: 2790.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10052/20000 | R: 1980.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10053/20000 | R: 550.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10054/20000 | R: 1350.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10055/20000 | R: 680.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10056/20000 | R: 560.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10057/20000 | R: 1250.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10058/20000 | R: 2070.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10059/20000 | R: 1790.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10060/20000 | R: 1510.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10061/20000 | R: 2420.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10062/20000 | R: 1530.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10063/20000 | R: 1300.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10064/20000 | R: 1100.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10065/20000 | R: 1680.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10066/20000 | R: 2090.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10067/20000 | R: 1140.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10068/20000 | R: 1460.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10069/20000 | R: 4850.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10070/20000 | R: 2090.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10071/20000 | R: 1300.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10072/20000 | R: 1560.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10073/20000 | R: 1890.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10074/20000 | R: 1570.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10075/20000 | R: 4100.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10076/20000 | R: 1270.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10077/20000 | R: 2450.0 | eps=0.050 | beta=1.000 | buf=131072
# ...
# [Dueling-DDQN+PER] Ep 10678/20000 | R: 1030.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10679/20000 | R: 1430.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10680/20000 | R: 1890.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10681/20000 | R: 3040.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10682/20000 | R: 1470.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10683/20000 | R: 5050.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10684/20000 | R: 830.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10685/20000 | R: 2040.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10686/20000 | R: 1560.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10687/20000 | R: 2650.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10688/20000 | R: 2390.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10689/20000 | R: 1690.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10690/20000 | R: 1360.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10691/20000 | R: 3000.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10692/20000 | R: 1190.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10693/20000 | R: 4340.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10694/20000 | R: 3080.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10695/20000 | R: 2330.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10696/20000 | R: 3480.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10697/20000 | R: 2190.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10698/20000 | R: 1980.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10699/20000 | R: 1660.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10700/20000 | R: 1280.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10701/20000 | R: 2900.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10702/20000 | R: 2950.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10703/20000 | R: 3290.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10704/20000 | R: 940.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10705/20000 | R: 2460.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10706/20000 | R: 2170.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10707/20000 | R: 1410.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10708/20000 | R: 1390.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10709/20000 | R: 1390.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10710/20000 | R: 1510.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10711/20000 | R: 1420.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10712/20000 | R: 3820.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10713/20000 | R: 2120.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10714/20000 | R: 1580.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10715/20000 | R: 1970.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10716/20000 | R: 2180.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10717/20000 | R: 1290.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10718/20000 | R: 1230.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10719/20000 | R: 1630.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10720/20000 | R: 1570.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10721/20000 | R: 1000.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10722/20000 | R: 2140.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10723/20000 | R: 1030.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10724/20000 | R: 520.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10725/20000 | R: 1230.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10726/20000 | R: 1180.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10727/20000 | R: 1840.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10728/20000 | R: 3850.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10729/20000 | R: 1340.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10730/20000 | R: 1510.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10731/20000 | R: 2200.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10732/20000 | R: 2000.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10733/20000 | R: 2960.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10734/20000 | R: 2340.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10735/20000 | R: 3530.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10736/20000 | R: 1030.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10737/20000 | R: 2580.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10738/20000 | R: 1610.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10739/20000 | R: 2620.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10740/20000 | R: 770.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10741/20000 | R: 3160.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10742/20000 | R: 1860.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10743/20000 | R: 1110.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10744/20000 | R: 660.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10745/20000 | R: 1720.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10746/20000 | R: 2040.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10747/20000 | R: 930.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10748/20000 | R: 970.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10749/20000 | R: 4000.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10750/20000 | R: 1220.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10751/20000 | R: 1570.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10752/20000 | R: 570.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10753/20000 | R: 3600.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10754/20000 | R: 1410.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10755/20000 | R: 2020.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10756/20000 | R: 3810.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10757/20000 | R: 1420.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10758/20000 | R: 1020.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10759/20000 | R: 2950.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10760/20000 | R: 3420.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10761/20000 | R: 3170.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10762/20000 | R: 1360.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10763/20000 | R: 2440.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10764/20000 | R: 4120.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10765/20000 | R: 2880.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10766/20000 | R: 2420.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10767/20000 | R: 1900.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10768/20000 | R: 770.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10769/20000 | R: 2260.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10770/20000 | R: 3280.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10771/20000 | R: 1500.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10772/20000 | R: 1470.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10773/20000 | R: 2160.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10774/20000 | R: 5370.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10775/20000 | R: 1870.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10776/20000 | R: 2820.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10777/20000 | R: 1380.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10778/20000 | R: 2450.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10779/20000 | R: 4140.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10780/20000 | R: 1850.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10781/20000 | R: 1650.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10782/20000 | R: 3420.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10783/20000 | R: 1720.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10784/20000 | R: 2280.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10785/20000 | R: 1440.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10786/20000 | R: 810.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10787/20000 | R: 2620.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10788/20000 | R: 2500.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10789/20000 | R: 2210.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10790/20000 | R: 1290.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10791/20000 | R: 1280.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10792/20000 | R: 2720.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10793/20000 | R: 1130.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10794/20000 | R: 1390.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10795/20000 | R: 2910.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10796/20000 | R: 1550.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10797/20000 | R: 2450.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10798/20000 | R: 2670.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10799/20000 | R: 1160.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10800/20000 | R: 1520.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10801/20000 | R: 1490.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10802/20000 | R: 2540.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10803/20000 | R: 970.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10804/20000 | R: 880.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10805/20000 | R: 1160.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10806/20000 | R: 1740.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10807/20000 | R: 2060.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10808/20000 | R: 2070.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10809/20000 | R: 2880.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10810/20000 | R: 1570.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10811/20000 | R: 2700.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10812/20000 | R: 2480.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10813/20000 | R: 1310.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10814/20000 | R: 1600.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10815/20000 | R: 1010.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10816/20000 | R: 2150.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10817/20000 | R: 1980.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10818/20000 | R: 2700.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10819/20000 | R: 1770.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10820/20000 | R: 1410.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10821/20000 | R: 1550.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10822/20000 | R: 820.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10823/20000 | R: 1130.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10824/20000 | R: 1520.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10825/20000 | R: 590.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10826/20000 | R: 330.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10827/20000 | R: 1880.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10828/20000 | R: 2070.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10829/20000 | R: 980.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10830/20000 | R: 800.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10831/20000 | R: 1480.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10832/20000 | R: 1950.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10833/20000 | R: 2420.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10834/20000 | R: 1310.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10835/20000 | R: 3110.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10836/20000 | R: 1230.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10837/20000 | R: 3450.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10838/20000 | R: 1830.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10839/20000 | R: 2020.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10840/20000 | R: 2770.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10841/20000 | R: 2310.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10842/20000 | R: 1990.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10843/20000 | R: 1860.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10844/20000 | R: 2140.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10845/20000 | R: 2510.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10846/20000 | R: 1450.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10847/20000 | R: 2880.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10848/20000 | R: 2740.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10849/20000 | R: 2360.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10850/20000 | R: 2740.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10851/20000 | R: 3560.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10852/20000 | R: 4690.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10853/20000 | R: 1870.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10854/20000 | R: 2310.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10855/20000 | R: 1260.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10856/20000 | R: 3290.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10857/20000 | R: 1570.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10858/20000 | R: 2040.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10859/20000 | R: 2790.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10860/20000 | R: 2890.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10861/20000 | R: 1550.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10862/20000 | R: 3870.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10863/20000 | R: 3300.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10864/20000 | R: 2210.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10865/20000 | R: 1330.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10866/20000 | R: 1470.0 | eps=0.050 | beta=1.000 | buf=131072
# [Dueling-DDQN+PER] Ep 10867/20000 | R: 1500.0 | eps=0.050 | beta=1.000 | buf=131072
